# %%
import os

srcs = [
    "foo_010_crop_harvested_area_and_yield/",
    "for_017_potential_vegetation/",
    # Need to change this to foo_038
    "for_038_nutrient_application/",
    "foo_030_effect_of_climate_variation/"
]

for src in srcs:
    os.environ["Zsrc"] = "s3://wri-public-data/resourcewatch/raster/" + src
    os.environ["Zdst"] = "s3://wri-public-data/resourcewatch/raster/intermediate/" + src
    # !aws s3 mv --recursive $Zsrc $Zdst
# Out:
# move: s3://wri-public-data/resourcewatch/raster/foo_010_crop_harvested_area_and_yield/maize_HarvAreaYield2000_NetCDF/mapexamples/Maize_Production.png to s3://wri-public-data/resourcewatch/raster/intermediate/foo_010_crop_harvested_area_and_yield/maize_HarvAreaYield2000_NetCDF/mapexamples/Maize_Production.png
# move: s3://wri-public-data/resourcewatch/raster/foo_010_crop_harvested_area_and_yield/maize_HarvAreaYield2000_NetCDF/METADATA_HarvestedAreaYield175Crops.pdf to s3://wri-public-data/resourcewatch/raster/intermediate/foo_010_crop_harvested_area_and_yield/maize_HarvAreaYield2000_NetCDF/METADATA_HarvestedAreaYield175Crops.pdf
# move: s3://wri-public-data/resourcewatch/raster/foo_010_crop_harvested_area_and_yield/maize_HarvAreaYield2000_NetCDF/mapexamples/Maize_Yield.png to s3://wri-public-data/resourcewatch/raster/intermediate/foo_010_crop_harvested_area_and_yield/maize_HarvAreaYield2000_NetCDF/mapexamples/Maize_Yield.png
# ...

# %%
# !aws s3 ls wri-public-data/resourcewatch/raster/intermediate/
# Out:
#                            PRE maize_HarvAreaYield2000_NetCDF/
#                            PRE rice_HarvAreaYield2000_NetCDF/
#                            PRE soybean_HarvAreaYield2000_NetCDF/
#                            PRE wheat_HarvAreaYield2000_NetCDF/
