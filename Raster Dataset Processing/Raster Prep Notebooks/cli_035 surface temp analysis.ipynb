# %%
# Libraries to fetch data
from urllib.request import urlopen
import shutil
from contextlib import closing
import gzip

# Libraries to handle data
from netCDF4 import Dataset
import rasterio

# Library to interact with OS
import subprocess
import os
import glob

# Libraries to reformat data
#from misc import fix_datetime_UTC
import datetime
from dateutil import parser
import numpy as np # use to set data type for rasterio
np.set_printoptions(threshold='nan')

# Libraries to debug
import logging
import sys
logging.basicConfig(stream=sys.stderr, level=logging.INFO)

# Script options
PROCESS_HISTORY = True


###
## Procedure for obtaining the netcdf file, and processing it to tifs
###

def download_full_nc_history(tmpNcFolder):
    """
    Inputs: location to store nc file temporary
    Outputs: Newest available gistemp250 file name, along with time_start and time_end for the entire collection
    """
    remote_path = 'https://data.giss.nasa.gov/pub/gistemp/'
    ncFile_zipped = 'gistemp250.nc.gz'
    ncFile_name = tmpNcFolder + ncFile_zipped[:-3]

    local_path = os.getcwd()

    logging.info(remote_path)
    logging.info(ncFile_zipped)
    logging.info(ncFile_name)

    #Download the file .nc
    with closing(urlopen(remote_path + ncFile_zipped)) as r:
        with gzip.open(r, "rb") as unzipped:
            with open(ncFile_name, 'wb') as f:
                shutil.copyfileobj(unzipped, f)
    
    logging.info('Downloaded full nc history')
    
    # NEED TO READ TIME_START FROM THE DATA... is in metadata?
    #time_start = fix_datetime_UTC("")
    
    #today = datetime.datetime.now()
    #time_end = fix_datetime_UTC(today)
    nc = Dataset(ncFile_name)
    return (nc)

def create_formatted_dates(ref_time, time_displacements, date_pattern="%Y-%m-%d"):
    """
    Inputs:
    * ref_time in datetime.datetime format
    * list of time values corresponding to data in the nc file
    ** time values are expressed in days since the ref_time
    Outputs:
    * list of strings in desired date_pattern
    """
    formatted_dates = [(ref_time + datetime.timedelta(days=int(time_disp))).strftime(date_pattern) for time_disp in time_displacements]
    return(formatted_dates)
    

def process_full_history_to_tifs(nc, time_var_name, data_var_name,
                                 tmpTifFolder, tifFileName_stub):
    # Extract time variable range
    time_displacements = nc[time_var_name]
    num_time_steps = len(time_displacements)
    logging.info(num_time_steps)
    
    # Identify time units
    # fuzzy=True allows the parser to pick the date out from a string with other text
    time_units = time_displacements.getncattr('units')
    logging.info(time_units)
    ref_time = parser.parse(time_units, fuzzy=True)
    logging.info(ref_time)
    
    # Create dates ready for tif names
    formatted_dates = create_formatted_dates(ref_time, time_displacements)
    
    # Convert nc to tifs
    netcdf2tif(nc, data_var_name, tmpTifFolder, tifFileName_stub, formatted_dates)
    
def process_most_recent_to_tif(nc, time_var_name, data_var_name,
                               tmpTifFolder, tifFileName_stub):
    ### TO DO
    ## Check to see if this is a new addition
    ## For now, simply overwrite
    ###
    
    # Extract time variable range
    time_displacement = nc[time_var_name][-1]
    
    # Identify time units
    # fuzzy=True allows the parser to pick the date out from a string with other text
    time_units = time_displacement.getncattr('units')
    logging.info(time_units)
    ref_time = parser.parse(time_units, fuzzy=True)
    logging.info(ref_time)
    
    # Create date ready for tif name
    formatted_date = create_formatted_dates(ref_time, time_displacement)
    
    # Convert nc to tif
    netcdf2tif(nc, data_var_name, tmpTifFolder, tifFileName_stub, formatted_date)

def netcdf2tif(nc, data_var_name, tmpTifFolder, tifFileName_stub, formatted_datez):
    """
    Inputs: 
    * pointer to a netcdf file, nc
    * variable name to select from the nc
    * folder to place temporary TIFFS
    * base for the tif file names
    * list of formatted_datez corresponding to entries in the nc file... must be a list
    
    Outputs:
    * Formatted TIFF files ready for GEE in tmpTifFolder
    """
    assert(type(formatted_datez)==list)
    for time_step, date in enumerate(formatted_datez):
        # Intercept the case where we're only looking at the most recent observation,
        # not the entire history
        if len(formatted_datez) == 1:
            time_step = -1
            
        data = nc[data_var_name][time_step,:,:]
        tifFile_name = tmpTifFolder + tifFileName_stub + date + "_.tif"

        #data[data < -40] = -99
        #data[data > 40] = -99
        # This was causing an error?
        #print (data)

        # Return lat info
        south_lat = -90
        north_lat = 90
        # Return lon info
        west_lon = -180
        east_lon = 180

        # Transformation function
        transform = rasterio.transform.from_bounds(west_lon, south_lat, east_lon, north_lat, data.shape[1], data.shape[0])
        # Profile
        profile = {
            'driver':'GTiff', 
            'height':data.shape[0], 
            'width':data.shape[1], 
            'count':1, 
            'dtype':np.float64, 
            'crs':'EPSG:4326', 
            'transform':transform, 
            'compress':'lzw', 
            'nodata':-99
        }

        with rasterio.open(tifFile_name, 'w', **profile) as dst:
            dst.write(data.astype(profile['dtype']), 1)

        logging.info('netCDF converted to TIFF' + tifFile_name)

    
###
## Procedure for moving tif files to the cloud
### 
    
def process_tif_files_to_cloud(tmpTifFolder, cloud_props, nodata_val):
    """
    Inputs:
    * folder with tif files to loop over
    * cloud_props, which at least contain keys: imageCollection, gs_bucket
    
    Outputs: files in the correct places on gs and gee
    """
    assert(type(cloud_props)==dict)
    assert(all([prop in cloud_props.keys() for prop in ["imageCollection", "gs_bucket"]]))
    
    # Create collection if doesn't already exist
    cmd = ["earthengine", "create", "collection",
           "users/resourcewatch/" + cloud_props["imageCollection"]]
    logging.info(subprocess.check_output(cmd))

    tifs = glob.glob(tmpTifFolder + "*_.tif")
    
    for ix, tif in enumerate(tifs):
        
        # always the same for this data set
        band_names = "surface_temp_anomalies"
        
        # read time_start from the file name
        # [-15:-5] is derived from the file name convention
        if ix < (len(tifs)-1):
            time_start = tif[-15:-5]
            time_end = tifs[ix+1][-15:-5]
        else:
            time_start = tif[-15:-5]
            ### TO DO
            ## Adjust this... should just increment the month by 1, accounting for year overflow
            ## 
            time_end = (datetime.strptime(time_start,"%Y-%m-%d") + datetime.timedelta(days=31)).strftime("%Y-%m-%d")
        
        # Times need to be expressed in milliseconds since last epoch, UNIX time
        # https://en.wikipedia.org/wiki/Unix_time
        # https://developers.google.com/earth-engine/glossary
        # See discussion here: https://groups.google.com/forum/#!searchin/google-earth-engine-developers/Value$20for$20property$20$27system$3Atime_start$27$20must$20be$20a$20number.%7Csort:date/google-earth-engine-developers/OG-G_7JzQGA/rnf-9oOIGwAJ
        # Livia.p's comment on 11/7/16
        time_start, time_end = format_time_for_gee(time_start, time_end)
        
        ## Some name formatting issues:
        # This isolates the tif name
        tifFile_name = tif.split("/")[-1]
        # The [:-4] below strips .tif from the asset name
        assetName = tifFile_name[:-5]
        kwargs = {
            "localTif_loc":tif,
            "gs_loc":"gs://"+cloud_props["gs_bucket"]+"/raster/"+cloud_props["imageCollection"]+"/"+tifFile_name,
            "gee_props":{
                "imageCollection":cloud_props["imageCollection"],
                "gee_asset_name": "users/resourcewatch/" + cloud_props["imageCollection"] + "/" + assetName,
                "band_names":band_names,
                "nodata_value":nodata_val,
                "time_start":time_start,
                "time_end":time_end
            }
        }

        cloudProcess(**kwargs)
    
def cloudProcess(localTif_loc, gs_loc, gee_props):
    """
    Inputs: 
    * location of the tif to upload
    * loc to upload to on google storage
    * properties to set on the gee_asset, gee_props
    ** gee_props should be a dictionary w/ at least six keys: 
    ** imageCollection, gee_asset_name, band_names, nodata_value, time_start, time_end
    
    Outputs: files in the correct places on gs, and gee
    
    Assumes: Collection of correct name already exists on GEE
    """
    assert(type(gee_props)==dict)
    assert(all([prop in gee_props.keys() for prop in ["imageCollection", "gee_asset_name", "band_names", "nodata_value", "time_start", "time_end"]]))
    
    loadToGoogleStorage(localTif_loc, gs_loc)
    loadToGEE(gs_loc, gee_props)

def loadToGoogleStorage(localTif_loc, gs_loc):
    cmd = ["gsutil", "cp", localTif_loc, gs_loc]
    logging.info(subprocess.check_output(cmd))
    logging.info(localTif_loc.split('/')[-1] + ' up on google storage')

def loadToGEE(gs_loc, gee_props):
    
    ### add in option to overwrite the asset if it is already up
    
    cmd = ["earthengine", "upload", "image",
    "--asset_id", gee_props["gee_asset_name"], gs_loc,
    "--nodata_value", gee_props["nodata_value"],
    "--pyramiding_policy=mode",
    "--bands", gee_props["band_names"],
    "-p", "system:time_start="+gee_props["time_start"],
    "-p", "system:time_end="+gee_props["time_end"]]
    try:
        logging.info(subprocess.check_output(cmd))
        logging.info('GEE asset upload started for ' + gee_props["gee_asset_name"])
        logging.info('Check back to ensure ACL is set to public before attempting to connect to the back office')
    
    except:
        logging.error(gs_loc)
        logging.error(gee_props)
        logging.error("Unexpected error:" + str(sys.exc_info()[0]))
    
###
## Cleaning up
###
    
def cleanUp(tmpDataFolder):
    shutil.rmtree(tmpDataFolder)
    
    
###
## Execution
### 

def main():
    
    logging.info('starting')
    
    # Create a temporary folder structure to store data
    tmpDataFolder = "tmpData"
    try:
        cleanUp(tmpDataFolder)
        os.mkdir(tmpDataFolder)
    except:
        os.mkdir(tmpDataFolder)
    logging.info("Clean folder created")
    
    tmpNcFolder = tmpDataFolder + "/ncFiles/"
    tmpTifFolder = tmpDataFolder + "/tifFiles/"
    os.mkdir(tmpNcFolder)
    os.mkdir(tmpTifFolder)
    
    # Returns the entire history of GISTEMP in a netCDF file
    nc = download_full_nc_history(tmpNcFolder)
    time_var_name = 'time'
    data_var_name = 'tempanomaly'
    nodata_val = str(nc[data_var_name].getncattr("_FillValue"))
    
    # Populate the tmpTifFolder will all files to process
    tifFileName_stub = "cli_035_surface_temp_analysis_"
    if PROCESS_HISTORY:
        process_full_history_to_tifs(nc, time_var_name, data_var_name, 
                                     tmpTifFolder, tifFileName_stub)
    else:
        process_most_recent_to_tif(nc, time_var_name, data_var_name, 
                                   tmpTifFolder, tifFileName_stub)
    
    # Process all files in the tmpTifFolder onto the cloud
    cloud_props = {
        "imageCollection": "cli_035_surface_temp_analysis",
        "gs_bucket": "resource-watch-public"
    }
    process_tif_files_to_cloud(tmpTifFolder, cloud_props, nodata_val)
    
    # Clean up before exit
    #cleanUp(tmpDataFolder)

    logging.info('container process finished, container cleaned')
    
main()
# Out:
# INFO:root:starting
# INFO:root:Clean folder created
# INFO:root:https://data.giss.nasa.gov/pub/gistemp/
# INFO:root:gistemp250.nc.gz
# INFO:root:tmpData/ncFiles/gistemp250.nc
# INFO:root:Downloaded full nc history
# INFO:root:1655
# INFO:root:days since 1800-01-01 00:00:00
# INFO:root:1800-01-01 00:00:00
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1880-01-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1880-02-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1880-03-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1880-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1880-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1880-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1880-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1880-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1880-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1880-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1880-11-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1880-12-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1881-01-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1881-02-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1881-03-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1881-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1881-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1881-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1881-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1881-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1881-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1881-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1881-11-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1881-12-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1882-01-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1882-02-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1882-03-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1882-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1882-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1882-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1882-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1882-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1882-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1882-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1882-11-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1882-12-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1883-01-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1883-02-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1883-03-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1883-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1883-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1883-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1883-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1883-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1883-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1883-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1883-11-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1883-12-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1884-01-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1884-02-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1884-03-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1884-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1884-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1884-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1884-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1884-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1884-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1884-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1884-11-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1884-12-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1885-01-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1885-02-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1885-03-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1885-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1885-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1885-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1885-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1885-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1885-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1885-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1885-11-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1885-12-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1886-01-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1886-02-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1886-03-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1886-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1886-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1886-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1886-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1886-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1886-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1886-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1886-11-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1886-12-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1887-01-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1887-02-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1887-03-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1887-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1887-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1887-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1887-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1887-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1887-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1887-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1887-11-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1887-12-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1888-01-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1888-02-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1888-03-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1888-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1888-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1888-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1888-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1888-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1888-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1888-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1888-11-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1888-12-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1889-01-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1889-02-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1889-03-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1889-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1889-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1889-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1889-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1889-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1889-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1889-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1889-11-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1889-12-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1890-01-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1890-02-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1890-03-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1890-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1890-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1890-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1890-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1890-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1890-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1890-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1890-11-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1890-12-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1891-01-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1891-02-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1891-03-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1891-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1891-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1891-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1891-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1891-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1891-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1891-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1891-11-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1891-12-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1892-01-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1892-02-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1892-03-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1892-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1892-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1892-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1892-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1892-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1892-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1892-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1892-11-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1892-12-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1893-01-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1893-02-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1893-03-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1893-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1893-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1893-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1893-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1893-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1893-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1893-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1893-11-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1893-12-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1894-01-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1894-02-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1894-03-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1894-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1894-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1894-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1894-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1894-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1894-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1894-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1894-11-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1894-12-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1895-01-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1895-02-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1895-03-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1895-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1895-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1895-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1895-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1895-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1895-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1895-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1895-11-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1895-12-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1896-01-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1896-02-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1896-03-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1896-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1896-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1896-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1896-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1896-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1896-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1896-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1896-11-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1896-12-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1897-01-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1897-02-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1897-03-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1897-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1897-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1897-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1897-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1897-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1897-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1897-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1897-11-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1897-12-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1898-01-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1898-02-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1898-03-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1898-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1898-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1898-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1898-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1898-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1898-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1898-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1898-11-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1898-12-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1899-01-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1899-02-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1899-03-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1899-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1899-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1899-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1899-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1899-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1899-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1899-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1899-11-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1899-12-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1900-01-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1900-02-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1900-03-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1900-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1900-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1900-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1900-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1900-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1900-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1900-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1900-11-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1900-12-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1901-01-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1901-02-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1901-03-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1901-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1901-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1901-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1901-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1901-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1901-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1901-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1901-11-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1901-12-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1902-01-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1902-02-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1902-03-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1902-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1902-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1902-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1902-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1902-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1902-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1902-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1902-11-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1902-12-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1903-01-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1903-02-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1903-03-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1903-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1903-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1903-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1903-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1903-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1903-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1903-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1903-11-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1903-12-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1904-01-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1904-02-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1904-03-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1904-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1904-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1904-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1904-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1904-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1904-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1904-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1904-11-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1904-12-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1905-01-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1905-02-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1905-03-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1905-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1905-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1905-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1905-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1905-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1905-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1905-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1905-11-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1905-12-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1906-01-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1906-02-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1906-03-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1906-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1906-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1906-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1906-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1906-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1906-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1906-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1906-11-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1906-12-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1907-01-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1907-02-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1907-03-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1907-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1907-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1907-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1907-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1907-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1907-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1907-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1907-11-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1907-12-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1908-01-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1908-02-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1908-03-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1908-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1908-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1908-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1908-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1908-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1908-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1908-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1908-11-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1908-12-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1909-01-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1909-02-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1909-03-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1909-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1909-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1909-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1909-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1909-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1909-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1909-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1909-11-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1909-12-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1910-01-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1910-02-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1910-03-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1910-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1910-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1910-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1910-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1910-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1910-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1910-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1910-11-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1910-12-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1911-01-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1911-02-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1911-03-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1911-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1911-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1911-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1911-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1911-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1911-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1911-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1911-11-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1911-12-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1912-01-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1912-02-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1912-03-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1912-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1912-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1912-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1912-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1912-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1912-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1912-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1912-11-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1912-12-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1913-01-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1913-02-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1913-03-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1913-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1913-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1913-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1913-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1913-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1913-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1913-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1913-11-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1913-12-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1914-01-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1914-02-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1914-03-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1914-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1914-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1914-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1914-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1914-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1914-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1914-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1914-11-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1914-12-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1915-01-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1915-02-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1915-03-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1915-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1915-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1915-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1915-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1915-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1915-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1915-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1915-11-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1915-12-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1916-01-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1916-02-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1916-03-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1916-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1916-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1916-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1916-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1916-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1916-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1916-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1916-11-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1916-12-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1917-01-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1917-02-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1917-03-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1917-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1917-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1917-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1917-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1917-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1917-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1917-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1917-11-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1917-12-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1918-01-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1918-02-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1918-03-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1918-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1918-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1918-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1918-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1918-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1918-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1918-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1918-11-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1918-12-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1919-01-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1919-02-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1919-03-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1919-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1919-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1919-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1919-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1919-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1919-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1919-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1919-11-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1919-12-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1920-01-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1920-02-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1920-03-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1920-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1920-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1920-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1920-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1920-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1920-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1920-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_1920-11-15_.tif
# ...
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2013-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2013-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2013-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2013-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2013-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2013-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2013-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2013-11-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2013-12-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2014-01-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2014-02-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2014-03-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2014-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2014-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2014-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2014-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2014-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2014-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2014-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2014-11-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2014-12-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2015-01-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2015-02-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2015-03-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2015-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2015-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2015-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2015-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2015-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2015-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2015-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2015-11-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2015-12-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2016-01-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2016-02-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2016-03-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2016-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2016-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2016-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2016-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2016-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2016-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2016-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2016-11-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2016-12-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2017-01-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2017-02-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2017-03-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2017-04-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2017-05-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2017-06-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2017-07-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2017-08-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2017-09-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2017-10-15_.tif
# INFO:root:netCDF converted to TIFFtmpData/tifFiles/cli_035_surface_temp_analysis_2017-11-15_.tif
# INFO:root:b'Asset users/resourcewatch/cli_035_surface_temp_analysis already exists\n'
# INFO:root:b''
# INFO:root:cli_035_surface_temp_analysis_1880-01-15_.tif up on google storage
# ERROR:root:gs://resource-watch-public/raster/cli_035_surface_temp_analysis/cli_035_surface_temp_analysis_1880-01-15_.tif
# ERROR:root:{'imageCollection': 'cli_035_surface_temp_analysis', 'gee_asset_name': 'users/resourcewatch/cli_035_surface_temp_analysis/cli_035_surface_temp_analysis_1880-01-15_', 'band_names': 'surface_temp_anomalies', 'nodata_value': '32767', 'time_start': '1880-01-15', 'time_end': '1880-02-15'}
# ERROR:root:Unexpected error:<class 'subprocess.CalledProcessError'>
# INFO:root:GEE asset upload started for users/resourcewatch/cli_035_surface_temp_analysis/cli_035_surface_temp_analysis_1880-01-15_
# INFO:root:Check back to ensure ACL is set to public before attempting to connect to the back office
# INFO:root:b''
# INFO:root:cli_035_surface_temp_analysis_1880-02-15_.tif up on google storage
# ERROR:root:gs://resource-watch-public/raster/cli_035_surface_temp_analysis/cli_035_surface_temp_analysis_1880-02-15_.tif
# ERROR:root:{'imageCollection': 'cli_035_surface_temp_analysis', 'gee_asset_name': 'users/resourcewatch/cli_035_surface_temp_analysis/cli_035_surface_temp_analysis_1880-02-15_', 'band_names': 'surface_temp_anomalies', 'nodata_value': '32767', 'time_start': '1880-02-15', 'time_end': '1880-03-15'}
# ERROR:root:Unexpected error:<class 'subprocess.CalledProcessError'>
# INFO:root:GEE asset upload started for users/resourcewatch/cli_035_surface_temp_analysis/cli_035_surface_temp_analysis_1880-02-15_
# INFO:root:Check back to ensure ACL is set to public before attempting to connect to the back office
# INFO:root:b''
# INFO:root:cli_035_surface_temp_analysis_1880-03-15_.tif up on google storage
# ERROR:root:gs://resource-watch-public/raster/cli_035_surface_temp_analysis/cli_035_surface_temp_analysis_1880-03-15_.tif
# ERROR:root:{'imageCollection': 'cli_035_surface_temp_analysis', 'gee_asset_name': 'users/resourcewatch/cli_035_surface_temp_analysis/cli_035_surface_temp_analysis_1880-03-15_', 'band_names': 'surface_temp_anomalies', 'nodata_value': '32767', 'time_start': '1880-03-15', 'time_end': '1880-04-15'}
# ERROR:root:Unexpected error:<class 'subprocess.CalledProcessError'>
# INFO:root:GEE asset upload started for users/resourcewatch/cli_035_surface_temp_analysis/cli_035_surface_temp_analysis_1880-03-15_
# INFO:root:Check back to ensure ACL is set to public before attempting to connect to the back office
# INFO:root:b''
# INFO:root:cli_035_surface_temp_analysis_1880-04-15_.tif up on google storage
# ERROR:root:gs://resource-watch-public/raster/cli_035_surface_temp_analysis/cli_035_surface_temp_analysis_1880-04-15_.tif
# ERROR:root:{'imageCollection': 'cli_035_surface_temp_analysis', 'gee_asset_name': 'users/resourcewatch/cli_035_surface_temp_analysis/cli_035_surface_temp_analysis_1880-04-15_', 'band_names': 'surface_temp_anomalies', 'nodata_value': '32767', 'time_start': '1880-04-15', 'time_end': '1880-05-15'}
# ERROR:root:Unexpected error:<class 'subprocess.CalledProcessError'>
# INFO:root:GEE asset upload started for users/resourcewatch/cli_035_surface_temp_analysis/cli_035_surface_temp_analysis_1880-04-15_
# INFO:root:Check back to ensure ACL is set to public before attempting to connect to the back office
# INFO:root:b''
# INFO:root:cli_035_surface_temp_analysis_1880-05-15_.tif up on google storage
# ERROR:root:gs://resource-watch-public/raster/cli_035_surface_temp_analysis/cli_035_surface_temp_analysis_1880-05-15_.tif
# ERROR:root:{'imageCollection': 'cli_035_surface_temp_analysis', 'gee_asset_name': 'users/resourcewatch/cli_035_surface_temp_analysis/cli_035_surface_temp_analysis_1880-05-15_', 'band_names': 'surface_temp_anomalies', 'nodata_value': '32767', 'time_start': '1880-05-15', 'time_end': '1880-06-15'}
# ERROR:root:Unexpected error:<class 'subprocess.CalledProcessError'>
# INFO:root:GEE asset upload started for users/resourcewatch/cli_035_surface_temp_analysis/cli_035_surface_temp_analysis_1880-05-15_
# INFO:root:Check back to ensure ACL is set to public before attempting to connect to the back office
# INFO:root:b''
# INFO:root:cli_035_surface_temp_analysis_1880-06-15_.tif up on google storage
# ERROR:root:gs://resource-watch-public/raster/cli_035_surface_temp_analysis/cli_035_surface_temp_analysis_1880-06-15_.tif
# ERROR:root:{'imageCollection': 'cli_035_surface_temp_analysis', 'gee_asset_name': 'users/resourcewatch/cli_035_surface_temp_analysis/cli_035_surface_temp_analysis_1880-06-15_', 'band_names': 'surface_temp_anomalies', 'nodata_value': '32767', 'time_start': '1880-06-15', 'time_end': '1880-07-15'}
# ERROR:root:Unexpected error:<class 'subprocess.CalledProcessError'>
# INFO:root:GEE asset upload started for users/resourcewatch/cli_035_surface_temp_analysis/cli_035_surface_temp_analysis_1880-06-15_
# INFO:root:Check back to ensure ACL is set to public before attempting to connect to the back office
# INFO:root:b''
# INFO:root:cli_035_surface_temp_analysis_1880-07-15_.tif up on google storage
# ERROR:root:gs://resource-watch-public/raster/cli_035_surface_temp_analysis/cli_035_surface_temp_analysis_1880-07-15_.tif
# ERROR:root:{'imageCollection': 'cli_035_surface_temp_analysis', 'gee_asset_name': 'users/resourcewatch/cli_035_surface_temp_analysis/cli_035_surface_temp_analysis_1880-07-15_', 'band_names': 'surface_temp_anomalies', 'nodata_value': '32767', 'time_start': '1880-07-15', 'time_end': '1880-08-15'}
# ERROR:root:Unexpected error:<class 'subprocess.CalledProcessError'>
# INFO:root:GEE asset upload started for users/resourcewatch/cli_035_surface_temp_analysis/cli_035_surface_temp_analysis_1880-07-15_
# INFO:root:Check back to ensure ACL is set to public before attempting to connect to the back office
# INFO:root:b''
# INFO:root:cli_035_surface_temp_analysis_1880-08-15_.tif up on google storage
# ERROR:root:gs://resource-watch-public/raster/cli_035_surface_temp_analysis/cli_035_surface_temp_analysis_1880-08-15_.tif
# ERROR:root:{'imageCollection': 'cli_035_surface_temp_analysis', 'gee_asset_name': 'users/resourcewatch/cli_035_surface_temp_analysis/cli_035_surface_temp_analysis_1880-08-15_', 'band_names': 'surface_temp_anomalies', 'nodata_value': '32767', 'time_start': '1880-08-15', 'time_end': '1880-09-15'}
# ERROR:root:Unexpected error:<class 'subprocess.CalledProcessError'>
# INFO:root:GEE asset upload started for users/resourcewatch/cli_035_surface_temp_analysis/cli_035_surface_temp_analysis_1880-08-15_
# INFO:root:Check back to ensure ACL is set to public before attempting to connect to the back office
# INFO:root:b''
# INFO:root:cli_035_surface_temp_analysis_1880-09-15_.tif up on google storage
# ERROR:root:gs://resource-watch-public/raster/cli_035_surface_temp_analysis/cli_035_surface_temp_analysis_1880-09-15_.tif
# ERROR:root:{'imageCollection': 'cli_035_surface_temp_analysis', 'gee_asset_name': 'users/resourcewatch/cli_035_surface_temp_analysis/cli_035_surface_temp_analysis_1880-09-15_', 'band_names': 'surface_temp_anomalies', 'nodata_value': '32767', 'time_start': '1880-09-15', 'time_end': '1880-10-15'}
# ERROR:root:Unexpected error:<class 'subprocess.CalledProcessError'>
# INFO:root:GEE asset upload started for users/resourcewatch/cli_035_surface_temp_analysis/cli_035_surface_temp_analysis_1880-09-15_
# INFO:root:Check back to ensure ACL is set to public before attempting to connect to the back office
# INFO:root:b''
# INFO:root:cli_035_surface_temp_analysis_1880-10-15_.tif up on google storage
# ERROR:root:gs://resource-watch-public/raster/cli_035_surface_temp_analysis/cli_035_surface_temp_analysis_1880-10-15_.tif
# ERROR:root:{'imageCollection': 'cli_035_surface_temp_analysis', 'gee_asset_name': 'users/resourcewatch/cli_035_surface_temp_analysis/cli_035_surface_temp_analysis_1880-10-15_', 'band_names': 'surface_temp_anomalies', 'nodata_value': '32767', 'time_start': '1880-10-15', 'time_end': '1880-11-15'}
# ERROR:root:Unexpected error:<class 'subprocess.CalledProcessError'>
# INFO:root:GEE asset upload started for users/resourcewatch/cli_035_surface_temp_analysis/cli_035_surface_temp_analysis_1880-10-15_
# INFO:root:Check back to ensure ACL is set to public before attempting to connect to the back office
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-7b6da444720b> in <module>()
#     339     logging.info('container process finished, container cleaned')
#     340
# --> 341 main()
#
# <ipython-input-38-7b6da444720b> in main()
#     332         "gs_bucket": "resource-watch-public"
#     333     }
# --> 334     process_tif_files_to_cloud(tmpTifFolder, cloud_props, nodata_val)
#     335
#     336     # Clean up before exit
#
# <ipython-input-38-7b6da444720b> in process_tif_files_to_cloud(tmpTifFolder, cloud_props, nodata_val)
#     234         }
#     235
# --> 236         cloudProcess(**kwargs)
#     237
#     238 def cloudProcess(localTif_loc, gs_loc, gee_props):
#
# <ipython-input-38-7b6da444720b> in cloudProcess(localTif_loc, gs_loc, gee_props)
#     252     assert(all([prop in gee_props.keys() for prop in ["imageCollection", "gee_asset_name", "band_names", "nodata_value", "time_start", "time_end"]]))
#     253
# --> 254     loadToGoogleStorage(localTif_loc, gs_loc)
#     255     loadToGEE(gs_loc, gee_props)
#     256
#
# <ipython-input-38-7b6da444720b> in loadToGoogleStorage(localTif_loc, gs_loc)
#     257 def loadToGoogleStorage(localTif_loc, gs_loc):
#     258     cmd = ["gsutil", "cp", localTif_loc, gs_loc]
# --> 259     logging.info(subprocess.check_output(cmd))
#     260     logging.info(localTif_loc.split('/')[-1] + ' up on google storage')
#     261
#
# ~/.pyenv/versions/3.6.0/lib/python3.6/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     334
#     335     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 336                **kwargs).stdout
#     337
#     338
#
# ~/.pyenv/versions/3.6.0/lib/python3.6/subprocess.py in run(input, timeout, check, *popenargs, **kwargs)
#     403     with Popen(*popenargs, **kwargs) as process:
#     404         try:
# --> 405             stdout, stderr = process.communicate(input, timeout=timeout)
#     406         except TimeoutExpired:
#     407             process.kill()
#
# ~/.pyenv/versions/3.6.0/lib/python3.6/subprocess.py in communicate(self, input, timeout)
#     821                 self._stdin_write(input)
#     822             elif self.stdout:
# --> 823                 stdout = self.stdout.read()
#     824                 self.stdout.close()
#     825             elif self.stderr:
#
# KeyboardInterrupt:

# %%
gee_props = {'imageCollection': 'cli_035_surface_temp_analysis', 'gee_asset_name': 'users/resourcewatch/cli_035_surface_temp_analysis/cli_035_surface_temp_analysis_1880-01-15', 'band_names': 'surface_temp_anomalies', 'nodata_value': '32767', 'time_start': '1880-01-15', 'time_end': '1880-02-15'}
gs_loc = "gs://resource-watch-public/raster/cli_035_surface_temp_analysis/cli_035_surface_temp_analysis_1880-01-15_.tif"

def loadToGEE(gs_loc, gee_props):
    
    ### add in option to overwrite the asset if it is already up
    
    cmd = ["earthengine", "upload", "image",
    "--asset_id", gee_props["gee_asset_name"], gs_loc,
    "--nodata_value", gee_props["nodata_value"],
    "--pyramiding_policy=mode",
    "--bands", gee_props["band_names"],
    "-p", "system:time_start="+gee_props["time_start"],
    "-p", "system:time_end="+gee_props["time_end"]]
    
    logging.info(" ".join(cmd))
    
    logging.info(subprocess.check_output(cmd))
    
    logging.info('GEE asset upload started for ' + gee_props["gee_asset_name"])
    logging.info('Check back to ensure ACL is set to public before attempting to connect to the back office')
    
loadToGEE(gs_loc, gee_props)
# Out:
# INFO:root:earthengine upload image --asset_id users/resourcewatch/cli_035_surface_temp_analysis/cli_035_surface_temp_analysis_1880-01-15 gs://resource-watch-public/raster/cli_035_surface_temp_analysis/cli_035_surface_temp_analysis_1880-01-15_.tif --nodata_value 32767 --pyramiding_policy=mode --bands surface_temp_anomalies -p system:time_start=1880-01-15 -p system:time_end=1880-02-15
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-39-28d07338edfa> in <module>()
#      21     logging.info('Check back to ensure ACL is set to public before attempting to connect to the back office')
#      22
# ---> 23 loadToGEE(gs_loc, gee_props)
#
# <ipython-input-39-28d07338edfa> in loadToGEE(gs_loc, gee_props)
#      16     logging.info(" ".join(cmd))
#      17
# ---> 18     logging.info(subprocess.check_output(cmd))
#      19
#      20     logging.info('GEE asset upload started for ' + gee_props["gee_asset_name"])
#
# ~/.pyenv/versions/3.6.0/lib/python3.6/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     334
#     335     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 336                **kwargs).stdout
#     337
#     338
#
# ~/.pyenv/versions/3.6.0/lib/python3.6/subprocess.py in run(input, timeout, check, *popenargs, **kwargs)
#     416         if check and retcode:
#     417             raise CalledProcessError(retcode, process.args,
# --> 418                                      output=stdout, stderr=stderr)
#     419     return CompletedProcess(process.args, retcode, stdout, stderr)
#     420
#
# CalledProcessError: Command '['earthengine', 'upload', 'image', '--asset_id', 'users/resourcewatch/cli_035_surface_temp_analysis/cli_035_surface_temp_analysis_1880-01-15', 'gs://resource-watch-public/raster/cli_035_surface_temp_analysis/cli_035_surface_temp_analysis_1880-01-15_.tif', '--nodata_value', '32767', '--pyramiding_policy=mode', '--bands', 'surface_temp_anomalies', '-p', 'system:time_start=1880-01-15', '-p', 'system:time_end=1880-02-15']' returned non-zero exit status 1.
