# %%
# Add more data, now have lat, lon, and area of each cell
# Merge WFP Price data w/ shapefile
# Rasterize the shapefile
# Logistic regression on whether an area experiences a price spike
# Use NDVI and SPI in an area... maybe trade data? macroeconomic indicators? crop calendars?

# Add a masked layer using Logistics Cluster Global Obstacles data

# File handling, miscellaneous libraries
import os
import pickle
from datetime import date
import zipfile
import json
import itertools

# Data handling libraries
import pandas as pd
pd.options.display.max_columns = 1000
pd.options.display.max_rows = 100
import numpy as np

# External data access & configuration
from hdx.hdx_configuration import Configuration
from hdx.data.dataset import Dataset
try:
    Configuration.create(hdx_site="test", hdx_read_only=True)
except:
    print("HDX already configured")
    
import requests as req

# Analysis libraries
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# Adding data to Carto
from configparser import ConfigParser

config = ConfigParser()
config.read("../.env")
# FROM: https://resourcewatch.carto.com/u/wri-rw/your_apps
carto_api_token = config.get("auth", "carto_api_token")
rw_api_token = config.get("auth", "rw_api_token")

# Libraries for uploading data to S3
import boto3
import sys
import threading

s3_upload = boto3.client("s3")
s3_bucket = "wri-public-data"
s3_folder = "resourcewatch/"

# %%
### Load data from Humanitarian Data Exchange ###
print("Started")
datasets = Dataset.search_in_hdx('Food and Commodity WFP', rows=10)
resource = Dataset.get_resources(datasets[0])
url, path = resource[0].download()

wfp_food_price_data = pd.read_csv(path,encoding = "ISO-8859-1")
df = wfp_food_price_data

print("Data loaded")

# %%
### Helper functions ###

# can be used for the toordinal function
def create_ordinal_date_column(date_tuple):
    return(date.toordinal(date(*date_tuple)))

def add_dummy_columns(df, src_col):
    """Create additional columns on df as dummy variables 
        for values in src_col (i.e. months) """
    
    dummy_data = df.loc[:,(src_col)]
    dummy_vals = dummy_data.unique()
    
    for val in dummy_vals:
        dummy = (dummy_data == val).astype(int)
        df.loc[:,("month_"+str(val))] = dummy
    
    return(df)

def sanity_check(df):
    # TO DO: check whether there are at least 3 records for each month
    months = df["mp_month"]
    #print(months)
    ct_months = np.zeros(12)
    for month in months:
        ct_months[month-1] +=1
        
    #print(ct_months)
    for ct in ct_months:
        if ct < 3:
            return(False)
    return(True)

def calc_alps(dev):
    if(dev < .25):
        return("white")
    elif(dev < 1):
        return("yellow")
    elif(dev < 2):
        return("orange")
    else:
        return("red")

# %%
# List all unique markets, commodities
mkt_names = df.loc[:,"mkt_name"].unique()
print(mkt_names)
commodities = {}
for mkt in mkt_names:
    commodities[mkt] = df.loc[df.loc[:,"mkt_name"]==mkt, "cm_name"].unique()

print("Markets and Commodities Set")

for mkt in mkt_names:
    for cmdty in commodities[mkt]:
        print("Market:", mkt, ", Commodity:", cmdty)
        selection = (df["mkt_name"]==mkt) & (df["cm_name"]==cmdty)
        
        price_history = df.loc[(selection), :]
        
        # Sanity check - at least 3 years of data for each month?
        if(not sanity_check(price_history)):
            print("Not enough raw training data")
            continue
        
        # Create ordinal date column
        date_nums = list(zip(price_history["mp_year"], price_history["mp_month"], np.ones(price_history.shape[0]).astype(int)))
        ordinal_dates = list(map(create_ordinal_date_column, date_nums))
        price_history.loc[:,("ordinal_dates")] = ordinal_dates
        
        # Create dummy columns for each month
        price_history = add_dummy_columns(price_history, "mp_month")
        
        # Create training and label data
        training_cols = ["ordinal_dates", "month_1", "month_2", "month_3",
                        "month_4", "month_5", "month_6",
                        "month_7", "month_8", "month_9",
                        "month_10", "month_11", "month_12"]
        X = price_history.loc[:, training_cols]
        Y = price_history.loc[:,"mp_price"]
        
        lm = linear_model.LinearRegression()
        lm.fit(X, Y)

        #print(lm.coef_)
        #print(lm.intercept_)
        
        # Calculate model residuals
        Y_hat = lm.predict(X)
        residuals = Y - Y_hat
        #print(residuals)
        
        # Divide by standard deviation of residuals
        resid_std_dev = np.sqrt(mean_squared_error(Y, Y_hat))
        ## ^ how to find from lm object?
        std_devs = residuals / resid_std_dev
        
        # Retrain model without first pass outliers
        price_history_tame = price_history.loc[(std_devs > -1) & (std_devs < 1), :]
        
        if(not sanity_check(price_history_tame)):
            print("Not enough tame training data")
            continue
        
        X_tame = price_history.loc[:,training_cols]
        Y_tame = price_history.loc[:,("mp_price")]
                
        lm_tame = linear_model.LinearRegression()
        lm_tame.fit(X_tame, Y_tame)
        
        Y_hat_tame = lm_tame.predict(X)
        residuals_tame = Y - Y_hat_tame
        #print(residuals_tame)
        
        # Divide by standard error of estimatation
        resid_std_dev_tame = np.sqrt(mean_squared_error(Y, Y_hat_tame))
        ## ^ how to find from lm object?
        std_devs_tame = residuals_tame / resid_std_dev_tame
        
        # Calculate ALPS
        ALPS = list(map(calc_alps, std_devs_tame))
        print("setting ALPS on current selection")
        df.loc[selection, "ALPS"] = ALPS
        print(type(list(lm_tame.coef_)))
        df.loc[selection, "Fitted Model"] = lm
        df.loc[selection, "Fitted Model Tame"] = lm_tame
        df.loc[selection, "Model Residual"] = std_devs_tame
        df.loc[selection, "Model Std Error of Residuals"] = resid_std_dev_tame

### Export results to pickle ###
df.to_pickle("/Users/nathansuberi/Desktop/RW_Data/wfp_alps.pkl")

# %%
### Merge WFP food price data from hdx with point locations from FAO GIEWS ###

# %%
# Load pickle, rename for easy typing
wfp_data_with_alps = pd.read_pickle("/Users/nathansuberi/Desktop/RW_Data/wfp_alps.pkl")
df = wfp_data_with_alps

### Possible speedup - create a dictionary of adm0 and adm1 names for each market
# This could avoid a full join in the wfp_alps_summary_by_year block

# Group by market name, price spike level, and year
group_df = df.groupby(["mkt_name", "ALPS", "mp_year", "adm0_name", "adm1_name"])
wfp_alps_summary_by_year = group_df.count().pivot_table(values="adm0_id", index=["mp_year", "mkt_name", "adm0_name", "adm1_name"], columns=["ALPS"])

# Pivot to have a row for each market in each year. Values set to the adm0_id count...
# This represents a count of each ALPS level for the market in a given year
wfp_alps_summary_by_year = wfp_alps_summary_by_year.reset_index()
keep_cols = ['adm0_name', 'adm1_name','mkt_name', 'mp_year',
             'orange', 'red', 'white', 'yellow']
wfp_alps_summary_by_year = wfp_alps_summary_by_year[keep_cols]

# Fetch FAO data to join with it
res = req.get("http://www.fao.org/giews/food-prices/tool/api/v1/series/fao-domestic")
data = res.json()
mkt_df = pd.DataFrame(data)
mkt_df = mkt_df[["market", "marketId", "marketInfo", "marketLatitude", "marketLongitude"]]
mkt_df = mkt_df.drop_duplicates()

# Merge the two
wfp_alps_summary_with_points = wfp_alps_summary_by_year.merge(mkt_df,
                               left_on = "mkt_name",
                               right_on = "market",
                               how="left")
df = wfp_alps_summary_with_points 

# Keep only those records that have market lat longs
wfp_data_with_points_geocoded = df[pd.notnull(df["market"])]

keep_cols = ['adm0_name', 'adm1_name','market','mp_year',
             'marketLatitude','marketLongitude','marketInfo',
            'orange','red','white','yellow']

final_data = wfp_data_with_points_geocoded[keep_cols]
final_data.columns = ['adm0_name', 'adm1_name','market','mp_year',
             'latitude','longitude','marketInfo',
            'orange','red','white','yellow']

### Important! Must rename to "latitude" and "longitude" for auto-georeferencing

# %%
final_data.head(100)
# Out:
#         adm0_name                                    adm1_name  \
# 3    Burkina Faso                                        Sahel
# 6    Burkina Faso                                  Centre-nord
# 9    Burkina Faso                                   Centre-est
# 14   Burkina Faso                                        Sahel
# 17   Burkina Faso                                  Centre-nord
# 20   Burkina Faso                                   Centre-est
# 34          India                                   Tamil Nadu
# 41   Burkina Faso                                        Sahel
# 56   Burkina Faso                                  Centre-nord
# 63          India                                  Maharashtra
# 67          India                                        Bihar
# 73   Burkina Faso                                   Centre-est
# 89          India                                   Tamil Nadu
# 95   Burkina Faso                                        Sahel
# 108  Burkina Faso                                  Centre-nord
# 115         India                                  Maharashtra
# 123  Burkina Faso                                   Centre-est
# 142         India                                   Tamil Nadu
# 149  Burkina Faso                                        Sahel
# 164  Burkina Faso                                  Centre-nord
# 171         India                                  Maharashtra
# 175         India                                        Bihar
# 181  Burkina Faso                                   Centre-est
# 200         India                                   Tamil Nadu
# 207  Burkina Faso                                        Sahel
# 222  Burkina Faso                                  Centre-nord
# 229         India                                  Maharashtra
# 233         India                                        Bihar
# 239  Burkina Faso                                   Centre-est
# 258         India                                   Tamil Nadu
# 265  Burkina Faso                                        Sahel
# 280  Burkina Faso                                  Centre-nord
# 287         India                                  Maharashtra
# 291         India                                        Bihar
# 297  Burkina Faso                                   Centre-est
# 315         India                                   Tamil Nadu
# 322  Burkina Faso                                        Sahel
# 337  Burkina Faso                                  Centre-nord
# 344         India                                  Maharashtra
# 348         India                                        Bihar
# 354  Burkina Faso                                   Centre-est
# 372         India                                   Tamil Nadu
# 374   Philippines                     Region XI (Davao Region)
# 380  Burkina Faso                                        Sahel
# 394   Afghanistan                                    Nangarhar
# 395   Afghanistan                                        Kabul
# 396   Afghanistan                                     Kandahar
# 400  Burkina Faso                                  Centre-nord
# 408         India                                  Maharashtra
# 412         India                                        Bihar
# 418  Burkina Faso                                   Centre-est
# 440         India                                   Tamil Nadu
# 442   Philippines                     Region XI (Davao Region)
# 449  Burkina Faso                                        Sahel
# 464   Afghanistan                                    Nangarhar
# 467   Afghanistan                                        Kabul
# 469   Afghanistan                                     Kandahar
# 473  Burkina Faso                                  Centre-nord
# 481         India                                  Maharashtra
# 486         India                                        Bihar
# 495  Burkina Faso                                   Centre-est
# 517         India                                   Tamil Nadu
# 519   Philippines                     Region XI (Davao Region)
# 526  Burkina Faso                                        Sahel
# 529    Tajikistan  Districts of Republican Subordination (DRS)
# 544   Afghanistan                                    Nangarhar
# 548   Afghanistan                                        Kabul
# 550   Afghanistan                                     Kandahar
# 553    Tajikistan                                        Sughd
# 556  Burkina Faso                                  Centre-nord
# 568         India                                  Maharashtra
# 573         India                                        Bihar
# 582  Burkina Faso                                   Centre-est
# 591          Chad                                      Ouaddai
# 605      Cambodia                             Banteay Meanchey
# 606      Cambodia                                   Battambang
# 611          Chad                                          Lac
# 612         India                                   Tamil Nadu
# 618    Mozambique                                         Gaza
# 622   Philippines                     Region XI (Davao Region)
# 629  Burkina Faso                                        Sahel
# 632    Tajikistan  Districts of Republican Subordination (DRS)
# 637         Sudan                            Northern Kordofan
# 642          Mali                                          Gao
# 657   Afghanistan                                    Nangarhar
# 661   Afghanistan                                        Kabul
# 664         Sudan                            Southern Kordofan
# 668      Cambodia                                 Kampong Cham
# 669      Cambodia                              Kampong Chhnang
# 670      Cambodia                                       Kampot
# 671   Afghanistan                                     Kandahar
# 681    Tajikistan                                        Sughd
# 686  Burkina Faso                                  Centre-nord
# 695        Malawi                              Southern Region
# 696        Malawi                               Central Region
# 709    Mozambique                                       Manica
# 711    Mozambique                               #Maputo (city)
# 723          Chad                              Logone Oriental
# 725         India                                  Maharashtra
# 730        Malawi                              Northern Region
#
#                market  mp_year  latitude longitude  \
# 3                Dori     1992    14.037     -0.05
# 6           Kongoussi     1992    13.333    -1.533
# 9           Tenkodogo     1992    11.783    -0.367
# 14               Dori     1993    14.037     -0.05
# 17          Kongoussi     1993    13.333    -1.533
# 20          Tenkodogo     1993    11.783    -0.367
# 34            Chennai     1994     13.06     80.25
# 41               Dori     1994    14.037     -0.05
# 56          Kongoussi     1994    13.333    -1.533
# 63             Mumbai     1994    19.018    72.856
# 67              Patna     1994    25.614    85.135
# 73          Tenkodogo     1994    11.783    -0.367
# 89            Chennai     1995     13.06     80.25
# 95               Dori     1995    14.037     -0.05
# 108         Kongoussi     1995    13.333    -1.533
# 115            Mumbai     1995    19.018    72.856
# 123         Tenkodogo     1995    11.783    -0.367
# 142           Chennai     1996     13.06     80.25
# 149              Dori     1996    14.037     -0.05
# 164         Kongoussi     1996    13.333    -1.533
# 171            Mumbai     1996    19.018    72.856
# 175             Patna     1996    25.614    85.135
# 181         Tenkodogo     1996    11.783    -0.367
# 200           Chennai     1997     13.06     80.25
# 207              Dori     1997    14.037     -0.05
# 222         Kongoussi     1997    13.333    -1.533
# 229            Mumbai     1997    19.018    72.856
# 233             Patna     1997    25.614    85.135
# 239         Tenkodogo     1997    11.783    -0.367
# 258           Chennai     1998     13.06     80.25
# 265              Dori     1998    14.037     -0.05
# 280         Kongoussi     1998    13.333    -1.533
# 287            Mumbai     1998    19.018    72.856
# 291             Patna     1998    25.614    85.135
# 297         Tenkodogo     1998    11.783    -0.367
# 315           Chennai     1999     13.06     80.25
# 322              Dori     1999    14.037     -0.05
# 337         Kongoussi     1999    13.333    -1.533
# 344            Mumbai     1999    19.018    72.856
# 348             Patna     1999    25.614    85.135
# 354         Tenkodogo     1999    11.783    -0.367
# 372           Chennai     2000     13.06     80.25
# 374        Davao City     2000    7.0900  125.6100
# 380              Dori     2000    14.037     -0.05
# 394         Jalalabad     2000    34.434    70.461
# 395             Kabul     2000   34.5155    69.195
# 396          Kandahar     2000    31.603    65.762
# 400         Kongoussi     2000    13.333    -1.533
# 408            Mumbai     2000    19.018    72.856
# 412             Patna     2000    25.614    85.135
# 418         Tenkodogo     2000    11.783    -0.367
# 440           Chennai     2001     13.06     80.25
# 442        Davao City     2001    7.0900  125.6100
# 449              Dori     2001    14.037     -0.05
# 464         Jalalabad     2001    34.434    70.461
# 467             Kabul     2001   34.5155    69.195
# 469          Kandahar     2001    31.603    65.762
# 473         Kongoussi     2001    13.333    -1.533
# 481            Mumbai     2001    19.018    72.856
# 486             Patna     2001    25.614    85.135
# 495         Tenkodogo     2001    11.783    -0.367
# 517           Chennai     2002     13.06     80.25
# 519        Davao City     2002    7.0900  125.6100
# 526              Dori     2002    14.037     -0.05
# 529          Dushanbe     2002   38.5600   68.7900
# 544         Jalalabad     2002    34.434    70.461
# 548             Kabul     2002   34.5155    69.195
# 550          Kandahar     2002    31.603    65.762
# 553           Khujand     2002   40.2800   69.6400
# 556         Kongoussi     2002    13.333    -1.533
# 568            Mumbai     2002    19.018    72.856
# 573             Patna     2002    25.614    85.135
# 582         Tenkodogo     2002    11.783    -0.367
# 591            Abeche     2003     13.83     20.83
# 605  Banteay Meanchey     2003   13.6673  102.8975
# 606        Battambang     2003   13.0895  103.2044
# 611               Bol     2003     13.47    14.715
# 612           Chennai     2003     13.06     80.25
# 618            Chokwe     2003   -24.529    32.992
# 622        Davao City     2003    7.0900  125.6100
# 629              Dori     2003    14.037     -0.05
# 632          Dushanbe     2003   38.5600   68.7900
# 637          El Obeid     2003    13.174    30.208
# 642               Gao     2003    16.267     -0.05
# 657         Jalalabad     2003    34.434    70.461
# 661             Kabul     2003   34.5155    69.195
# 664           Kadugli     2003    11.005    29.711
# 668      Kampong Cham     2003   11.9914  105.4654
# 669   Kampong Chhnang     2003   12.2567  104.6640
# 670            Kampot     2003   10.6063  104.1819
# 671          Kandahar     2003    31.603    65.762
# 681           Khujand     2003   40.2800   69.6400
# 686         Kongoussi     2003    13.333    -1.533
# 695           Liwonde     2003  -15.0600   35.2300
# 696            Lizulu     2003  -14.5200   34.4700
# 709            Manica     2003   -18.934    32.876
# 711            Maputo     2003   -25.969     32.58
# 723           Moundou     2003      8.57     16.07
# 725            Mumbai     2003    19.018    72.856
# 730            Mzimba     2003  -11.9000   33.6000
#
#                                             marketInfo  orange  red  white  \
# 3    Located in the northern Sahelian region. Food ...     NaN  NaN   12.0
# 6                                                 None     NaN  NaN   12.0
# 9                                                 None     NaN  NaN   10.0
# 14   Located in the northern Sahelian region. Food ...     NaN  NaN   12.0
# 17                                                None     NaN  NaN   12.0
# 20                                                None     NaN  NaN   12.0
# 34   Important rice producing area. Wheat is not pr...    20.0  NaN    1.0
# 41   Located in the northern Sahelian region. Food ...     NaN  NaN   12.0
# 56                                                None     NaN  NaN   12.0
# 63   Main urban food deficit area in the country. L...    18.0  1.0   11.0
# 67   Important producing area for both rice and wheat.     3.0  1.0    NaN
# 73                                                None     NaN  NaN   12.0
# 89   Important rice producing area. Wheat is not pr...     1.0  NaN    NaN
# 95   Located in the northern Sahelian region. Food ...     NaN  NaN   12.0
# 108                                               None     NaN  NaN   11.0
# 115  Main urban food deficit area in the country. L...     1.0  NaN    NaN
# 123                                               None     NaN  NaN   11.0
# 142  Important rice producing area. Wheat is not pr...    14.0  NaN    1.0
# 149  Located in the northern Sahelian region. Food ...     8.0  NaN    NaN
# 164                                               None     3.0  3.0    NaN
# 171  Main urban food deficit area in the country. L...     1.0  NaN    8.0
# 175  Important producing area for both rice and wheat.    33.0  3.0    NaN
# 181                                               None     4.0  NaN    2.0
# 200  Important rice producing area. Wheat is not pr...     9.0  NaN    1.0
# 207  Located in the northern Sahelian region. Food ...     1.0  NaN    5.0
# 222                                               None     5.0  NaN    NaN
# 229  Main urban food deficit area in the country. L...     3.0  NaN    NaN
# 233  Important producing area for both rice and wheat.     9.0  NaN    NaN
# 239                                               None     8.0  NaN    NaN
# 258  Important rice producing area. Wheat is not pr...     NaN  NaN    4.0
# 265  Located in the northern Sahelian region. Food ...     7.0  1.0    1.0
# 280                                               None     6.0  3.0    NaN
# 287  Main urban food deficit area in the country. L...    15.0  NaN    NaN
# 291  Important producing area for both rice and wheat.     NaN  NaN    2.0
# 297                                               None     7.0  4.0    NaN
# 315  Important rice producing area. Wheat is not pr...     NaN  NaN    3.0
# 322  Located in the northern Sahelian region. Food ...     NaN  NaN   11.0
# 337                                               None     NaN  NaN   10.0
# 344  Main urban food deficit area in the country. L...     1.0  NaN   10.0
# 348  Important producing area for both rice and wheat.     5.0  NaN    NaN
# 354                                               None     NaN  NaN   10.0
# 372  Important rice producing area. Wheat is not pr...     NaN  NaN   24.0
# 374                  Rice deficit region in the South.     7.0  2.0    NaN
# 380  Located in the northern Sahelian region. Food ...     NaN  NaN   11.0
# 394  Food deficit district in the north-eastern par...     8.0  NaN   12.0
# 395  Major market in the country for domestic and i...    10.0  NaN    7.0
# 396  Important market in a main wheat producing dis...    12.0  2.0    1.0
# 400                                               None     NaN  NaN   12.0
# 408  Main urban food deficit area in the country. L...    11.0  NaN   20.0
# 412  Important producing area for both rice and wheat.     1.0  NaN   10.0
# 418                                               None     NaN  NaN   12.0
# 440  Important rice producing area. Wheat is not pr...     NaN  NaN   15.0
# 442                  Rice deficit region in the South.     1.0  NaN    3.0
# 449  Located in the northern Sahelian region. Food ...     9.0  NaN    2.0
# 464  Food deficit district in the north-eastern par...    11.0  NaN    3.0
# 467  Major market in the country for domestic and i...     7.0  1.0   10.0
# 469  Important market in a main wheat producing dis...     8.0  1.0    9.0
# 473                                               None     NaN  NaN    4.0
# 481  Main urban food deficit area in the country. L...     NaN  NaN   14.0
# 486  Important producing area for both rice and wheat.     NaN  NaN    9.0
# 495                                               None     3.0  NaN    3.0
# 517  Important rice producing area. Wheat is not pr...     NaN  NaN   36.0
# 519                  Rice deficit region in the South.     1.0  NaN    7.0
# 526  Located in the northern Sahelian region. Food ...     7.0  NaN    NaN
# 529  The capital city market is the main centre for...    17.0  6.0   87.0
# 544  Food deficit district in the north-eastern par...     3.0  3.0   12.0
# 548  Major market in the country for domestic and i...     4.0  3.0   10.0
# 550  Important market in a main wheat producing dis...     2.0  NaN   15.0
# 553                  Second-largest city of Tajikistan    16.0  NaN  114.0
# 556                                               None     2.0  NaN    2.0
# 568  Main urban food deficit area in the country. L...     NaN  NaN   45.0
# 573  Important producing area for both rice and wheat.     NaN  NaN   48.0
# 582                                               None     5.0  NaN    2.0
# 591  Food deficit region with low yields located in...     NaN  NaN    5.0
# 605  It is in the northwest of the country, near Th...     NaN  NaN    8.0
# 606  Battambang is the main hub of the Northwest. T...     NaN  NaN   12.0
# 611  Food deficit area with economy based on subsis...     NaN  NaN    3.0
# 612  Important rice producing area. Wheat is not pr...     NaN  NaN   36.0
# 618                                               None    10.0  NaN   13.0
# 622                  Rice deficit region in the South.     NaN  NaN   12.0
# 629  Located in the northern Sahelian region. Food ...    12.0  1.0   18.0
# 632  The capital city market is the main centre for...     8.0  NaN  140.0
# 637                            Major railway junction.    13.0  NaN    NaN
# 642                                               None    12.0  3.0   11.0
# 657  Food deficit district in the north-eastern par...     NaN  NaN   24.0
# 661  Major market in the country for domestic and i...     NaN  NaN   24.0
# 664            Main sorghum and millet producing area.     4.0  NaN    NaN
# 668  It is the most populous province. Kampong Cham...     NaN  NaN   12.0
# 669  It is a central province of Cambodia. The econ...     NaN  NaN   12.0
# 670  It is a southern privince of Cambodia. Fishing...     NaN  NaN   12.0
# 671  Important market in a main wheat producing dis...     NaN  NaN   24.0
# 681                  Second-largest city of Tajikistan     2.0  NaN  150.0
# 686                                               None     5.0  NaN   21.0
# 695  Maize deficit area, bordering surplus Mozambic...     NaN  NaN    2.0
# 696                      Market in maize deficit area.     1.0  NaN    NaN
# 709                                               None     6.0  NaN   35.0
# 711              Main urban deficit area in the south.     8.0  NaN   11.0
# 723  Major cereal producing area located in the  Su...     NaN  NaN    6.0
# 725  Main urban food deficit area in the country. L...     2.0  NaN   36.0
# 730  Major market in the north, cassava producing area     2.0  NaN    NaN
#
#      yellow
# 3       NaN
# 6       NaN
# 9       2.0
# 14      NaN
# 17      NaN
# 20      NaN
# 34     23.0
# 41      NaN
# 56      NaN
# 63     18.0
# 67      NaN
# 73      NaN
# 89     23.0
# 95      NaN
# 108     1.0
# 115    23.0
# 123     1.0
# 142    33.0
# 149     4.0
# 164     6.0
# 171    39.0
# 175     4.0
# 181     6.0
# 200    14.0
# 207     6.0
# 222     7.0
# 229    21.0
# 233     7.0
# 239     4.0
# 258    20.0
# 265     3.0
# 280     3.0
# 287     9.0
# 291    20.0
# 297     1.0
# 315    21.0
# 322     1.0
# 337     2.0
# 344    13.0
# 348     7.0
# 354     2.0
# 372    12.0
# 374     NaN
# 380     1.0
# 394     2.0
# 395     5.0
# 396     6.0
# 400     NaN
# 408    17.0
# 412    17.0
# 418     NaN
# 440     NaN
# 442     7.0
# 449     1.0
# 464    10.0
# 467     6.0
# 469     NaN
# 473     8.0
# 481     6.0
# 486     3.0
# 495     6.0
# 517     NaN
# 519     2.0
# 526     5.0
# 529   106.0
# 544     6.0
# 548     5.0
# 550     7.0
# 553    86.0
# 556     8.0
# 568     3.0
# 573     NaN
# 582     5.0
# 591     1.0
# 605     4.0
# 606     NaN
# 611     NaN
# 612     NaN
# 618    33.0
# 622     NaN
# 629     5.0
# 632    68.0
# 637    11.0
# 642    10.0
# 657     NaN
# 661     NaN
# 664     NaN
# 668     NaN
# 669     NaN
# 670     NaN
# 671     NaN
# 681    64.0
# 686    10.0
# 695    10.0
# 696    11.0
# 709    26.0
# 711    51.0
# 723     NaN
# 725    10.0
# 730     8.0

# %%
# Push to S3 and then have Carto sync from there
zip_local_name = '/Users/nathansuberi/Desktop/RW_Data/com_008_wfp_alerts_price_spikes.zip'
zip_s3_name = s3_folder + "com_008_wfp_alerts_price_spikes.zip"
with zipfile.ZipFile(zip_local_name, 'w') as csv_zip:
    csv_zip.writestr("com_008_wfp_alerts_price_spikes.csv", final_data.to_csv())

# Upload to S3
s3_upload.upload_file(zip_local_name, s3_bucket, zip_s3_name)

# %%
### ONLY NEED TO RUN THIS ONCE TO SET UP THE SYNC ###

alps_data_url = "https://wri-public-data.s3.amazonaws.com/resourcewatch/com_008_wfp_alerts_price_spikes.zip"

# 3600 = sync every hour
# 3600 * 24 * 30 = sync every week
interval = str(3600*24*7)

alps_payload = {
    "url":alps_data_url,
    "interval":interval
}

sync_url = "https://wri-rw.carto.com/api/v1/synchronizations/?api_key={}".format(carto_api_token)
headers = {
    'content-type': "application/json"
}

alps_res = req.request("POST", sync_url, data=json.dumps(alps_payload), headers = headers)
print("alps:", alps_res.text)

# %%
# Base URL for getting dataset metadata from RW API
# Metadata = Data that describes Data 
url = "https://api.resourcewatch.org/v1/dataset?sort=slug,-provider,userId&status=saved&includes=metadata,vocabulary,widget,layer"

# page[size] tells the API the maximum number of results to send back
# There are currently between 200 and 300 datasets on the RW API
payload = { "application":"rw", "page[size]": 1000}

# Request all datasets, and extract the data from the response
res = req.get(url, params=payload)
data = res.json()["data"]

#############################################################

### Convert the json object returned by the API into a pandas DataFrame
# Another option: https://pandas.pydata.org/pandas-docs/stable/generated/pandas.io.json.json_normalize.html
datasets_on_api = {}

for ix, dset in enumerate(data):

    atts = dset["attributes"]
    metadata = atts["metadata"]
    layers = atts["layer"]
    widgets = atts["widget"]
    tags = atts["vocabulary"]
    datasets_on_api[atts["name"]] = {
        "rw_id":dset["id"],
        "upload_name":atts["name"],
        "table_name":atts["tableName"],
        "provider":atts["provider"],
        "date_updated":atts["updatedAt"],
        "num_metadata_keys":len(metadata),
        "metadata": metadata,
        "num_layers":len(layers),
        "layers": layers,
        "num_widgets":len(widgets),
        "widgets": widgets,
        "num_tags":len(tags),
        "tags":tags
    }    
    
# Create the DataFrame, name the index, and sort by date_updated
# More recently updated datasets at the top
current_datasets_on_api = pd.DataFrame.from_dict(datasets_on_api, orient='index')

def check_public_title(metadata):
    if len(metadata) > 0:
        mdata = metadata[0]
        if "attributes" in mdata:
            if "info" in mdata["attributes"]:
                if "name" in mdata["attributes"]["info"]:
                    return(mdata["attributes"]["info"]["name"])
        return(None)

# Grab public title, if it exists in metadata
current_datasets_on_api["public_title"] = current_datasets_on_api.apply(lambda row: check_public_title(row["metadata"]), axis=1)

current_datasets_on_api.set_index("rw_id", inplace=True)
current_datasets_on_api.index.rename("Dataset", inplace=True)
current_datasets_on_api.sort_values(by=["date_updated"], inplace=True, ascending = False)

# %%
current_datasets_on_api.loc["e4bdc4c9-96a3-4f0b-8d8f-1742cabd8f80", "layers"]
# Out:
# [{'attributes': {'application': ['rw'],
#    'applicationConfig': {},
#    'dataset': 'e4bdc4c9-96a3-4f0b-8d8f-1742cabd8f80',
#    'default': False,
#    'description': 'This shows the number of markets at alert level orange from the WFP, in the year 2014',
#    'env': 'production',
#    'interactionConfig': {},
#    'iso': [''],
#    'layerConfig': {'account': 'wri-rw',
#     'body': {'layers': [{'options': {'cartocss': '#com_008_wfp_alerts_price_spikes{marker-width:3; marker-opacity:1; marker-fill:#FFA500; marker-allow-overlap: true;[orange>=20]{marker-width:15;} [orange>=15][orange<20]{marker-width:12;}[orange>=10][orange<15]{marker-width:7;} [orange>=5][orange<10]{marker-width:4;}[orange<5]{marker-width:3;}}',
#         'cartocss_version': '2.3.0',
#         'sql': 'SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2014'},
#        'type': 'cartodb'}],
#      'maxzoom': 18,
#      'minzoom': 3}},
#    'legendConfig': {'items': [{'color': '#FFA500',
#       'name': 'WFP markets at alert level orange in 2014'}],
#     'type': 'basic'},
#    'name': 'Alerts for Price Spikes - level orange in 2014',
#    'provider': 'cartodb',
#    'slug': 'Alerts-for-Price-Spikes-level-orange-in-2014',
#    'staticImageConfig': {},
#    'updatedAt': '2017-11-02T15:52:41.545Z',
#    'userId': '58f66f96733af88e4f563967'},
#   'id': 'ba943d0b-7cbe-4db8-ba36-f5ada9ca406a',
#   'type': 'layer'},
#  {'attributes': {'application': ['rw'],
#    'applicationConfig': {},
#    'dataset': 'e4bdc4c9-96a3-4f0b-8d8f-1742cabd8f80',
#    'default': False,
#    'description': 'This shows the number of markets at alert level red from the WFP, in the year 2014',
#    'env': 'production',
#    'interactionConfig': {},
#    'iso': [''],
#    'layerConfig': {'account': 'wri-rw',
#     'body': {'layers': [{'options': {'cartocss': '#com_008_wfp_alerts_price_spikes{marker-width:3; marker-opacity:1; marker-fill:#FF0000; marker-allow-overlap: true;[red>=20]{marker-width:15;} [red>=15][red<20]{marker-width:12;}[red>=10][red<15]{marker-width:7;} [red>=5][red<10]{marker-width:4;}[red<5]{marker-width:3;}}',
#         'cartocss_version': '2.3.0',
#         'sql': 'SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2014'},
#        'type': 'cartodb'}],
#      'maxzoom': 18,
#      'minzoom': 3}},
#    'legendConfig': {'items': [{'color': '#FF0000',
#       'name': 'WFP markets at alert level red in 2014'}],
#     'type': 'basic'},
#    'name': 'Alerts for Price Spikes - level red in 2014',
#    'provider': 'cartodb',
#    'slug': 'Alerts-for-Price-Spikes-level-red-in-2014',
#    'staticImageConfig': {},
#    'updatedAt': '2017-11-02T15:52:41.823Z',
#    'userId': '58f66f96733af88e4f563967'},
#   'id': '65026bf8-06dd-49b2-a64f-ab38fa38d4ca',
#   'type': 'layer'},
#  {'attributes': {'application': ['rw'],
#    'applicationConfig': {},
#    'dataset': 'e4bdc4c9-96a3-4f0b-8d8f-1742cabd8f80',
#    'default': False,
#    'description': 'This shows the number of markets at alert level white from the WFP, in the year 2014',
#    'env': 'production',
#    'interactionConfig': {},
#    'iso': [''],
#    'layerConfig': {'account': 'wri-rw',
#     'body': {'layers': [{'options': {'cartocss': '#com_008_wfp_alerts_price_spikes{marker-width:3; marker-opacity:1; marker-fill:#FFFFFF; marker-allow-overlap: true;[white>=20]{marker-width:15;} [white>=15][white<20]{marker-width:12;}[white>=10][white<15]{marker-width:7;} [white>=5][white<10]{marker-width:4;}[white<5]{marker-width:3;}}',
#         'cartocss_version': '2.3.0',
#         'sql': 'SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2014'},
#        'type': 'cartodb'}],
#      'maxzoom': 18,
#      'minzoom': 3}},
#    'legendConfig': {'items': [{'color': '#FFFFFF',
#       'name': 'WFP markets at alert level white in 2014'}],
#     'type': 'basic'},
#    'name': 'Alerts for Price Spikes - level white in 2014',
#    'provider': 'cartodb',
#    'slug': 'Alerts-for-Price-Spikes-level-white-in-2014',
#    'staticImageConfig': {},
#    'updatedAt': '2017-11-02T15:52:42.079Z',
#    'userId': '58f66f96733af88e4f563967'},
#   'id': '7fdd6c3e-ed20-4cbe-a41b-13e59bde86d0',
#   'type': 'layer'},
#  {'attributes': {'application': ['rw'],
#    'applicationConfig': {},
#    'dataset': 'e4bdc4c9-96a3-4f0b-8d8f-1742cabd8f80',
#    'default': False,
#    'description': 'This shows the number of markets at alert level yellow from the WFP, in the year 2014',
#    'env': 'production',
#    'interactionConfig': {},
#    'iso': [''],
#    'layerConfig': {'account': 'wri-rw',
#     'body': {'layers': [{'options': {'cartocss': '#com_008_wfp_alerts_price_spikes{marker-width:3; marker-opacity:1; marker-fill:#FFFF00; marker-allow-overlap: true;[yellow>=20]{marker-width:15;} [yellow>=15][yellow<20]{marker-width:12;}[yellow>=10][yellow<15]{marker-width:7;} [yellow>=5][yellow<10]{marker-width:4;}[yellow<5]{marker-width:3;}}',
#         'cartocss_version': '2.3.0',
#         'sql': 'SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2014'},
#        'type': 'cartodb'}],
#      'maxzoom': 18,
#      'minzoom': 3}},
#    'legendConfig': {'items': [{'color': '#FFFF00',
#       'name': 'WFP markets at alert level yellow in 2014'}],
#     'type': 'basic'},
#    'name': 'Alerts for Price Spikes - level yellow in 2014',
#    'provider': 'cartodb',
#    'slug': 'Alerts-for-Price-Spikes-level-yellow-in-2014',
#    'staticImageConfig': {},
#    'updatedAt': '2017-11-02T15:52:42.284Z',
#    'userId': '58f66f96733af88e4f563967'},
#   'id': 'c8cc122a-6712-4ac1-9bb4-6e5363b36cc0',
#   'type': 'layer'},
#  {'attributes': {'application': ['rw'],
#    'applicationConfig': {},
#    'dataset': 'e4bdc4c9-96a3-4f0b-8d8f-1742cabd8f80',
#    'default': False,
#    'description': 'This shows the number of markets at alert level orange from the WFP, in the year 2015',
#    'env': 'production',
#    'interactionConfig': {},
#    'iso': [''],
#    'layerConfig': {'account': 'wri-rw',
#     'body': {'layers': [{'options': {'cartocss': '#com_008_wfp_alerts_price_spikes{marker-width:3; marker-opacity:1; marker-fill:#FFA500; marker-allow-overlap: true;[orange>=20]{marker-width:15;} [orange>=15][orange<20]{marker-width:12;}[orange>=10][orange<15]{marker-width:7;} [orange>=5][orange<10]{marker-width:4;}[orange<5]{marker-width:3;}}',
#         'cartocss_version': '2.3.0',
#         'sql': 'SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2015'},
#        'type': 'cartodb'}],
#      'maxzoom': 18,
#      'minzoom': 3}},
#    'legendConfig': {'items': [{'color': '#FFA500',
#       'name': 'WFP markets at alert level orange in 2015'}],
#     'type': 'basic'},
#    'name': 'Alerts for Price Spikes - level orange in 2015',
#    'provider': 'cartodb',
#    'slug': 'Alerts-for-Price-Spikes-level-orange-in-2015',
#    'staticImageConfig': {},
#    'updatedAt': '2017-11-02T15:52:42.540Z',
#    'userId': '58f66f96733af88e4f563967'},
#   'id': '1127b16f-e7d4-4214-a3aa-360cba2433eb',
#   'type': 'layer'},
#  {'attributes': {'application': ['rw'],
#    'applicationConfig': {},
#    'dataset': 'e4bdc4c9-96a3-4f0b-8d8f-1742cabd8f80',
#    'default': False,
#    'description': 'This shows the number of markets at alert level red from the WFP, in the year 2015',
#    'env': 'production',
#    'interactionConfig': {},
#    'iso': [''],
#    'layerConfig': {'account': 'wri-rw',
#     'body': {'layers': [{'options': {'cartocss': '#com_008_wfp_alerts_price_spikes{marker-width:3; marker-opacity:1; marker-fill:#FF0000; marker-allow-overlap: true;[red>=20]{marker-width:15;} [red>=15][red<20]{marker-width:12;}[red>=10][red<15]{marker-width:7;} [red>=5][red<10]{marker-width:4;}[red<5]{marker-width:3;}}',
#         'cartocss_version': '2.3.0',
#         'sql': 'SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2015'},
#        'type': 'cartodb'}],
#      'maxzoom': 18,
#      'minzoom': 3}},
#    'legendConfig': {'items': [{'color': '#FF0000',
#       'name': 'WFP markets at alert level red in 2015'}],
#     'type': 'basic'},
#    'name': 'Alerts for Price Spikes - level red in 2015',
#    'provider': 'cartodb',
#    'slug': 'Alerts-for-Price-Spikes-level-red-in-2015',
#    'staticImageConfig': {},
#    'updatedAt': '2017-11-02T15:52:42.783Z',
#    'userId': '58f66f96733af88e4f563967'},
#   'id': 'f6bd6057-2e69-4ce2-9659-b94993236024',
#   'type': 'layer'},
#  {'attributes': {'application': ['rw'],
#    'applicationConfig': {},
#    'dataset': 'e4bdc4c9-96a3-4f0b-8d8f-1742cabd8f80',
#    'default': False,
#    'description': 'This shows the number of markets at alert level white from the WFP, in the year 2015',
#    'env': 'production',
#    'interactionConfig': {},
#    'iso': [''],
#    'layerConfig': {'account': 'wri-rw',
#     'body': {'layers': [{'options': {'cartocss': '#com_008_wfp_alerts_price_spikes{marker-width:3; marker-opacity:1; marker-fill:#FFFFFF; marker-allow-overlap: true;[white>=20]{marker-width:15;} [white>=15][white<20]{marker-width:12;}[white>=10][white<15]{marker-width:7;} [white>=5][white<10]{marker-width:4;}[white<5]{marker-width:3;}}',
#         'cartocss_version': '2.3.0',
#         'sql': 'SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2015'},
#        'type': 'cartodb'}],
#      'maxzoom': 18,
#      'minzoom': 3}},
#    'legendConfig': {'items': [{'color': '#FFFFFF',
#       'name': 'WFP markets at alert level white in 2015'}],
#     'type': 'basic'},
#    'name': 'Alerts for Price Spikes - level white in 2015',
#    'provider': 'cartodb',
#    'slug': 'Alerts-for-Price-Spikes-level-white-in-2015',
#    'staticImageConfig': {},
#    'updatedAt': '2017-11-02T15:52:43.071Z',
#    'userId': '58f66f96733af88e4f563967'},
#   'id': '9b0afc0e-8b4b-4b3f-9170-58cd67f71bcb',
#   'type': 'layer'},
#  {'attributes': {'application': ['rw'],
#    'applicationConfig': {},
#    'dataset': 'e4bdc4c9-96a3-4f0b-8d8f-1742cabd8f80',
#    'default': False,
#    'description': 'This shows the number of markets at alert level yellow from the WFP, in the year 2015',
#    'env': 'production',
#    'interactionConfig': {},
#    'iso': [''],
#    'layerConfig': {'account': 'wri-rw',
#     'body': {'layers': [{'options': {'cartocss': '#com_008_wfp_alerts_price_spikes{marker-width:3; marker-opacity:1; marker-fill:#FFFF00; marker-allow-overlap: true;[yellow>=20]{marker-width:15;} [yellow>=15][yellow<20]{marker-width:12;}[yellow>=10][yellow<15]{marker-width:7;} [yellow>=5][yellow<10]{marker-width:4;}[yellow<5]{marker-width:3;}}',
#         'cartocss_version': '2.3.0',
#         'sql': 'SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2015'},
#        'type': 'cartodb'}],
#      'maxzoom': 18,
#      'minzoom': 3}},
#    'legendConfig': {'items': [{'color': '#FFFF00',
#       'name': 'WFP markets at alert level yellow in 2015'}],
#     'type': 'basic'},
#    'name': 'Alerts for Price Spikes - level yellow in 2015',
#    'provider': 'cartodb',
#    'slug': 'Alerts-for-Price-Spikes-level-yellow-in-2015',
#    'staticImageConfig': {},
#    'updatedAt': '2017-11-02T15:52:43.304Z',
#    'userId': '58f66f96733af88e4f563967'},
#   'id': 'ef664cd8-ed9d-42a2-a788-4f06e1ce9e5e',
#   'type': 'layer'},
#  {'attributes': {'application': ['rw'],
#    'applicationConfig': {},
#    'dataset': 'e4bdc4c9-96a3-4f0b-8d8f-1742cabd8f80',
#    'default': False,
#    'description': 'This shows the number of markets at alert level orange from the WFP, in the year 2016',
#    'env': 'production',
#    'interactionConfig': {},
#    'iso': [''],
#    'layerConfig': {'account': 'wri-rw',
#     'body': {'layers': [{'options': {'cartocss': '#com_008_wfp_alerts_price_spikes{marker-width:3; marker-opacity:1; marker-fill:#FFA500; marker-allow-overlap: true;[orange>=20]{marker-width:15;} [orange>=15][orange<20]{marker-width:12;}[orange>=10][orange<15]{marker-width:7;} [orange>=5][orange<10]{marker-width:4;}[orange<5]{marker-width:3;}}',
#         'cartocss_version': '2.3.0',
#         'sql': 'SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2016'},
#        'type': 'cartodb'}],
#      'maxzoom': 18,
#      'minzoom': 3}},
#    'legendConfig': {'items': [{'color': '#FFA500',
#       'name': 'WFP markets at alert level orange in 2016'}],
#     'type': 'basic'},
#    'name': 'Alerts for Price Spikes - level orange in 2016',
#    'provider': 'cartodb',
#    'slug': 'Alerts-for-Price-Spikes-level-orange-in-2016',
#    'staticImageConfig': {},
#    'updatedAt': '2017-11-02T15:52:43.565Z',
#    'userId': '58f66f96733af88e4f563967'},
#   'id': '6957d9d9-3a44-4892-924a-561579ea2fba',
#   'type': 'layer'},
#  {'attributes': {'application': ['rw'],
#    'applicationConfig': {},
#    'dataset': 'e4bdc4c9-96a3-4f0b-8d8f-1742cabd8f80',
#    'default': False,
#    'description': 'This shows the number of markets at alert level red from the WFP, in the year 2016',
#    'env': 'production',
#    'interactionConfig': {},
#    'iso': [''],
#    'layerConfig': {'account': 'wri-rw',
#     'body': {'layers': [{'options': {'cartocss': '#com_008_wfp_alerts_price_spikes{marker-width:3; marker-opacity:1; marker-fill:#FF0000; marker-allow-overlap: true;[red>=20]{marker-width:15;} [red>=15][red<20]{marker-width:12;}[red>=10][red<15]{marker-width:7;} [red>=5][red<10]{marker-width:4;}[red<5]{marker-width:3;}}',
#         'cartocss_version': '2.3.0',
#         'sql': 'SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2016'},
#        'type': 'cartodb'}],
#      'maxzoom': 18,
#      'minzoom': 3}},
#    'legendConfig': {'items': [{'color': '#FF0000',
#       'name': 'WFP markets at alert level red in 2016'}],
#     'type': 'basic'},
#    'name': 'Alerts for Price Spikes - level red in 2016',
#    'provider': 'cartodb',
#    'slug': 'Alerts-for-Price-Spikes-level-red-in-2016',
#    'staticImageConfig': {},
#    'updatedAt': '2017-11-02T15:52:43.844Z',
#    'userId': '58f66f96733af88e4f563967'},
#   'id': 'a951b744-517d-4f70-a660-290b0392ebf9',
#   'type': 'layer'},
#  {'attributes': {'application': ['rw'],
#    'applicationConfig': {},
#    'dataset': 'e4bdc4c9-96a3-4f0b-8d8f-1742cabd8f80',
#    'default': False,
#    'description': 'This shows the number of markets at alert level white from the WFP, in the year 2016',
#    'env': 'production',
#    'interactionConfig': {},
#    'iso': [''],
#    'layerConfig': {'account': 'wri-rw',
#     'body': {'layers': [{'options': {'cartocss': '#com_008_wfp_alerts_price_spikes{marker-width:3; marker-opacity:1; marker-fill:#FFFFFF; marker-allow-overlap: true;[white>=20]{marker-width:15;} [white>=15][white<20]{marker-width:12;}[white>=10][white<15]{marker-width:7;} [white>=5][white<10]{marker-width:4;}[white<5]{marker-width:3;}}',
#         'cartocss_version': '2.3.0',
#         'sql': 'SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2016'},
#        'type': 'cartodb'}],
#      'maxzoom': 18,
#      'minzoom': 3}},
#    'legendConfig': {'items': [{'color': '#FFFFFF',
#       'name': 'WFP markets at alert level white in 2016'}],
#     'type': 'basic'},
#    'name': 'Alerts for Price Spikes - level white in 2016',
#    'provider': 'cartodb',
#    'slug': 'Alerts-for-Price-Spikes-level-white-in-2016',
#    'staticImageConfig': {},
#    'updatedAt': '2017-11-02T15:52:44.047Z',
#    'userId': '58f66f96733af88e4f563967'},
#   'id': 'd3d7c7d0-81b5-446e-bb22-a5e959c785a0',
#   'type': 'layer'},
#  {'attributes': {'application': ['rw'],
#    'applicationConfig': {},
#    'dataset': 'e4bdc4c9-96a3-4f0b-8d8f-1742cabd8f80',
#    'default': False,
#    'description': 'This shows the number of markets at alert level yellow from the WFP, in the year 2016',
#    'env': 'production',
#    'interactionConfig': {},
#    'iso': [''],
#    'layerConfig': {'account': 'wri-rw',
#     'body': {'layers': [{'options': {'cartocss': '#com_008_wfp_alerts_price_spikes{marker-width:3; marker-opacity:1; marker-fill:#FFFF00; marker-allow-overlap: true;[yellow>=20]{marker-width:15;} [yellow>=15][yellow<20]{marker-width:12;}[yellow>=10][yellow<15]{marker-width:7;} [yellow>=5][yellow<10]{marker-width:4;}[yellow<5]{marker-width:3;}}',
#         'cartocss_version': '2.3.0',
#         'sql': 'SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2016'},
#        'type': 'cartodb'}],
#      'maxzoom': 18,
#      'minzoom': 3}},
#    'legendConfig': {'items': [{'color': '#FFFF00',
#       'name': 'WFP markets at alert level yellow in 2016'}],
#     'type': 'basic'},
#    'name': 'Alerts for Price Spikes - level yellow in 2016',
#    'provider': 'cartodb',
#    'slug': 'Alerts-for-Price-Spikes-level-yellow-in-2016',
#    'staticImageConfig': {},
#    'updatedAt': '2017-11-02T15:52:44.253Z',
#    'userId': '58f66f96733af88e4f563967'},
#   'id': '3132cab0-e34d-4873-beb8-e6f79d7da217',
#   'type': 'layer'},
#  {'attributes': {'application': ['rw'],
#    'applicationConfig': {},
#    'dataset': 'e4bdc4c9-96a3-4f0b-8d8f-1742cabd8f80',
#    'default': False,
#    'description': 'This shows the number of markets at alert level orange from the WFP, in the year 2017',
#    'env': 'production',
#    'interactionConfig': {},
#    'iso': [''],
#    'layerConfig': {'account': 'wri-rw',
#     'body': {'layers': [{'options': {'cartocss': '#com_008_wfp_alerts_price_spikes{marker-width:3; marker-opacity:1; marker-fill:#FFA500; marker-allow-overlap: true;[orange>=20]{marker-width:15;} [orange>=15][orange<20]{marker-width:12;}[orange>=10][orange<15]{marker-width:7;} [orange>=5][orange<10]{marker-width:4;}[orange<5]{marker-width:3;}}',
#         'cartocss_version': '2.3.0',
#         'sql': 'SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2017'},
#        'type': 'cartodb'}],
#      'maxzoom': 18,
#      'minzoom': 3}},
#    'legendConfig': {'items': [{'color': '#FFA500',
#       'name': 'WFP markets at alert level orange in 2017'}],
#     'type': 'basic'},
#    'name': 'Alerts for Price Spikes - level orange in 2017',
#    'provider': 'cartodb',
#    'slug': 'Alerts-for-Price-Spikes-level-orange-in-2017',
#    'staticImageConfig': {},
#    'updatedAt': '2017-11-02T15:52:44.477Z',
#    'userId': '58f66f96733af88e4f563967'},
#   'id': '32c0f0fd-f8b8-41f3-9eb3-3bc79f489dfb',
#   'type': 'layer'},
#  {'attributes': {'application': ['rw'],
#    'applicationConfig': {},
#    'dataset': 'e4bdc4c9-96a3-4f0b-8d8f-1742cabd8f80',
#    'default': False,
#    'description': 'This shows the number of markets at alert level red from the WFP, in the year 2017',
#    'env': 'production',
#    'interactionConfig': {},
#    'iso': [''],
#    'layerConfig': {'account': 'wri-rw',
#     'body': {'layers': [{'options': {'cartocss': '#com_008_wfp_alerts_price_spikes{marker-width:3; marker-opacity:1; marker-fill:#FF0000; marker-allow-overlap: true;[red>=20]{marker-width:15;} [red>=15][red<20]{marker-width:12;}[red>=10][red<15]{marker-width:7;} [red>=5][red<10]{marker-width:4;}[red<5]{marker-width:3;}}',
#         'cartocss_version': '2.3.0',
#         'sql': 'SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2017'},
#        'type': 'cartodb'}],
#      'maxzoom': 18,
#      'minzoom': 3}},
#    'legendConfig': {'items': [{'color': '#FF0000',
#       'name': 'WFP markets at alert level red in 2017'}],
#     'type': 'basic'},
#    'name': 'Alerts for Price Spikes - level red in 2017',
#    'provider': 'cartodb',
#    'slug': 'Alerts-for-Price-Spikes-level-red-in-2017',
#    'staticImageConfig': {},
#    'updatedAt': '2017-11-02T15:52:44.664Z',
#    'userId': '58f66f96733af88e4f563967'},
#   'id': '4df398fb-4356-42e7-90c9-4d5ad060de21',
#   'type': 'layer'},
#  {'attributes': {'application': ['rw'],
#    'applicationConfig': {},
#    'dataset': 'e4bdc4c9-96a3-4f0b-8d8f-1742cabd8f80',
#    'default': False,
#    'description': 'This shows the number of markets at alert level white from the WFP, in the year 2017',
#    'env': 'production',
#    'interactionConfig': {},
#    'iso': [''],
#    'layerConfig': {'account': 'wri-rw',
#     'body': {'layers': [{'options': {'cartocss': '#com_008_wfp_alerts_price_spikes{marker-width:3; marker-opacity:1; marker-fill:#FFFFFF; marker-allow-overlap: true;[white>=20]{marker-width:15;} [white>=15][white<20]{marker-width:12;}[white>=10][white<15]{marker-width:7;} [white>=5][white<10]{marker-width:4;}[white<5]{marker-width:3;}}',
#         'cartocss_version': '2.3.0',
#         'sql': 'SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2017'},
#        'type': 'cartodb'}],
#      'maxzoom': 18,
#      'minzoom': 3}},
#    'legendConfig': {'items': [{'color': '#FFFFFF',
#       'name': 'WFP markets at alert level white in 2017'}],
#     'type': 'basic'},
#    'name': 'Alerts for Price Spikes - level white in 2017',
#    'provider': 'cartodb',
#    'slug': 'Alerts-for-Price-Spikes-level-white-in-2017',
#    'staticImageConfig': {},
#    'updatedAt': '2017-11-02T15:52:44.935Z',
#    'userId': '58f66f96733af88e4f563967'},
#   'id': '0deba330-639f-4bc5-82a3-ccc32f3f0216',
#   'type': 'layer'},
#  {'attributes': {'application': ['rw'],
#    'applicationConfig': {},
#    'dataset': 'e4bdc4c9-96a3-4f0b-8d8f-1742cabd8f80',
#    'default': True,
#    'description': 'This shows the number of markets at alert level yellow from the WFP, in the year 2017',
#    'env': 'production',
#    'interactionConfig': {},
#    'iso': [''],
#    'layerConfig': {'account': 'wri-rw',
#     'body': {'layers': [{'options': {'cartocss': '#com_008_wfp_alerts_price_spikes{marker-width:3; marker-opacity:1; marker-fill:#FFFF00; marker-allow-overlap: true;[yellow>=20]{marker-width:15;} [yellow>=15][yellow<20]{marker-width:12;}[yellow>=10][yellow<15]{marker-width:7;} [yellow>=5][yellow<10]{marker-width:4;}[yellow<5]{marker-width:3;}}',
#         'cartocss_version': '2.3.0',
#         'sql': 'SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2017'},
#        'type': 'cartodb'}],
#      'maxzoom': 18,
#      'minzoom': 3}},
#    'legendConfig': {'items': [{'color': '#FFFF00',
#       'name': 'WFP markets at alert level yellow in 2017'}],
#     'type': 'basic'},
#    'name': 'Alerts for Price Spikes - level yellow in 2017',
#    'provider': 'cartodb',
#    'slug': 'Alerts-for-Price-Spikes-level-yellow-in-2017',
#    'staticImageConfig': {},
#    'updatedAt': '2017-11-02T15:55:46.229Z',
#    'userId': '58f66f96733af88e4f563967'},
#   'id': '83df4f89-ff31-495f-85ba-e0efad83f2fd',
#   'type': 'layer'}]

# %%
# Create list of SQL statements by year and spike level
## print(final_data.columns)
## markets = list(final_data["market"].unique())

table_name = "com_008_wfp_alerts_price_spikes"

years = list(final_data["mp_year"].unique().astype(str))
alert_levels = ["orange", "red", "white", "yellow"]
params_for_SQL = itertools.product(years, alert_levels)

list_of_SQL = [["SELECT * FROM " + table_name + " WHERE mp_year="+params[0], params]   for params in params_for_SQL]
list_of_SQL
# Out:
# [['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=1992',
#   ('1992', 'orange')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=1992',
#   ('1992', 'red')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=1992',
#   ('1992', 'white')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=1992',
#   ('1992', 'yellow')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=1993',
#   ('1993', 'orange')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=1993',
#   ('1993', 'red')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=1993',
#   ('1993', 'white')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=1993',
#   ('1993', 'yellow')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=1994',
#   ('1994', 'orange')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=1994',
#   ('1994', 'red')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=1994',
#   ('1994', 'white')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=1994',
#   ('1994', 'yellow')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=1995',
#   ('1995', 'orange')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=1995',
#   ('1995', 'red')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=1995',
#   ('1995', 'white')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=1995',
#   ('1995', 'yellow')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=1996',
#   ('1996', 'orange')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=1996',
#   ('1996', 'red')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=1996',
#   ('1996', 'white')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=1996',
#   ('1996', 'yellow')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=1997',
#   ('1997', 'orange')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=1997',
#   ('1997', 'red')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=1997',
#   ('1997', 'white')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=1997',
#   ('1997', 'yellow')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=1998',
#   ('1998', 'orange')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=1998',
#   ('1998', 'red')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=1998',
#   ('1998', 'white')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=1998',
#   ('1998', 'yellow')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=1999',
#   ('1999', 'orange')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=1999',
#   ('1999', 'red')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=1999',
#   ('1999', 'white')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=1999',
#   ('1999', 'yellow')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2000',
#   ('2000', 'orange')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2000',
#   ('2000', 'red')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2000',
#   ('2000', 'white')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2000',
#   ('2000', 'yellow')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2001',
#   ('2001', 'orange')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2001',
#   ('2001', 'red')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2001',
#   ('2001', 'white')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2001',
#   ('2001', 'yellow')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2002',
#   ('2002', 'orange')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2002',
#   ('2002', 'red')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2002',
#   ('2002', 'white')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2002',
#   ('2002', 'yellow')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2003',
#   ('2003', 'orange')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2003',
#   ('2003', 'red')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2003',
#   ('2003', 'white')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2003',
#   ('2003', 'yellow')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2004',
#   ('2004', 'orange')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2004',
#   ('2004', 'red')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2004',
#   ('2004', 'white')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2004',
#   ('2004', 'yellow')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2005',
#   ('2005', 'orange')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2005',
#   ('2005', 'red')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2005',
#   ('2005', 'white')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2005',
#   ('2005', 'yellow')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2006',
#   ('2006', 'orange')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2006',
#   ('2006', 'red')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2006',
#   ('2006', 'white')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2006',
#   ('2006', 'yellow')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2007',
#   ('2007', 'orange')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2007',
#   ('2007', 'red')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2007',
#   ('2007', 'white')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2007',
#   ('2007', 'yellow')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2008',
#   ('2008', 'orange')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2008',
#   ('2008', 'red')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2008',
#   ('2008', 'white')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2008',
#   ('2008', 'yellow')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2009',
#   ('2009', 'orange')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2009',
#   ('2009', 'red')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2009',
#   ('2009', 'white')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2009',
#   ('2009', 'yellow')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2010',
#   ('2010', 'orange')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2010',
#   ('2010', 'red')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2010',
#   ('2010', 'white')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2010',
#   ('2010', 'yellow')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2011',
#   ('2011', 'orange')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2011',
#   ('2011', 'red')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2011',
#   ('2011', 'white')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2011',
#   ('2011', 'yellow')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2012',
#   ('2012', 'orange')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2012',
#   ('2012', 'red')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2012',
#   ('2012', 'white')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2012',
#   ('2012', 'yellow')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2013',
#   ('2013', 'orange')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2013',
#   ('2013', 'red')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2013',
#   ('2013', 'white')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2013',
#   ('2013', 'yellow')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2014',
#   ('2014', 'orange')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2014',
#   ('2014', 'red')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2014',
#   ('2014', 'white')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2014',
#   ('2014', 'yellow')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2015',
#   ('2015', 'orange')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2015',
#   ('2015', 'red')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2015',
#   ('2015', 'white')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2015',
#   ('2015', 'yellow')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2016',
#   ('2016', 'orange')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2016',
#   ('2016', 'red')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2016',
#   ('2016', 'white')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2016',
#   ('2016', 'yellow')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2017',
#   ('2017', 'orange')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2017',
#   ('2017', 'red')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2017',
#   ('2017', 'white')],
#  ['SELECT * FROM com_008_wfp_alerts_price_spikes WHERE mp_year=2017',
#   ('2017', 'yellow')]]

# %%
### Create the layer definitions, by year

# Make sure to include the year in the layer_config option
# Write out all the SQL queries, store in an object on the layer config... duplicate
# This among all the 

layer_defs = []

datasetID = "e4bdc4c9-96a3-4f0b-8d8f-1742cabd8f80"

for ix, sql in enumerate(list_of_SQL):
    
    alert_year = sql[1][0]
    alert_level = sql[1][1]
    
    alert_color = {
        "yellow":"#FFFF00",
        "red":"#FF0000",
        "white":"#FFFFFF",
        "orange":"#FFA500"
    }
    
    title = "Alerts for Price Spikes - level "+alert_level+" in "+alert_year
    provider = "cartodb"
    description = "This shows the number of markets at alert level "+alert_level+" from the WFP, in the year "+alert_year+\
    ". The current ALPS value for a food commodity is the number of standard deviations the current price is above the "+\
    "commodity's expected price for that month. Based on this ALPS value, markets are assigned to 1 of 4 situations, where "+\
    "all nominal values are measured in standard deviations from the seasonal mean price: Normal (white), ALPS < 0.25 Stress "+\
    "(yellow), 0.25 < ALPS < 1 Alert (orange), 1 < ALPS < 2 Crisis (red), ALPS >= 2."
    # Is this the dataset or layer slug?
    slug = ''

    # Do I need to set these?
    layer_id = ''
    user_id = ''
    updated_at = ''
    iso_var = ['']

    layer_type = "cartodb" # or mapnik?
    table_name = "com_008_wfp_alerts_price_spikes"

    layer_config = {
      "body": {
        "layers": [
          {
            "options": {
              "cartocss_version": "2.3.0",
              "cartocss": "#"+table_name+\
              "{marker-width:3; marker-opacity:1; marker-fill:"+alert_color[alert_level]+"; marker-allow-overlap: true;"+\
                "["+alert_level+">=20]{marker-width:15;} ["+alert_level+">=15]["+alert_level+"<20]{marker-width:12;}"+\
                "["+alert_level+">=10]["+alert_level+"<15]{marker-width:7;} ["+alert_level+">=5]["+alert_level+"<10]{marker-width:4;}"
                "["+alert_level+"<5]{marker-width:3;}}",
              "sql": sql[0]
            },
            "type": layer_type
          }
        ],
        "minzoom": 3,
        "maxzoom": 18
      },
      "account": "wri-rw"
    }

    legend_config = {
      "items": [
        {
          "color": alert_color[alert_level],
          "name": "WFP markets at alert level "+alert_level+" in "+alert_year
        }
      ],
      "type": "basic"
    }

    interaction_config = {}

    # {'attributes': 
    layer_object = {'application': ['rw'],
       'applicationConfig': {},
       'dataset': datasetID,
       'default': True if ix==(len(list_of_SQL)-1) else False,
       'description': description,
       'interactionConfig': interaction_config,
       'iso': iso_var,
       'layerConfig': layer_config,
       'legendConfig': legend_config,
       'name': title,
       'provider': provider,
       'slug': slug,
       'staticImageConfig': {},
       'updatedAt': updated_at,
       'userId': user_id}
#       'id': layer_id,
#       'type': 'layer'}
    
    layer_defs.append(layer_object)

# %%
num_years_to_display = 4

for layer_def in layer_defs[-(num_years_to_display*4):]:
    layer_update_url = "https://api.resourcewatch.org/v1/dataset/"+str(datasetID)+"/layer"
    #print(layer_update_url)
    #print(layer_def)
    headers = {
        'content-type': "application/json",
        'authorization': "Bearer " + rw_api_token,
    }

    res = req.request("POST", layer_update_url, data=json.dumps(layer_def), headers = headers)
    print(res.text)

# %%
req.get("https://api.resourcewatch.org/v1/dataset/")

# %%
### Experimentation ###

# %%
df[df["Model Std Error of Residuals"] > 10000]

# %%
df["mkt_id"].unique().shape

# %%
wfp_data_with_points_geocoded["mkt_name"].unique().shape

# %%
wfp_data_with_points_geocoded["mkt_name"]

# %%
adm1_names = df["adm1_name"].unique()

# %%
### Matching with GADM files ###

import requests as req

sql = "SELECT * FROM gadm28_adm1"
limit = 9000
sql = sql.format(limit)

rw_id = "098b33df-6871-4e53-a5ff-b56a7d989f9a"
query_base = "https://api.resourcewatch.org/v1/query/{}?sql={}"
query2 = query_base.format(rw_id, sql)

payload = { "application":"rw", "page[size]": 10000000}
res2 = req.get(query2, params=payload)

# %%
import fiona
# import geopandas as gpd
# Use geopandas or fiona to merge ALPS data with a shapefile - try GADM

# %%
file = "/Users/nathansuberi/Desktop/RW_Data/gadm28/gadm28.shp"
adm1_features = {}
with fiona.open(file) as src:
    print(len(src))
    for i, feature in enumerate(src):
        if i%10000==0:
            print(i)
        name = feature["properties"]["NAME_1"] 
        if(name in adm1_names):
            if(name not in adm1_features):
                adm1_features[name] = feature["geometry"]

# %%
adm1_features

# %%
import numpy as np
group_df = wfp_data_with_points_geocoded.groupby(["market", "ALPS", "mp_year"])
print(group_df.groups)
#group_df.groups.keys()

#group_df.groups

# %%
group_df.get_group(('Kabul', 'yellow', 2014))

# %%
pd.options.display.max_rows = 10000
summed_data = group_df.count().pivot_table(values="adm0_id", index=["mp_year", "market"], columns=["ALPS"])
#summed_data = summed_data.reset_index()
summed_data

# %%
keep_cols = ["orange","red","white","yellow","market", "mp_year", "marketLatitude", "marketLongitude"]

# %%
import numpy as np
df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar',
                           'foo', 'bar', 'foo', 'foo'],
                   'B' : ['one', 'one', 'two', 'three',
                          'two', 'two', 'one', 'three'],
                   'C' : np.random.randn(8),
                   'D' : np.random.randn(8)})

grouped = df.groupby(['A', 'B'])
grouped.groups

# %%
red_alerts_fayzabad = df.loc[(df["ALPS"]=="red") & (df["mkt_name"]=="Fayzabad") , ["adm0_name", "adm1_name", "mkt_name", "cm_name", "cur_name", "um_name", "mp_month", "mp_year", "mp_price"]]
print(red_alerts.head(10))

red_alerts_fayzabad.to_csv("/Users/nathansuberi/Desktop/RW_Data/wfp_red_alerts_fayzabad.csv")

# %%
not_represented = [key for key in adm1_names if key not in adm1_features.keys()]
print(len(not_represented)/len(adm1_names))

# %%
import rasterio as rio

# Use rasterio to rasterize the vector, print to a geotiff

# %%
red_alerts_fayzabad = df.loc[(df["ALPS"]=="red") & (df["mkt_name"]=="Fayzabad") , ["adm0_name", "adm1_name", "mkt_name", "cm_name", "cur_name", "um_name", "mp_month", "mp_year", "mp_price"]]
red_alerts_fayzabad.head(10)

# %%
tuples = list(zip(red_alerts_fayzabad["mp_year"], red_alerts_fayzabad["mp_month"]))
multi_index = pd.MultiIndex.from_tuples(tuples, names=["Year", "Month"])
red_alerts_fayzabad.index = multi_index
red_alerts_fayzabad.loc[(2008, 5)]

# %%
multi_index = pd.MultiIndex.from_arrays([red_alerts_fayzabad["mp_year"], red_alerts_fayzabad["mp_month"]], names=["Year", "Month"])
red_alerts_fayzabad.index = multi_index
red_alerts_fayzabad
