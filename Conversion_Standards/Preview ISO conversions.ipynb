# %%
import pandas as pd

# %%
# Isos from: http://www.nationsonline.org/oneworld/country_code_list.htm

isos = pd.read_csv("/Users/nathansuberi/Desktop/Code Portfolio/ResourceWatchCode/Conversion_Standards/iso_conversions.csv", sep="\t", header=None)
isos.columns = ["country", "iso2", "iso3", "num"]
isos
# Out:
#                              country iso2 iso3  num
# 0                        Afghanistan   AF  AFG    4
# 1                      Aland Islands   AX  ALA  248
# 2                            Albania   AL  ALB    8
# 3                            Algeria   DZ  DZA   12
# 4                     American Samoa   AS  ASM   16
# 5                            Andorra   AD  AND   20
# 6                             Angola   AO  AGO   24
# 7                           Anguilla   AI  AIA  660
# 8                         Antarctica   AQ  ATA   10
# 9                Antigua and Barbuda   AG  ATG   28
# 10                         Argentina   AR  ARG   32
# 11                           Armenia   AM  ARM   51
# 12                             Aruba   AW  ABW  533
# 13                         Australia   AU  AUS   36
# 14                           Austria   AT  AUT   40
# 15                        Azerbaijan   AZ  AZE   31
# 16                           Bahamas   BS  BHS   44
# ...
