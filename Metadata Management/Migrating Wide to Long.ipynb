# %%
import cartoframes
import pandas as pd

# %%
user = #'rw-nrt','wri-rw'
# `base_url`s are of the form `http://{username}.carto.com/` for most users
cc = cartoframes.CartoContext(base_url='https://rw-nrt.carto.com/',
                              api_key='')

# %%
# read a table from your CARTO account to a DataFrame
df = cc.read('cli_005_polar_monthly_sea_ice_extent_polylines')
df
# Out:
#                       _uid date  \
# cartodb_id
# 1              arctic_01_0   01
# 2           antarctic_01_0   01
# 3              arctic_02_0   02
# 4           antarctic_02_0   02
# 5              arctic_03_0   03
# 6           antarctic_03_0   03
# 7              arctic_04_0   04
# 8           antarctic_04_0   04
# 9              arctic_05_0   05
# 10          antarctic_05_0   05
# 11             arctic_06_0   06
# 12          antarctic_06_0   06
# 13             arctic_07_0   07
# 14          antarctic_07_0   07
# 15             arctic_08_0   08
# 16          antarctic_08_0   08
# 17             arctic_09_0   09
# 18          antarctic_09_0   09
# 19             arctic_10_0   10
# 20          antarctic_10_0   10
# 21             arctic_11_0   11
# 22          antarctic_11_0   11
# 23             arctic_12_0   12
# 24          antarctic_12_0   12
#
#                                                      the_geom
# cartodb_id
# ...

# %%
df = pd.read_csv('/Users/nathansuberi/Desktop/WRI_Programming/Py_Scripts/Metadata_Management/long_form_ids.csv',header=None,sep='\t',index_col=[0])
df.to_json()
# Out:
# '{"1":{"cit.022":"6b670396-c52c-430c-b5bb-20693da03b60","cit.025":"d38d0d5c-31b1-47f4-9d2e-d8fba4c7d083","cit.028":"35ce2b98-adbb-4873-b334-d7b1cc542de7","cit.029":"10337db6-8321-445e-a60b-28fc1e114f29","cli.007":"3d2ce960-abda-4c9c-bd29-1929e9ca24c9","cli.008":"3a46f6b4-0eec-49d4-bbfc-e2e8f64e6117","com.006":"2e31a1f3-576b-46b4-84f0-3f0cc399f887","com.007":"fe311144-8c0e-4440-b068-6efd057e0f6a","com.009":"c61c364b-1d68-4dd9-ae3d-76c2a0022280","com.010":"52c55378-0484-48c3-92fc-3ee94d21c716","com.015":"c18a38cd-94ff-48cd-818f-6ffb05992abb","com.019":"5e3a3a9f-7380-47c0-ad84-2c193861e106","com.028":"62c988a7-1e4d-418e-87bf-a743e24209e8","ene.012":"d446a52e-c4c1-4e74-ae30-3204620a0365","ene.021":"2c092793-aa3a-4520-959c-ad48165dcae4","ene.022":"d639909f-bcf3-4875-b8c3-35f030b68ed3","ene.028":"c665f519-eef9-4f67-a8bf-7e3e6dc8bfcd","foo.006":"2034a766-6e8a-416d-b8ab-9b7b3e3abb15","foo.015":"4338471d-881a-475f-8bd9-60c4d48b8e12","foo.019":"8bc79a36-d77e-4ee3-b9bc-c77146cfc503","foo.040":"
# ...
