# %%
# Data fetching library
import requests as req
# used below: 'res' stands for 'response'

# File management library
import os

# Data manipulation libraries
import pandas as pd
pd.options.display.max_rows = 1000
pd.options.display.max_columns = 1000

# Data visualization library
## Uses Vega-Lite, which can be easily put in websites
from altair import *

# %% [markdown]
# # Find information about all data on the Resource Watch API, format as DataFrame

# %%
# Base URL for getting dataset metadata from RW API
# Metadata = Data that describes Data 
url = "https://api.resourcewatch.org/v1/dataset?sort=slug,-provider,userId&status=saved&includes=metadata,vocabulary,widget,layer"

# page[size] tells the API the maximum number of results to send back
# There are currently between 200 and 300 datasets on the RW API
payload = { "application":"rw", "page[size]": 1000}

# Request all datasets, and extract the data from the response
res = req.get(url, params=payload)
data = res.json()["data"]

#############################################################

### Convert the json object returned by the API into a pandas DataFrame
# Another option: https://pandas.pydata.org/pandas-docs/stable/generated/pandas.io.json.json_normalize.html
datasets_on_api = {}
for ix, dset in enumerate(data):
    atts = dset["attributes"]
    metadata = atts["metadata"]
    layers = atts["layer"]
    widgets = atts["widget"]
    tags = atts["vocabulary"]
    datasets_on_api[atts["name"]] = {
        "rw_id":dset["id"],
        "table_name":atts["tableName"],
        "provider":atts["provider"],
        "date_updated":atts["updatedAt"],
        "num_metadata":len(metadata),
        "metadata": metadata,
        "num_layers":len(layers),
        "layers": layers,
        "num_widgets":len(widgets),
        "widgets": widgets,
        "num_tags":len(tags),
        "tags":tags
    }

# Create the DataFrame, name the index, and sort by date_updated
# More recently updated datasets at the top
current_datasets_on_api = pd.DataFrame.from_dict(datasets_on_api, orient='index')
current_datasets_on_api.index.rename("Dataset", inplace=True)
current_datasets_on_api.sort_values(by=["date_updated"], inplace=True, ascending = False)

# %%
# View datasets on the Resource Watch API
current_datasets_on_api.head()
# Out:
#                                                                                    rw_id  \
# Dataset
# wat.036 Water Stress Country Ranking                86fff033-dd27-41be-be64-2ec8983b3db1
# cli.017 Glacier Extents                             e2971008-029f-441b-97cd-ee0555728182
# cli.029 Vulnerability to Climate Change Index       fa6443ff-eb95-4d0f-84d2-f0c91682efdf
# cit.003 Air Quality Measurements (PM25)             815eaa09-d626-495e-91e2-523cb07de475
# [delete] soc.063 Anthropogenic Biomes of the World  d8a45b34-4cc0-42f4-957d-e13b37e9182e
#
#                                                                               table_name  \
# Dataset
# wat.036 Water Stress Country Ranking                wat_036_water_stress_country_ranking
# cli.017 Glacier Extents                                           cli_017_glacier_extent
# cli.029 Vulnerability to Climate Change Index                cli_029_vulnerability_to_cc
# cit.003 Air Quality Measurements (PM25)                     %20cit_003a_air_quality_pm25
# [delete] soc.063 Anthropogenic Biomes of the World                         anthro2_a2000
#
#                                                    provider  \
# Dataset
# wat.036 Water Stress Country Ranking                cartodb
# cli.017 Glacier Extents                             cartodb
# cli.029 Vulnerability to Climate Change Index       cartodb
# cit.003 Air Quality Measurements (PM25)             cartodb
# [delete] soc.063 Anthropogenic Biomes of the World  cartodb
#
#                                                                 date_updated  \
# Dataset
# wat.036 Water Stress Country Ranking                2018-01-24T19:33:58.147Z
# cli.017 Glacier Extents                             2018-01-24T19:13:05.952Z
# cli.029 Vulnerability to Climate Change Index       2018-01-24T14:22:57.938Z
# cit.003 Air Quality Measurements (PM25)             2018-01-21T22:16:44.233Z
# [delete] soc.063 Anthropogenic Biomes of the World  2018-01-19T21:27:12.553Z
#
#                                                     num_metadata  \
# Dataset
# wat.036 Water Stress Country Ranking                           1
# cli.017 Glacier Extents                                        1
# cli.029 Vulnerability to Climate Change Index                  2
# cit.003 Air Quality Measurements (PM25)                        1
# [delete] soc.063 Anthropogenic Biomes of the World             2
#
#                                                                                              metadata  \
# Dataset
# wat.036 Water Stress Country Ranking                [{'id': '5a5df56d1db3960012e77a74', 'type': 'm...
# cli.017 Glacier Extents                             [{'id': '59f881e85366950011d78d59', 'type': 'm...
# cli.029 Vulnerability to Climate Change Index       [{'id': '59a427ab7b6c000012baa707', 'type': 'm...
# cit.003 Air Quality Measurements (PM25)             [{'id': '5a3eaec21479c50011fcbd56', 'type': 'm...
# [delete] soc.063 Anthropogenic Biomes of the World  [{'id': '59d7cac1331a2f00111422e7', 'type': 'm...
#
#                                                     num_layers  \
# Dataset
# wat.036 Water Stress Country Ranking                         1
# cli.017 Glacier Extents                                      1
# cli.029 Vulnerability to Climate Change Index                1
# cit.003 Air Quality Measurements (PM25)                      9
# [delete] soc.063 Anthropogenic Biomes of the World           1
#
#                                                                                                layers  \
# Dataset
# wat.036 Water Stress Country Ranking                [{'id': 'c4b5b246-1dcf-492f-8352-278e737ffdf7'...
# cli.017 Glacier Extents                             [{'id': '614b5627-b34b-41aa-8c07-baad3ab649f5'...
# cli.029 Vulnerability to Climate Change Index       [{'id': '07b6e469-d1c4-4ab8-a8a7-cf37f344ae4c'...
# cit.003 Air Quality Measurements (PM25)             [{'id': 'a0cf3282-976c-455c-9352-3cc559dc76c0'...
# [delete] soc.063 Anthropogenic Biomes of the World  [{'id': '60c2f13b-9522-4255-98e2-f373f9b4a1f2'...
#
#                                                     num_widgets  \
# Dataset
# wat.036 Water Stress Country Ranking                          1
# cli.017 Glacier Extents                                       3
# cli.029 Vulnerability to Climate Change Index                 2
# cit.003 Air Quality Measurements (PM25)                       9
# [delete] soc.063 Anthropogenic Biomes of the World            2
#
#                                                                                               widgets  \
# Dataset
# wat.036 Water Stress Country Ranking                [{'id': 'fd6f666b-da36-497f-946d-1af871aa1535'...
# cli.017 Glacier Extents                             [{'id': '0174ee41-b64d-44b5-85be-8c99bf9dc436'...
# cli.029 Vulnerability to Climate Change Index       [{'id': '8c44a854-63e7-4ce6-b864-4858c7394852'...
# cit.003 Air Quality Measurements (PM25)             [{'id': '0871f00b-c48d-46ab-a515-ac550a2f351b'...
# [delete] soc.063 Anthropogenic Biomes of the World  [{'id': 'd81a14b0-8388-4b75-abb0-8149102426f0'...
#
#                                                     num_tags  \
# Dataset
# wat.036 Water Stress Country Ranking                       1
# cli.017 Glacier Extents                                    1
# cli.029 Vulnerability to Climate Change Index              1
# cit.003 Air Quality Measurements (PM25)                    1
# [delete] soc.063 Anthropogenic Biomes of the World         1
#
#                                                                                                  tags
# Dataset
# wat.036 Water Stress Country Ranking                [{'type': 'vocabulary', 'attributes': {'resour...
# cli.017 Glacier Extents                             [{'type': 'vocabulary', 'attributes': {'resour...
# cli.029 Vulnerability to Climate Change Index       [{'type': 'vocabulary', 'attributes': {'resour...
# cit.003 Air Quality Measurements (PM25)             [{'type': 'vocabulary', 'attributes': {'resour...
# [delete] soc.063 Anthropogenic Biomes of the World  [{'type': 'vocabulary', 'attributes': {'resour...

# %%
# View all providers of RW data
current_datasets_on_api["provider"].unique()
# Out:
# array(['cartodb', 'gee', 'featureservice', 'nexgddp', 'csv', 'json',
#        'bigquery', 'rasdaman', 'wms'], dtype=object)

# %%
# Choose only datasets stored on:
## cartodb, csv, gee, featureservice, bigquery, wms, json, rasdaman
provider = "cartodb"
carto_ids = (current_datasets_on_api["provider"]==provider)
carto_data = current_datasets_on_api.loc[carto_ids]

print("Number of Carto datasets: ", carto_data.shape[0])
# Out:
# Number of Carto datasets:  213

# %%
carto_data.head()
# Out:
#                                                                                    rw_id  \
# Dataset
# wat.036 Water Stress Country Ranking                86fff033-dd27-41be-be64-2ec8983b3db1
# cli.017 Glacier Extents                             e2971008-029f-441b-97cd-ee0555728182
# cli.029 Vulnerability to Climate Change Index       fa6443ff-eb95-4d0f-84d2-f0c91682efdf
# cit.003 Air Quality Measurements (PM25)             815eaa09-d626-495e-91e2-523cb07de475
# [delete] soc.063 Anthropogenic Biomes of the World  d8a45b34-4cc0-42f4-957d-e13b37e9182e
#
#                                                                               table_name  \
# Dataset
# wat.036 Water Stress Country Ranking                wat_036_water_stress_country_ranking
# cli.017 Glacier Extents                                           cli_017_glacier_extent
# cli.029 Vulnerability to Climate Change Index                cli_029_vulnerability_to_cc
# cit.003 Air Quality Measurements (PM25)                     %20cit_003a_air_quality_pm25
# [delete] soc.063 Anthropogenic Biomes of the World                         anthro2_a2000
#
#                                                    provider  \
# Dataset
# wat.036 Water Stress Country Ranking                cartodb
# cli.017 Glacier Extents                             cartodb
# cli.029 Vulnerability to Climate Change Index       cartodb
# cit.003 Air Quality Measurements (PM25)             cartodb
# [delete] soc.063 Anthropogenic Biomes of the World  cartodb
#
#                                                                 date_updated  \
# Dataset
# wat.036 Water Stress Country Ranking                2018-01-24T19:33:58.147Z
# cli.017 Glacier Extents                             2018-01-24T19:13:05.952Z
# cli.029 Vulnerability to Climate Change Index       2018-01-24T14:22:57.938Z
# cit.003 Air Quality Measurements (PM25)             2018-01-21T22:16:44.233Z
# [delete] soc.063 Anthropogenic Biomes of the World  2018-01-19T21:27:12.553Z
#
#                                                     num_metadata  \
# Dataset
# wat.036 Water Stress Country Ranking                           1
# cli.017 Glacier Extents                                        1
# cli.029 Vulnerability to Climate Change Index                  2
# cit.003 Air Quality Measurements (PM25)                        1
# [delete] soc.063 Anthropogenic Biomes of the World             2
#
#                                                                                              metadata  \
# Dataset
# wat.036 Water Stress Country Ranking                [{'id': '5a5df56d1db3960012e77a74', 'type': 'm...
# cli.017 Glacier Extents                             [{'id': '59f881e85366950011d78d59', 'type': 'm...
# cli.029 Vulnerability to Climate Change Index       [{'id': '59a427ab7b6c000012baa707', 'type': 'm...
# cit.003 Air Quality Measurements (PM25)             [{'id': '5a3eaec21479c50011fcbd56', 'type': 'm...
# [delete] soc.063 Anthropogenic Biomes of the World  [{'id': '59d7cac1331a2f00111422e7', 'type': 'm...
#
#                                                     num_layers  \
# Dataset
# wat.036 Water Stress Country Ranking                         1
# cli.017 Glacier Extents                                      1
# cli.029 Vulnerability to Climate Change Index                1
# cit.003 Air Quality Measurements (PM25)                      9
# [delete] soc.063 Anthropogenic Biomes of the World           1
#
#                                                                                                layers  \
# Dataset
# wat.036 Water Stress Country Ranking                [{'id': 'c4b5b246-1dcf-492f-8352-278e737ffdf7'...
# cli.017 Glacier Extents                             [{'id': '614b5627-b34b-41aa-8c07-baad3ab649f5'...
# cli.029 Vulnerability to Climate Change Index       [{'id': '07b6e469-d1c4-4ab8-a8a7-cf37f344ae4c'...
# cit.003 Air Quality Measurements (PM25)             [{'id': 'a0cf3282-976c-455c-9352-3cc559dc76c0'...
# [delete] soc.063 Anthropogenic Biomes of the World  [{'id': '60c2f13b-9522-4255-98e2-f373f9b4a1f2'...
#
#                                                     num_widgets  \
# Dataset
# wat.036 Water Stress Country Ranking                          1
# cli.017 Glacier Extents                                       3
# cli.029 Vulnerability to Climate Change Index                 2
# cit.003 Air Quality Measurements (PM25)                       9
# [delete] soc.063 Anthropogenic Biomes of the World            2
#
#                                                                                               widgets  \
# Dataset
# wat.036 Water Stress Country Ranking                [{'id': 'fd6f666b-da36-497f-946d-1af871aa1535'...
# cli.017 Glacier Extents                             [{'id': '0174ee41-b64d-44b5-85be-8c99bf9dc436'...
# cli.029 Vulnerability to Climate Change Index       [{'id': '8c44a854-63e7-4ce6-b864-4858c7394852'...
# cit.003 Air Quality Measurements (PM25)             [{'id': '0871f00b-c48d-46ab-a515-ac550a2f351b'...
# [delete] soc.063 Anthropogenic Biomes of the World  [{'id': 'd81a14b0-8388-4b75-abb0-8149102426f0'...
#
#                                                     num_tags  \
# Dataset
# wat.036 Water Stress Country Ranking                       1
# cli.017 Glacier Extents                                    1
# cli.029 Vulnerability to Climate Change Index              1
# cit.003 Air Quality Measurements (PM25)                    1
# [delete] soc.063 Anthropogenic Biomes of the World         1
#
#                                                                                                  tags
# Dataset
# wat.036 Water Stress Country Ranking                [{'type': 'vocabulary', 'attributes': {'resour...
# cli.017 Glacier Extents                             [{'type': 'vocabulary', 'attributes': {'resour...
# cli.029 Vulnerability to Climate Change Index       [{'type': 'vocabulary', 'attributes': {'resour...
# cit.003 Air Quality Measurements (PM25)             [{'type': 'vocabulary', 'attributes': {'resour...
# [delete] soc.063 Anthropogenic Biomes of the World  [{'type': 'vocabulary', 'attributes': {'resour...

# %%
electricity_datasets = [ds for ds in carto_data.index if 'electricity' in ds.lower()]
electricity_datasets
# Out:
# ['Electricity/Heat Per Capita',
#  'ene.024 Electricity Production, Sources, and Access',
#  'ene.012 Access to Electricity']

# %% [markdown]
# # Import CSV with lat, lon points. These can be used to get information out of the Resource Watch API

# %%
# Store your data in a "data" folder in the same location
# As this notebook
DATA_FOLDER = os.getcwd() + "/data/"

# src: https://developers.google.com/public-data/docs/canonical/countries_csv
country_points = pd.read_csv(DATA_FOLDER + "country_points.tsv", sep="\t")

country_points.head()
# Out:
#   country   latitude  longitude                  name
# 0      AD  42.546245   1.601554               Andorra
# 1      AE  23.424076  53.847818  United Arab Emirates
# 2      AF  33.939110  67.709953           Afghanistan
# 3      AG  17.060816 -61.796428   Antigua and Barbuda
# 4      AI  18.220554 -63.068615              Anguilla

# %% [markdown]
# # Create queries to retrieve specific information from the Resource Watch API

# %%
# Template query string used to query RW datasets
query_base = "https://api.resourcewatch.org/v1/query/{}?sql={}"

# Template SQL string used in RW query
sql = "".join(["SELECT * FROM {} WHERE ",
"ST_Intersects({}, ",
"{}.the_geom)"])

# %%
# Pick a dataset from carto_data
dataset = 'ene.012 Access to Electricity'

# Select the Carto table name, and Resource Watch ID (rw_id)
# The rw_id is needed to query the RW API
table_name = carto_data.loc[dataset, "table_name"]
rw_id = carto_data.loc[dataset, "rw_id"]

def query_api(row):
    # Construct a Well-Known-Text (WKT) Point string
    # WKT formats points: 'POINT(Latitude Longitude)'
    # https://www.drupal.org/node/511370
    point = "ST_GeomFromText('POINT({} {})', 4326)".format(row.longitude, row.latitude)
    
    # Use the templates defined above to create/send a query to RW API
    query_sql = sql.format(table_name, point, table_name)
    query = query_base.format(rw_id, query_sql)    
    res = req.get(query)

    # Try, except: useful in python to catch errors,
    # and provide an alternative action if an error occurs
    try:
        data = res.json()["data"]
        return(data[0]["yr_2014"])
    except:
        return("No matching data found")

country_points["% Urban Population with Electricity Access"] = pd.Series(query_api(row) for row in country_points.itertuples())

# %%
country_points
# Out:
#     country   latitude   longitude  \
# 0        AD  42.546245    1.601554
# 1        AE  23.424076   53.847818
# 2        AF  33.939110   67.709953
# 3        AG  17.060816  -61.796428
# 4        AI  18.220554  -63.068615
# 5        AL  41.153332   20.168331
# 6        AM  40.069099   45.038189
# 7        AN  12.226079  -69.060087
# 8        AO -11.202692   17.873887
# 9        AQ -75.250973   -0.071389
# 10       AR -38.416097  -63.616672
# 11       AS -14.270972 -170.132217
# 12       AT  47.516231   14.550072
# 13       AU -25.274398  133.775136
# 14       AW  12.521110  -69.968338
# 15       AZ  40.143105   47.576927
# 16       BA  43.915886   17.679076
# 17       BB  13.193887  -59.543198
# 18       BD  23.684994   90.356331
# 19       BE  50.503887    4.469936
# 20       BF  12.238333   -1.561593
# 21       BG  42.733883   25.485830
# 22       BH  25.930414   50.637772
# 23       BI  -3.373056   29.918886
# 24       BJ   9.307690    2.315834
# 25       BM  32.321384  -64.757370
# 26       BN   4.535277  114.727669
# 27       BO -16.290154  -63.588653
# 28       BR -14.235004  -51.925280
# 29       BS  25.034280  -77.396280
# 30       BT  27.514162   90.433601
# 31       BV -54.423199    3.413194
# 32       BW -22.328474   24.684866
# 33       BY  53.709807   27.953389
# 34       BZ  17.189877  -88.497650
# 35       CA  56.130366 -106.346771
# 36       CC -12.164165   96.870956
# 37       CD  -4.038333   21.758664
# 38       CF   6.611111   20.939444
# 39       CG  -0.228021   15.827659
# 40       CH  46.818188    8.227512
# 41       CI   7.539989   -5.547080
# 42       CK -21.236736 -159.777671
# 43       CL -35.675147  -71.542969
# 44       CM   7.369722   12.354722
# 45       CN  35.861660  104.195397
# 46       CO   4.570868  -74.297333
# 47       CR   9.748917  -83.753428
# 229      UZ  41.377491   64.585262
# 230      VA  41.902916   12.453389
# 231      VC  12.984305  -61.287228
# 232      VE   6.423750  -66.589730
# 233      VG  18.420695  -64.639968
# 234      VI  18.335765  -64.896335
# 235      VN  14.058324  108.277199
# 236      VU -15.376706  166.959158
# 237      WF -13.768752 -177.156097
# 238      WS -13.759029 -172.104629
# 239      XK  42.602636   20.902977
# 240      YE  15.552727   48.516388
# 241      YT -12.827500   45.166244
# 242      ZA -30.559482   22.937506
# 243      ZM -13.133897   27.849332
# 244      ZW -19.015438   29.154857
#
#                                              name  \
# 0                                         Andorra
# 1                            United Arab Emirates
# 2                                     Afghanistan
# 3                             Antigua and Barbuda
# 4                                        Anguilla
# 5                                         Albania
# 6                                         Armenia
# 7                            Netherlands Antilles
# 8                                          Angola
# 9                                      Antarctica
# 10                                      Argentina
# 11                                 American Samoa
# 12                                        Austria
# 13                                      Australia
# 14                                          Aruba
# 15                                     Azerbaijan
# 16                         Bosnia and Herzegovina
# 17                                       Barbados
# 18                                     Bangladesh
# 19                                        Belgium
# 20                                   Burkina Faso
# 21                                       Bulgaria
# 22                                        Bahrain
# 23                                        Burundi
# 24                                          Benin
# 25                                        Bermuda
# 26                                         Brunei
# 27                                        Bolivia
# 28                                         Brazil
# 29                                        Bahamas
# 30                                         Bhutan
# 31                                  Bouvet Island
# 32                                       Botswana
# 33                                        Belarus
# 34                                         Belize
# 35                                         Canada
# 36                        Cocos [Keeling] Islands
# 37                                    Congo [DRC]
# 38                       Central African Republic
# 39                               Congo [Republic]
# 40                                    Switzerland
# 41                                  Côte d'Ivoire
# 42                                   Cook Islands
# 43                                          Chile
# 44                                       Cameroon
# 45                                          China
# 46                                       Colombia
# 47                                     Costa Rica
# 48                                           Cuba
# 49                                     Cape Verde
# 50                               Christmas Island
# 51                                         Cyprus
# 52                                 Czech Republic
# 53                                        Germany
# 54                                       Djibouti
# 55                                        Denmark
# 56                                       Dominica
# 57                             Dominican Republic
# 58                                        Algeria
# 59                                        Ecuador
# 60                                        Estonia
# 61                                          Egypt
# 62                                 Western Sahara
# 63                                        Eritrea
# 64                                          Spain
# 65                                       Ethiopia
# 66                                        Finland
# 67                                           Fiji
# 68              Falkland Islands [Islas Malvinas]
# 69                                     Micronesia
# 70                                  Faroe Islands
# 71                                         France
# 72                                          Gabon
# 73                                 United Kingdom
# 74                                        Grenada
# 75                                        Georgia
# 76                                  French Guiana
# 77                                       Guernsey
# 78                                          Ghana
# 79                                      Gibraltar
# 80                                      Greenland
# 81                                         Gambia
# 82                                         Guinea
# 83                                     Guadeloupe
# 84                              Equatorial Guinea
# 85                                         Greece
# 86   South Georgia and the South Sandwich Islands
# 87                                      Guatemala
# 88                                           Guam
# 89                                  Guinea-Bissau
# 90                                         Guyana
# 91                                     Gaza Strip
# 92                                      Hong Kong
# 93              Heard Island and McDonald Islands
# 94                                       Honduras
# 95                                        Croatia
# 96                                          Haiti
# 97                                        Hungary
# 98                                      Indonesia
# 99                                        Ireland
# 100                                        Israel
# 101                                   Isle of Man
# 102                                         India
# 103                British Indian Ocean Territory
# 104                                          Iraq
# 105                                          Iran
# 235                                       Vietnam
# 236                                       Vanuatu
# 237                             Wallis and Futuna
# 238                                         Samoa
# 239                                        Kosovo
# 240                                         Yemen
# 241                                       Mayotte
# 242                                  South Africa
# 243                                        Zambia
# 244                                      Zimbabwe
#
#     % Urban Population with Electricity Access
# 0                       No matching data found
# 1                       No matching data found
# 2                       No matching data found
# 3                       No matching data found
# 4                       No matching data found
# 5                       No matching data found
# 6                       No matching data found
# 7                       No matching data found
# 8                       No matching data found
# 9                       No matching data found
# 10                      No matching data found
# 11                      No matching data found
# 12                      No matching data found
# 13                      No matching data found
# 14                      No matching data found
# 15                      No matching data found
# 16                      No matching data found
# 17                      No matching data found
# 18                      No matching data found
# 19                      No matching data found
# 20                      No matching data found
# 21                      No matching data found
# 22                      No matching data found
# 23                      No matching data found
# 24                      No matching data found
# 25                      No matching data found
# 26                      No matching data found
# 27                      No matching data found
# 28                      No matching data found
# 29                      No matching data found
# 30                      No matching data found
# 31                      No matching data found
# 32                      No matching data found
# 33                      No matching data found
# 34                      No matching data found
# 35                      No matching data found
# 36                      No matching data found
# 37                      No matching data found
# 38                      No matching data found
# 39                      No matching data found
# 40                      No matching data found
# 41                      No matching data found
# 42                      No matching data found
# 43                      No matching data found
# 44                      No matching data found
# 45                      No matching data found
# 46                      No matching data found
# 47                      No matching data found
# 48                      No matching data found
# 49                      No matching data found
# 50                      No matching data found
# 51                      No matching data found
# 52                      No matching data found
# 53                      No matching data found
# 54                      No matching data found
# 55                      No matching data found
# 56                      No matching data found
# 57                      No matching data found
# 58                      No matching data found
# 59                      No matching data found
# 60                      No matching data found
# 61                      No matching data found
# 62                      No matching data found
# 63                      No matching data found
# 64                      No matching data found
# 65                      No matching data found
# 66                      No matching data found
# 67                      No matching data found
# 68                      No matching data found
# 69                      No matching data found
# 70                      No matching data found
# 71                      No matching data found
# 72                      No matching data found
# 73                      No matching data found
# 74                      No matching data found
# 75                      No matching data found
# 76                      No matching data found
# 77                      No matching data found
# 78                      No matching data found
# 79                      No matching data found
# 80                      No matching data found
# 81                      No matching data found
# 82                      No matching data found
# 83                      No matching data found
# 84                      No matching data found
# 85                      No matching data found
# 86                      No matching data found
# 87                      No matching data found
# 88                      No matching data found
# 89                      No matching data found
# 90                      No matching data found
# 91                      No matching data found
# 92                      No matching data found
# 93                      No matching data found
# 94                      No matching data found
# 95                      No matching data found
# 96                      No matching data found
# 97                      No matching data found
# 98                      No matching data found
# 99                      No matching data found
# 100                     No matching data found
# 101                     No matching data found
# 102                     No matching data found
# 103                     No matching data found
# 104                     No matching data found
# 105                     No matching data found
# 106                     No matching data found
# 107                     No matching data found
# 108                     No matching data found
# 109                     No matching data found
# 110                     No matching data found
# 111                     No matching data found
# 112                     No matching data found
# 113                     No matching data found
# 114                     No matching data found
# 115                     No matching data found
# 116                     No matching data found
# 117                     No matching data found
# 118                     No matching data found
# 119                     No matching data found
# 120                     No matching data found
# 121                     No matching data found
# 122                     No matching data found
# 123                     No matching data found
# 124                     No matching data found
# 125                     No matching data found
# 126                     No matching data found
# 127                     No matching data found
# 128                     No matching data found
# 129                     No matching data found
# 130                     No matching data found
# 131                     No matching data found
# 132                     No matching data found
# 133                     No matching data found
# 134                     No matching data found
# 135                     No matching data found
# 136                     No matching data found
# 137                     No matching data found
# 138                     No matching data found
# 139                     No matching data found
# 140                     No matching data found
# 141                     No matching data found
# 142                     No matching data found
# 143                     No matching data found
# 144                     No matching data found
# 145                     No matching data found
# 146                     No matching data found
# 147                     No matching data found
# 148                     No matching data found
# 149                     No matching data found
# 150                     No matching data found
# 151                     No matching data found
# 152                     No matching data found
# 153                     No matching data found
# 154                     No matching data found
# 155                     No matching data found
# 156                     No matching data found
# 157                     No matching data found
# 158                     No matching data found
# 159                     No matching data found
# 160                     No matching data found
# 161                     No matching data found
# 162                     No matching data found
# 163                     No matching data found
# 164                     No matching data found
# 165                     No matching data found
# 166                     No matching data found
# 167                     No matching data found
# 168                     No matching data found
# 169                     No matching data found
# 170                     No matching data found
# 171                     No matching data found
# 172                     No matching data found
# 173                     No matching data found
# 174                     No matching data found
# 175                     No matching data found
# 176                     No matching data found
# 177                     No matching data found
# 178                     No matching data found
# 179                     No matching data found
# 180                     No matching data found
# 181                     No matching data found
# 182                     No matching data found
# 183                     No matching data found
# 184                     No matching data found
# 185                     No matching data found
# 186                     No matching data found
# 187                     No matching data found
# 188                     No matching data found
# 189                     No matching data found
# 190                     No matching data found
# 191                     No matching data found
# 192                     No matching data found
# 193                     No matching data found
# 194                     No matching data found
# 195                     No matching data found
# 196                     No matching data found
# 197                     No matching data found
# 198                     No matching data found
# 199                     No matching data found
# 200                     No matching data found
# 201                     No matching data found
# 202                     No matching data found
# 203                     No matching data found
# 204                     No matching data found
# 205                     No matching data found
# 206                     No matching data found
# 207                     No matching data found
# 208                     No matching data found
# 209                     No matching data found
# 210                     No matching data found
# 211                     No matching data found
# 212                     No matching data found
# 213                     No matching data found
# 214                     No matching data found
# 215                     No matching data found
# 216                     No matching data found
# 217                     No matching data found
# 218                     No matching data found
# 219                     No matching data found
# 220                     No matching data found
# 221                     No matching data found
# 222                     No matching data found
# 223                     No matching data found
# 224                     No matching data found
# 225                     No matching data found
# 226                     No matching data found
# 227                     No matching data found
# 228                     No matching data found
# 229                     No matching data found
# 230                     No matching data found
# 231                     No matching data found
# 232                     No matching data found
# 233                     No matching data found
# 234                     No matching data found
# 235                     No matching data found
# 236                     No matching data found
# 237                     No matching data found
# 238                     No matching data found
# 239                     No matching data found
# 240                     No matching data found
# 241                     No matching data found
# 242                     No matching data found
# 243                     No matching data found
# 244                     No matching data found

# %%
# Add a plot to show something about it

Chart(country_points).mark_bar().encode(
x=X("% Urban Population with Electricity Access", bin=Bin()),
y="count(*):Q")
# Out:
# /Users/nathansuberi/.pyenv/versions/3.6.0/lib/python3.6/site-packages/altair/utils/core.py:110: FutureWarning: pandas.lib is deprecated and will be removed in a future version.
# You can access infer_dtype as pandas.api.types.infer_dtype
#   typ = pd.lib.infer_dtype(data)
# <div class="vega-embed" id="74aa738b-2d36-45da-bd01-c41eab8a1a72"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>
