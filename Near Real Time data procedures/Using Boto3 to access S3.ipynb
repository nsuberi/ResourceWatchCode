# %%
import boto3
import pandas as pd
import os
import subprocess
from datetime import datetime

# %% [markdown]
# Boto3 is a Python library which allows you to access Amazon web services, such as Amazon's cloud storage platform, s3: Simple Storage Service.
#
# Two tools Boto3 offers are an s3 client and an s3 resource.
#
# The client is more low-level - it has access to all the info, i.e. when files were last updated and the file size.
#
# The resource is higher-level, and better suited to run summary operations.

# %%
s3_resource = boto3.resource("s3")
s3_client = s3_resource.meta.client

# %% [markdown]
# <b>S3 Client</b>

# %%
s3_client = boto3.client("s3")
bucket_list = s3_client.list_buckets()
buckets = [bucket["Name"] for bucket in bucket_list["Buckets"]]
print("Bucket List:", buckets)
# Out:
# Bucket List: ['Development_Alert', 'WHRC-carbon', 'alerts-test-data', 'aqueduct-projection-backup01', 'aws-logs-838255262149-us-east-1', 'blueraster-wri', 'bmf_s3', 'communityland', 'dg-optimizeraster-test', 'digital-globe-imagery', 'fire-alerts', 'fires', 'forest-watcher-files', 'gfw-data', 'gfw-files', 'gfw-gee-glad-export', 'gfw-maps', 'gfw-notifications', 'gfw-pro', 'gfw-user-fires', 'gfw-user-fires-staging', 'gfw.blog', 'gfw2-data', 'gfw2-data.s3.amazonaws.com', 'gfw2-test', 'gfw2_download', 'gfw2stories', 'gfw_odp', 'grump-tiles', 'ignfi_s3', 'landmarkmap', 'landscape-application', 'lpfn', 'osinfor', 'palm-risk-poc', 'rw-nrt-scripts', 's3hub-2f9587736414f4c637f06a6d0a895309295931e8773a0856d95e337c9', 'suitability-mapper', 'terra-i_grids', 'user-contributed-data', 'whrc2', 'wri', 'wri-api-backups', 'wri-assets', 'wri-aws', 'wri-cdb-backup', 'wri-data', 'wri-dataportal-prod', 'wri-dataportal-stg', 'wri-dataupload', 'wri-forest-atlas', 'wri-groups', 'wri-idn', 'wri-logs', 'wri-maps', 'wri-projects', 'wri-projects-eu', 'wri-protected-areas', 'wri-public-data', 'wri-sites', 'wri-tiles', 'wri-users', 'wri_aws', 'wriforma', 'wriforma-processing']

# %% [markdown]
# Read this article to learn how the Prefix and Delimiter options work when calling list_objects from the s3 client.
#
# Also, look over for the reference to "hooking into the events" to register a change in the client config (in this case, allow to send messages through boto3 without signing what you send with an SSL certificate).
#
# Listing the top level contents of a s3 bucket with Prefix and Delimiter: https://github.com/boto/boto3/issues/134

# %%
objects = s3_client.list_objects(Bucket="wri-public-data",
                                Prefix="resourcewatch/raster/",
                                 # Use Delimiter to only see the folders in resourcewatch/raster/
                                 # To see the actual items, need to remove the Delimiter keyword
                                #Delimiter="/"
                                )

objects["Contents"]
all_raster_objects = [obj for obj in objects["Contents"] if obj["Key"][-1] != "/"]
#all_raster_objects

# %%
# Don't have the rights to create a bucket without location constraint: s3.create_bucket(Bucket="nds_bucket")
# Location constraint incorrect: s3.create_bucket(Bucket='nds_bucket', CreateBucketConfiguration={
#    'LocationConstraint': 'us-east-1c'})
# No CORS setup: s3.get_bucket_cors(Bucket="wri-public-data")
s3_client.get_bucket_acl(Bucket="wri-public-data")
# Out:
# {'Grants': [{'Grantee': {'DisplayName': 'worldresourcesinst',
#     'ID': '2f9587736414f4c637f06a6d0a895309295931e8773a0856d95e337c9fffc42d',
#     'Type': 'CanonicalUser'},
#    'Permission': 'READ'},
#   {'Grantee': {'DisplayName': 'worldresourcesinst',
#     'ID': '2f9587736414f4c637f06a6d0a895309295931e8773a0856d95e337c9fffc42d',
#     'Type': 'CanonicalUser'},
#    'Permission': 'WRITE'},
#   {'Grantee': {'DisplayName': 'worldresourcesinst',
#     'ID': '2f9587736414f4c637f06a6d0a895309295931e8773a0856d95e337c9fffc42d',
#     'Type': 'CanonicalUser'},
#    'Permission': 'READ_ACP'},
#   {'Grantee': {'DisplayName': 'worldresourcesinst',
#     'ID': '2f9587736414f4c637f06a6d0a895309295931e8773a0856d95e337c9fffc42d',
#     'Type': 'CanonicalUser'},
#    'Permission': 'WRITE_ACP'},
#   {'Grantee': {'DisplayName': 'worldresourcesinst',
#     'ID': '2f9587736414f4c637f06a6d0a895309295931e8773a0856d95e337c9fffc42d',
#     'Type': 'CanonicalUser'},
#    'Permission': 'FULL_CONTROL'},
#   {'Grantee': {'Type': 'Group',
#     'URI': 'http://acs.amazonaws.com/groups/global/AllUsers'},
#    'Permission': 'READ'}],
#  'Owner': {'DisplayName': 'worldresourcesinst',
#   'ID': '2f9587736414f4c637f06a6d0a895309295931e8773a0856d95e337c9fffc42d'},
#  'ResponseMetadata': {'HTTPHeaders': {'content-type': 'application/xml',
#    'date': 'Mon, 13 Nov 2017 19:13:10 GMT',
#    'server': 'AmazonS3',
#    'transfer-encoding': 'chunked',
#    'x-amz-id-2': '5ZbX+hL4KZj0w0zRLvpYCRTsLIoghCCzxErbTY6gx1P9237QuhyCzlW7NzxMV5wSy8t91d2Ss1M=',
#    'x-amz-request-id': 'B664A9A085B0E0CA'},
#   'HTTPStatusCode': 200,
#   'HostId': '5ZbX+hL4KZj0w0zRLvpYCRTsLIoghCCzxErbTY6gx1P9237QuhyCzlW7NzxMV5wSy8t91d2Ss1M=',
#   'RequestId': 'B664A9A085B0E0CA',
#   'RetryAttempts': 0}}

# %% [markdown]
# <b>S3 Resource</b>

# %% [markdown]
# Note below the use of "filter" instead of "list_objects". This is a higher level function that returns summary info about s3 assets, such as their bucket and full key name. It does not provide information on the size of the file or the last update.

# %%
s3_resource = boto3.resource("s3")
s3_resource.meta.client.head_bucket(Bucket="wri-public-data")
#for bucket in s3_resource.buckets.all():
#    print(bucket.name)
# The line above and below are the same
#print(s3_client.head_bucket(Bucket="wri-public-data"))

all_raster_objects_summary = []

wri_public_data = s3_resource.Bucket('wri-public-data')
for key in wri_public_data.objects.filter(Prefix="resourcewatch/raster/"):
#for key in bucket.objects.filter(Prefix="resourcewatch/raster/",
#                                Delimiter="/"):
    if(not key.key.endswith("/")):
        all_raster_objects_summary.append(key)

# This has less information than what comes with the s3.resource call
all_raster_objects_summary
# Out:
# [s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/Annual_discharge_anomalies/Dis_an01.tif'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/Annual_discharge_anomalies/Dis_an02.tif'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/Annual_discharge_anomalies/Dis_an03.tif'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/Annual_discharge_anomalies/Dis_an04.tif'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/Annual_discharge_anomalies/Dis_an05.tif'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster
tif'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/foo_030_effect_of_climate_variation/dray_2015.pdf'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/foo_030_effect_of_climate_variation/explanatorycat_Maize.png'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/foo_030_effect_of_climate_variation/explanatorycat_Rice.png'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/foo_030_effect_of_climate_variation/explanatorycat_Soybean.png'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/foo_030_effect_of_climate_variation/explanatorycat_Wheat.png'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/foo_030_effect_of_climate_variation/explanatorycat_maize.tif'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/foo_030_effect_of_climate_variation/explanatorycat_rice.tif'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/foo_030_effect_of_climate_variation/explanatorycat_soybean.tif'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/foo_030_effect_of_climate_variation/explanatorycat_wheat.tif'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/foo_030_effect_of_climate_variation/varcat_Maize.png'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/foo_030_effect_of_climate_variation/varcat_Rice.png'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/foo_030_effect_of_climate_variation/varcat_Soybean.png'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/foo_030_effect_of_climate_variation/varcat_Wheat.png'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/foo_030_effect_of_climate_variation/varcat_maize.tif'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/foo_030_effect_of_climate_variation/varcat_rice.tif'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/foo_030_effect_of_climate_variation/varcat_soybean.tif'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/foo_030_effect_of_climate_variation/varcat_wheat.tif'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/foo_030_effect_of_climate_variation/ycvar_geotiff.zip'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/for_017_potential_vegetation/PotentialVegetation.png'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/for_017_potential_vegetation/Scripts.txt'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/for_017_potential_vegetation/for_014_potential_vegetation.tif'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/for_017_potential_vegetation/for_014_potential_vegetation2.tif'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/for_017_potential_vegetation/potentialvegetation.tif'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/for_017_potential_vegetation/potentialvegetation_METADATA.pdf'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/for_038_nutrient_application/FertilizerCropSpecific_Geotiff.zip'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/for_038_nutrient_application/METADATA_CropSpecificFertilizerandTotalConsumption-2.pdf'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/for_038_nutrient_application/Mueller_etal2012_ClosingYieldGaps_NATURE.pdf'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/for_038_nutrient_application/barley_NitrogenApplication_Rate.png'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/for_038_nutrient_application/barley_NitrogenApplication_Rate.tif'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/for_038_nutrient_application/barley_NitrogenApplication_Total.png'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/for_038_nutrient_application/barley_NitrogenApplication_Total.tif'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/for_038_nutrient_application/barley_NitrogenDataQuality.tif'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/for_038_nutrient_application/barley_PhosphorusApplication_Rate.png'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/for_038_nutrient_application/barley_PhosphorusApplication_Rate.tif'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/for_038_nutrient_application/barley_PhosphorusApplication_Total.png'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/for_038_nutrient_application/barley_PhosphorusApplication_Total.tif'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/for_038_nutrient_application/barley_PhosphorusDataQuality.tif'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/for_038_nutrient_application/barley_PotassiumApplication_Rate.png'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/for_038_nutrient_application/barley_PotassiumApplication_Rate.tif'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/for_038_nutrient_application/barley_PotassiumApplication_Total.png'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/for_038_nutrient_application/barley_PotassiumApplication_Total.tif'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/for_038_nutrient_application/barley_PotassiumDataQuality.tif'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/for_038_nutrient_application/cotton_NitrogenApplication_Rate.png'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/for_038_nutrient_application/cotton_NitrogenApplication_Rate.tif'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/for_038_nutrient_application/cotton_NitrogenApplication_Total.png'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/for_038_nutrient_application/cotton_NitrogenApplication_Total.tif'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/for_038_nutrient_application/cotton_NitrogenDataQuality.tif'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/for_038_nutrient_application/cotton_PhosphorusApplication_Rate.png'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/for_038_nutrient_application/cotton_PhosphorusApplication_Rate.tif'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/for_038_nutrient_application/cotton_PhosphorusApplication_Total.png'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/for_038_nutrient_application/cotton_PhosphorusApplication_Total.tif'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/for_038_nutrient_application/cotton_PhosphorusDataQuality.tif'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/for_038_nutrient_application/cotton_PotassiumApplication_Rate.png'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/for_038_nutrient_application/cotton_PotassiumApplication_Rate.tif'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/for_038_nutrient_application/cotton_PotassiumApplication_Total.png'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/intermediate/for_038_nutrient_application/cotton_PotassiumApplication_Total.tif'),
# ...
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030/PPP1995/.prj'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030/PPP1995/PPP1995sum.prj'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030/PPP1995/ppp1995sum.asc.aux.xml'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030/PPP1995/ppp1995sum.asc.xml'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030/PPP2000/.prj'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030/PPP2000/PPP2000sum.prj'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030/PPP2000/ppp2000sum.asc.aux.xml'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030/PPP2000/ppp2000sum.asc.xml'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030/PPP2005/.prj'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030/PPP2005/PPP2005sum.prj'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030/PPP2005/ppp2005sum.asc.aux.xml'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030/PPP2005/ppp2005sum.asc.xml'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030/mer1990sum.asc'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030/mer1995sum.asc'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030/mer2000sum.asc'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030/mer2005sum.asc'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030/ppp1990sum.asc'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030/ppp1995sum.asc'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030/ppp2000sum.asc'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030/ppp2005sum.asc'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030/soc_030_emily/soc_030_Gridded_GDP_in_MER_and_PPP_1990-2005_merged.tif'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030/soc_030_emily/soc_030_Gridded_GDP_in_MER_and_PPP_1990-2005_merged.tif.aux.xml'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030/soc_030_emily/soc_030_mer_1990_sum.vrt'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030/soc_030_emily/soc_030_mer_1995_sum.vrt'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030/soc_030_emily/soc_030_mer_2000_sum.vrt'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030/soc_030_emily/soc_030_mer_2005_sum.vrt'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030/soc_030_emily/soc_030_ppp_1990_sum.vrt'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030/soc_030_emily/soc_030_ppp_1995_sum.vrt'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030/soc_030_emily/soc_030_ppp_2000_sum.vrt'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030/soc_030_emily/soc_030_ppp_2005_sum.vrt'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030/soc_030_emily/soc_030_sum.vrt'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2/MER1990/.prj'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2/MER1990/MER1990sum.prj'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2/MER1990/mer1990sum.asc.aux.xml'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2/MER1990/mer1990sum.asc.xml'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2/MER1995/.prj'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2/MER1995/MER1995sum.prj'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2/MER1995/mer1995sum.asc.aux.xml'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2/MER1995/mer1995sum.asc.xml'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2/MER2000/.prj'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2/MER2000/MER2000sum.prj'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2/MER2000/mer2000sum.asc.aux.xml'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2/MER2000/mer2000sum.asc.xml'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2/MER2005/.prj'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2/MER2005/MER2005sum.prj'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2/MER2005/mer2005sum.asc.aux.xml'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2/MER2005/mer2005sum.asc.xml'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2/PPP1990/.prj'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2/PPP1990/PPP1990sum.prj'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2/PPP1990/ppp1990sum.asc.aux.xml'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2/PPP1990/ppp1990sum.asc.xml'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2/PPP1995/.prj'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2/PPP1995/PPP1995sum.prj'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2/PPP1995/ppp1995sum.asc.aux.xml'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2/PPP1995/ppp1995sum.asc.xml'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2/PPP2000/.prj'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2/PPP2000/PPP2000sum.prj'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2/PPP2000/ppp2000sum.asc.aux.xml'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2/PPP2000/ppp2000sum.asc.xml'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2/PPP2005/.prj'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2/PPP2005/PPP2005sum.prj'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2/PPP2005/ppp2005sum.asc.aux.xml'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2/PPP2005/ppp2005sum.asc.xml'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2/mer1990sum.asc'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2/mer1995sum.asc'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2/mer2000sum.asc'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2/mer2005sum.asc'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2/ppp1990sum.asc'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2/ppp1995sum.asc'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2/ppp2000sum.asc'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2/ppp2005sum.asc'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2/soc_030_composite.tif'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2/soc_030_composite.vrt'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2/soc_030_mer_1990_sum.tif'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2/soc_030_mer_1990_sum.vrt'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2/soc_030_mer_1995_sum.tif'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/test/soc_030_2
),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/wat_015_erosion_risk/wat_015_erosion_risk.tif.ovr'),
#  s3.ObjectSummary(bucket_name='wri-public-data', key='resourcewatch/raster/wat_015_erosion_risk/wat_015_erosion_risk.tif.vat.dbf')]

# %% [markdown]
# <b>Calculate raster statistics with all rasters in s3 w/ Bucket=wri-public-data, Prefix=resourcewatch/raster/</b>

# %%
# This all_raster_objects comes from the client, so has file size and last update included
s3_files = pd.DataFrame(all_raster_objects)

# Big files take a long time, so this selects only files less than a million bytes (~1 mb)
s3_files_small = s3_files[s3_files["Size"] < 1000000]
print(s3_files.shape)
print(s3_files_small.shape)
# Out:
# (615, 6)
# (266, 6)

# %% [markdown]
# Can run GDAL using subprocess.check_output() to use command line tools (instead of using the ! symbol, with the added benefit of returning the output to the Jupyter notebook directly)

# %%
# In case this takes a long time, you can store the results in this gdalinfo list
# gdalinfo = []

def run_gdalinfo_remotely(start_time, num_files, key, count):
    try:
        start = datetime.now()

        s3_loc = "/vsicurl/https://wri-public-data.s3.amazonaws.com/" + key
        res = subprocess.check_output(["gdalinfo", s3_loc, "-stats"])

        # Show how far in we are...
        print("Finished", count, "out of", num_files)
        print("Progress:", count/float(num_files))
        # This would help you to investigate the outputs on some entries, 
        # even if you have to keyboard interrupt before the entire apply function finishes
        # gdalinfo.append(res)

        end = datetime.now()
        print("Time for current file:", end-start)
        print("Total time:", end-start_time, "\n")
        return(res)
    except:
        return("Not a gdalinfo compatible file")

# Initializers
# print("Total number of files to try:", s3_files_small.shape[0])
# num_files = s3_files_small.shape[0]
# s3_files_small["count"] = list(range(1, num_files+1))

print("Total number of files to try:", s3_files.shape[0])
num_files = s3_files.shape[0]
s3_files["count"] = list(range(1, num_files+1))
start_time = datetime.now()

s3_files["gdalinfo"] = s3_files.apply(lambda row: run_gdalinfo_remotely(start_time, 
                                                                        num_files, 
                                                                        row["Key"],
                                                                        row["count"],), axis=1)
# Out:
# Total number of files to try: 615
# Finished 1 out of 615
# Progress: 0.0016260162601626016
# Time for current file: 0:00:04.804231
# Total time: 0:00:04.807482
#
# Finished 2 out of 615
# Progress: 0.0032520325203252032
# Time for current file: 0:00:04.187172
# Total time: 0:00:08.996067
#
# Finished 3 out of 615
# Progress: 0.004878048780487805
# Time for current file: 0:00:04.963413
# Total time: 0:00:13.960682
#
# Finished 4 out of 615
# Progress: 0.0065040650406504065
# Time for current file: 0:00:04.601072
# Total time: 0:00:18.563683
#
# Finished 5 out of 615
# Progress: 0.008130081300813009
# Time for current file: 0:00:04.182318
# Total time: 0:00:22.747569
#
# Finished 6 out of 615
# Progress: 0.00975609756097561
# Time for current file: 0:00:04.470400
# Total time: 0:00:27.219419
#
# Finished 7 out of 615
# Progress: 0.011382113821138212
# Time for current file: 0:00:05.575513
# Total time: 0:00:32.795942
#
# Finished 8 out of 615
# Progress: 0.013008130081300813
# Time for current file: 0:00:04.621763
# Total time: 0:00:37.418762
#
# Finished 9 out of 615
# Progress: 0.014634146341463415
# Time for current file: 0:00:05.074483
# Total time: 0:00:42.494490
#
# Finished 10 out of 615
# Progress: 0.016260162601626018
# Time for current file: 0:00:04.396968
# Total time: 0:00:46.892958
#
# Finished 11 out of 615
# Progress: 0.01788617886178862
# Time for current file: 0:00:04.117033
# Total time: 0:00:51.011285
#
# Finished 12 out of 615
# Progress: 0.01951219512195122
driver: GTiff/GeoTIFF\nFiles: /vsicurl/https://wri-public-data.s3.amazonaws.com/resourcewatch/raster/cit_014/GHS_1975_1k.tif\nSize is 35497, 15236\nCoordinate System is:\nPROJCS["World_Mollweide",\n    GEOGCS["GCS_WGS_1984",\n        DATUM["D_WGS_1984",\n            SPHEROID["WGS_1984",6378137.0,298.257223563]],\n        PRIMEM["Greenwich",0.0],\n        UNIT["Degree",0.017453292519943295]],\n    PROJECTION["Mollweide"],\n    PARAMETER["False_Easting",0.0],\n    PARAMETER["False_Northing",0.0],\n    PARAMETER["Central_Meridian",0.0],\n    UNIT["Meter",1.0]]\nOrigin = (-17619594.547443531453609,8751029.461868489161134)\nPixel Size = (1000.000000000000000,-1000.000000000000000)\nMetadata:\n  AREA_OR_POINT=Area\n  DataType=Generic\nImage Structure Metadata:\n  COMPRESSION=LZW\n  INTERLEAVE=BAND\nCorner Coordinates:\nUpper Left  (-17619594.547, 8751029.462) \nLower Left  (-17619594.547,-6484970.538) \nUpper Right (17877405.453, 8751029.462) \nLower Right (17877405.453,-6484970.538) \nCenter      (  128905.453, 1133029.462) (  1d17\'47.25"E,  9d10\'43.07"N)\nBand 1 Block=512x512 Type=Float32, ColorInterp=Gray\n  Minimum=0.000, Maximum=1.000, Mean=0.001, StdDev=0.017\n  NoData Value=-3.4028234663852886e+38\n  Metadata:\n    STATISTICS_MAXIMUM=1\n    STATISTICS_MEAN=0.00067647525680008\n    STATISTICS_MINIMUM=0\n    STATISTICS_STDDEV=0.016860923187342\n'

# %%
# Join the gdalinfo results from the smaller dataset back to your dataframe of all files on s3
s3_files = s3_files.join(s3_files_small["gdalinfo"])
# Out:
#                                    ETag  \
# 38   "a4a4284cca59054d28c2b45f0ae43829"
# 39   "6198e88c1cb3d16f512dd53ef1009ca7"
# 40   "7d5040da88038078cf97664d74b4a98a"
# 42   "64804a5fe798c782e746eccb74a212e8"
# 65   "7589bacfbaa4861ca650f2181f5f32a1"
# 66   "a2fc744a156d93ea0a494f9a2057689b"
# 67   "c923585547f9e6b631460adde0cf2299"
# 68   "0fd7a83fb3228f65ec21e05ed6d1c485"
# 69   "db71d5876f19c90e65c6bd7af72ba487"
# 70   "a4c32553f06f722778ad3610807fd187"
# 84   "00dcef85e2cf645c39c2aa576373d2e7"
# 85   "44aa15fc34c8e34c843e8971d7bac946"
# 86   "567ac434f6a4a44f03012c2461ef17f6"
# 87   "fa7d7c23f547cc399ab12691f91888c6"
# 120  "c8cfe509f1ca6746ab65c412fcf4cc41"
# 213  "76deed33a034949ba3e73fb1a8fe9124"
# 215  "5775d30d21ad2212638cb379bbb3a372"
# 218  "e8aa076819bfb026ed482123956c4636"
# 221  "41fb7f85dec8e007530e51fbf96a620e"
# 222  "c9cb60a93210693b42baa1eb96fe4107"
# 223  "dcd809bc024258073b4aa2b340447fbc"
# 224  "30b970e331f6f6949b0405d0a7d84769"
# 225  "990090117d23ffcbb083702d7b1c6972"
# 226  "8941fded716fb93eeb11e9f1329d5d5e"
# 228  "cc123ba9605136781ac5c77487abb11f"
# 229  "1f1ffc5a004bda8335d072e641a47ea6"
# 230  "a08ce2c2da412cbc18d71b8ae1d0d37f"
# 231  "b7be7d047489415c9eccd065a890496d"
# 232  "bdf374e4ef9312844d36269f2a56220c"
# 233  "8e98999c0375be241ec9dc07d9c4f533"
# ..                                  ...
# 574  "73d5cf5cb6085546e717cf412344cfce"
# 575  "6f38100b5b4e10bebadf23c41a7eaf61"
# 576  "160e4a3317a00bb95b717acc09b16b29"
# 577  "91215561efdd912f6aa141a449140bd5"
# 578  "f40ef4d55f3e3ab7a7f5da95401b7827"
# 579  "e60d4a04d3812d1f32f12aa1be04541b"
# 580  "7bec97de0cfa38907baaf54b55cdd070"
# 581  "bb7d4e8598852400f68fef88bd683312"
# 582  "2499f85ae658c1230f24bfc7c3fad8bd"
# 583  "af310c3815dab710d7d186a27d127cbb"
# 584  "d3302e6000acefc81b837053a3a41e7a"
# 585  "4d64a907e9fd233297ec69c5fca0c55d"
# 586  "ef76c5e35f9b4e01daa9e24f8b62bf95"
# 587  "d3e0e0cad2f35466a30838baaae19109"
# 588  "8fa6f856695fd8040f0e4f1901703849"
# 589  "6d1e78cbca8084d025a130fe500fb7cd"
# 590  "f4790e24dd1c38a1aca033c18451e77c"
# 591  "eea1ecf5fd2a2179a474edbcd250ac59"
# 592  "3c10c84859576106ee54518002cf83dc"
# 593  "f6691fb5bf2ee2314837de0671834ee5"
# 594  "73d5cf5cb6085546e717cf412344cfce"
# 595  "d52cd5d1bc672a4c38568597f2983ec8"
# 601  "f1f169ead2ac7f50783808e8f6fc607b"
# 604  "ca6c5074b4867bc57e0b87b06eb8c7bd"
# 606  "36802cba8428a685d256391ca225de24"
# 609  "6296267acfc9d995913435da8fe0d722"
# 610  "ae3b3df9970b49b6523e608759bc957d"
# 611  "7e25879f87ada47f0903f377820db744"
# 612  "5c15e49293da2325a4b398d72bce69e3"
# 614  "6c105aa0c0ae62a821900c88869cef4f"
#
#                                                    Key  \
# 38   resourcewatch/raster/Annual_discharge_anomalie...
# 39   resourcewatch/raster/bio_008_cumulative_climat...
# 40   resourcewatch/raster/bio_008_cumulative_climat...
# 42   resourcewatch/raster/bio_008_cumulative_climat...
# 65   resourcewatch/raster/bio_035_coral_reef_future...
# 66   resourcewatch/raster/bio_035_coral_reef_future...
# 67   resourcewatch/raster/bio_035_coral_reef_future...
# 68   resourcewatch/raster/bio_035_coral_reef_future...
# 69   resourcewatch/raster/bio_035_coral_reef_future...
# 70   resourcewatch/raster/cit_014/GHSL_data_access_...
# 84   resourcewatch/raster/cli_005_1_antarctic_sea_i...
# 85   resourcewatch/raster/cli_005_1_antarctic_sea_i...
# 86   resourcewatch/raster/cli_005_2_arctic_sea_ice_...
# 87   resourcewatch/raster/cli_005_2_arctic_sea_ice_...
# 120  resourcewatch/raster/dis_006_disaster_and_emer...
# 213  resourcewatch/raster/for_014_potential_vegetat...
# 215  resourcewatch/raster/intermediate/com_012_glob...
# 218  resourcewatch/raster/intermediate/com_012_glob...
# 221  resourcewatch/raster/intermediate/foo_010_crop...
# 222  resourcewatch/raster/intermediate/foo_010_crop...
# 223  resourcewatch/raster/intermediate/foo_010_crop...
# 224  resourcewatch/raster/intermediate/foo_010_crop...
# 225  resourcewatch/raster/intermediate/foo_010_crop...
# 226  resourcewatch/raster/intermediate/foo_010_crop...
# 228  resourcewatch/raster/intermediate/foo_010_crop...
# 229  resourcewatch/raster/intermediate/foo_010_crop...
# 230  resourcewatch/raster/intermediate/foo_010_crop...
# 231  resourcewatch/raster/intermediate/foo_010_crop...
# 232  resourcewatch/raster/intermediate/foo_010_crop...
# 233  resourcewatch/raster/intermediate/foo_010_crop...
# ..                                                 ...
# 574  resourcewatch/raster/test/soc_030_2/soc_030_su...
# 575  resourcewatch/raster/test/soc_030_joy/soc_030_...
# 576  resourcewatch/raster/test/soc_030_liz/mer1990s...
# 577  resourcewatch/raster/test/soc_030_liz/mer1995s...
# 578  resourcewatch/raster/test/soc_030_liz/mer2000s...
# 579  resourcewatch/raster/test/soc_030_liz/mer2005s...
# 580  resourcewatch/raster/test/soc_030_liz/ppp1990s...
# 581  resourcewatch/raster/test/soc_030_liz/ppp1995s...
# 582  resourcewatch/raster/test/soc_030_liz/ppp2000s...
# 583  resourcewatch/raster/test/soc_030_liz/ppp2005s...
# 584  resourcewatch/raster/test/soc_030_liz/raster_t...
# 585  resourcewatch/raster/test/soc_030_liz/soc_030_...
# 586  resourcewatch/raster/test/soc_030_liz/soc_030_...
# 587  resourcewatch/raster/test/soc_030_liz/soc_030_...
# 588  resourcewatch/raster/test/soc_030_liz/soc_030_...
# 589  resourcewatch/raster/test/soc_030_liz/soc_030_...
# 590  resourcewatch/raster/test/soc_030_liz/soc_030_...
# 591  resourcewatch/raster/test/soc_030_liz/soc_030_...
# 592  resourcewatch/raster/test/soc_030_liz/soc_030_...
# 593  resourcewatch/raster/test/soc_030_liz/soc_030_...
# 594  resourcewatch/raster/test/soc_030_liz/soc_030_...
# 595  resourcewatch/raster/wat.018/wat_018_GRACE_aqu...
# 601  resourcewatch/raster/wat_011_global_riverine_N...
# 604  resourcewatch/raster/wat_011_global_riverine_N...
# 606  resourcewatch/raster/wat_011_global_riverine_N...
# 609  resourcewatch/raster/wat_011_global_riverine_N...
# 610  resourcewatch/raster/wat_015_erosion_risk/tif1...
# 611  resourcewatch/raster/wat_015_erosion_risk/wat_...
# 612  resourcewatch/raster/wat_015_erosion_risk/wat_...
# 614  resourcewatch/raster/wat_015_erosion_risk/wat_...
#
#                  LastModified  \
# 38  2017-11-01 18:50:11+00:00
# 39  2017-10-06 21:08:16+00:00
# 40  2017-10-06 21:08:17+00:00
# 42  2017-10-06 21:08:17+00:00
# 65  2017-10-04 17:25:37+00:00
# 66  2017-10-04 17:55:35+00:00
# 67  2017-10-04 17:26:02+00:00
# 68  2017-10-04 17:55:35+00:00
# 69  2017-10-04 18:58:05+00:00
# 70  2017-11-07 23:56:13+00:00
# 84  2017-09-24 00:02:34+00:00
# 85  2017-09-24 00:02:16+00:00
# 86  2017-09-24 00:01:34+00:00
# 87  2017-09-24 00:01:17+00:00
# 120 2017-10-27 20:37:11+00:00
# 213 2017-11-07 23:08:56+00:00
# 120  {'DisplayName': 'worldresourcesinst', 'ID': '2...     656     STANDARD
# 213  {'DisplayName': 'worldresourcesinst', 'ID': '2...  849740     STANDARD
# 215  {'DisplayName': 'worldresourcesinst', 'ID': '2...    1341     STANDARD
# 218  {'DisplayName': 'worldresourcesinst', 'ID': '2...    2323     STANDARD
# 221  {'DisplayName': 'worldresourcesinst', 'ID': '2...  259966     STANDARD
# 222  {'DisplayName': 'worldresourcesinst', 'ID': '2...  564770     STANDARD
# 223  {'DisplayName': 'worldresourcesinst', 'ID': '2...  568430     STANDARD
# 224  {'DisplayName': 'worldresourcesinst', 'ID': '2...  490938     STANDARD
# 225  {'DisplayName': 'worldresourcesinst', 'ID': '2...  497415     STANDARD
# 226  {'DisplayName': 'worldresourcesinst', 'ID': '2...  309570     STANDARD
# 228  {'DisplayName': 'worldresourcesinst', 'ID': '2...  255701     STANDARD
# 229  {'DisplayName': 'worldresourcesinst', 'ID': '2...  422673     STANDARD
# 230  {'DisplayName': 'worldresourcesinst', 'ID': '2...  422798     STANDARD
# 231  {'DisplayName': 'worldresourcesinst', 'ID': '2...  425685     STANDARD
# 232  {'DisplayName': 'worldresourcesinst', 'ID': '2...  441508     STANDARD
# 233  {'DisplayName': 'worldresourcesinst', 'ID': '2...  284494     STANDARD
# ..                                                 ...     ...          ...
# 574  {'DisplayName': 'worldresourcesinst', 'ID': '2...    4175     STANDARD
# 575  {'DisplayName': 'worldresourcesinst', 'ID': '2...  712488     STANDARD
# 576  {'DisplayName': 'worldresourcesinst', 'ID': '2...  389166     STANDARD
# 577  {'DisplayName': 'worldresourcesinst', 'ID': '2...  385948     STANDARD
# 578  {'DisplayName': 'worldresourcesinst', 'ID': '2...  385341     STANDARD
# 579  {'DisplayName': 'worldresourcesinst', 'ID': '2...  382601     STANDARD
# 580  {'DisplayName': 'worldresourcesinst', 'ID': '2...  382941     STANDARD
# 581  {'DisplayName': 'worldresourcesinst', 'ID': '2...  379521     STANDARD
# 582  {'DisplayName': 'worldresourcesinst', 'ID': '2...  378949     STANDARD
# 583  {'DisplayName': 'worldresourcesinst', 'ID': '2...  377507     STANDARD
# 584  {'DisplayName': 'worldresourcesinst', 'ID': '2...  620076     STANDARD
# 585  {'DisplayName': 'worldresourcesinst', 'ID': '2...    1812     STANDARD
# 586  {'DisplayName': 'worldresourcesinst', 'ID': '2...    1812     STANDARD
# 587  {'DisplayName': 'worldresourcesinst', 'ID': '2...    1812     STANDARD
# 588  {'DisplayName': 'worldresourcesinst', 'ID': '2...    1812     STANDARD
# 589  {'DisplayName': 'worldresourcesinst', 'ID': '2...    1812     STANDARD
# 590  {'DisplayName': 'worldresourcesinst', 'ID': '2...    1812     STANDARD
# 591  {'DisplayName': 'worldresourcesinst', 'ID': '2...    1812     STANDARD
# 592  {'DisplayName': 'worldresourcesinst', 'ID': '2...    1812     STANDARD
# 593  {'DisplayName': 'worldresourcesinst', 'ID': '2...  632300     STANDARD
# 594  {'DisplayName': 'worldresourcesinst', 'ID': '2...    4175     STANDARD
# 595  {'DisplayName': 'worldresourcesinst', 'ID': '2...  780744     STANDARD
# 601  {'DisplayName': 'worldresourcesinst', 'ID': '2...  446809     STANDARD
# 604  {'DisplayName': 'worldresourcesinst', 'ID': '2...  418895     STANDARD
# 606  {'DisplayName': 'worldresourcesinst', 'ID': '2...  434171     STANDARD
# 609  {'DisplayName': 'worldresourcesinst', 'ID': '2...  418557     STANDARD
# 610  {'DisplayName': 'worldresourcesinst', 'ID': '2...       5     STANDARD
# 611  {'DisplayName': 'worldresourcesinst', 'ID': '2...      97     STANDARD
# 612  {'DisplayName': 'worldresourcesinst', 'ID': '2...    1510     STANDARD
# 614  {'DisplayName': 'worldresourcesinst', 'ID': '2...     203     STANDARD
#
#                                               gdalinfo
# 38                      Not a gdalinfo compatible file
# 39   b"Driver: AAIGrid/Arc/Info ASCII Grid\nFiles: ...
# 40   b'Driver: GTiff/GeoTIFF\nFiles: /vsicurl/https...
# 42   b'Driver: GTiff/GeoTIFF\nFiles: /vsicurl/https...
# 65   b'Driver: GTiff/GeoTIFF\nFiles: /vsicurl/https...
# 66   b'Driver: GTiff/GeoTIFF\nFiles: /vsicurl/https...
# 67   b'Driver: GTiff/GeoTIFF\nFiles: /vsicurl/https...
# 68   b'Driver: GTiff/GeoTIFF\nFiles: /vsicurl/https...
# 69   b'Driver: GTiff/GeoTIFF\nFiles: /vsicurl/https...
# 70                      Not a gdalinfo compatible file
# 84   b'Driver: GTiff/GeoTIFF\nFiles: /vsicurl/https...
# 85   b'Driver: GTiff/GeoTIFF\nFiles: /vsicurl/https...
# 86   b'Driver: GTiff/GeoTIFF\nFiles: /vsicurl/https...
# 87   b'Driver: GTiff/GeoTIFF\nFiles: /vsicurl/https...
# 120                     Not a gdalinfo compatible file
# 213  b'Driver: GTiff/GeoTIFF\nFiles: /vsicurl/https...
# 215                     Not a gdalinfo compatible file
# 218                     Not a gdalinfo compatible file
# 221  b"Driver: PNG/Portable Network Graphics\nFiles...
# 222  b"Driver: PNG/Portable Network Graphics\nFiles...
# 223  b"Driver: PNG/Portable Network Graphics\nFiles...
# 224  b"Driver: PNG/Portable Network Graphics\nFiles...
# 225  b"Driver: PNG/Portable Network Graphics\nFiles...
# 226  b"Driver: PNG/Portable Network Graphics\nFiles...
# 228  b"Driver: PNG/Portable Network Graphics\nFiles...
# 229  b"Driver: PNG/Portable Network Graphics\nFiles...
# 230  b"Driver: PNG/Portable Network Graphics\nFiles...
# 231  b"Driver: PNG/Portable Network Graphics\nFiles...
# 232  b"Driver: PNG/Portable Network Graphics\nFiles...
# 233  b"Driver: PNG/Portable Network Graphics\nFiles...
# ..                                                 ...
# 574  b'Driver: VRT/Virtual Raster\nFiles: /vsicurl/...
# 575  b'Driver: GTiff/GeoTIFF\nFiles: /vsicurl/https...
# 576  b"Driver: AAIGrid/Arc/Info ASCII Grid\nFiles: ...
# 577  b"Driver: AAIGrid/Arc/Info ASCII Grid\nFiles: ...
# 578  b"Driver: AAIGrid/Arc/Info ASCII Grid\nFiles: ...
# 579  b"Driver: AAIGrid/Arc/Info ASCII Grid\nFiles: ...
# 580  b"Driver: AAIGrid/Arc/Info ASCII Grid\nFiles: ...
# 581  b"Driver: AAIGrid/Arc/Info ASCII Grid\nFiles: ...
# 582  b"Driver: AAIGrid/Arc/Info ASCII Grid\nFiles: ...
# 583  b"Driver: AAIGrid/Arc/Info ASCII Grid\nFiles: ...
# 584                     Not a gdalinfo compatible file
# 585  b'Driver: VRT/Virtual Raster\nFiles: /vsicurl/...
# 586  b'Driver: VRT/Virtual Raster\nFiles: /vsicurl/...
# 587  b'Driver: VRT/Virtual Raster\nFiles: /vsicurl/...
# 588  b'Driver: VRT/Virtual Raster\nFiles: /vsicurl/...
# 589  b'Driver: VRT/Virtual Raster\nFiles: /vsicurl/...
# 590  b'Driver: VRT/Virtual Raster\nFiles: /vsicurl/...
# 591  b'Driver: VRT/Virtual Raster\nFiles: /vsicurl/...
# 592  b'Driver: VRT/Virtual Raster\nFiles: /vsicurl/...
# 593  b'Driver: GTiff/GeoTIFF\nFiles: /vsicurl/https...
# 594  b'Driver: VRT/Virtual Raster\nFiles: /vsicurl/...
# 595                     Not a gdalinfo compatible file
# 601  b'Driver: GTiff/GeoTIFF\nFiles: /vsicurl/https...
# 604  b'Driver: GTiff/GeoTIFF\nFiles: /vsicurl/https...
# 606  b'Driver: GTiff/GeoTIFF\nFiles: /vsicurl/https...
# 609  b'Driver: GTiff/GeoTIFF\nFiles: /vsicurl/https...
# 610                     Not a gdalinfo compatible file
# 611                     Not a gdalinfo compatible file
# 612                     Not a gdalinfo compatible file
# 614                     Not a gdalinfo compatible file
#
# [266 rows x 7 columns]

# %%
# Extract information from the gdalinfo command
# How long does this take on local computer? How long on a cloud instance?

# %%
sample_gdalinfo = s3_files["gdalinfo"].loc[570]
#print(sample_gdalinfo)

def extract_raster_statistics(gdalinfo):
    try:
        statistics = str(gdalinfo).split("\\n")[-5:-1]
        stats = [stat.strip() for stat in statistics]
        stats = [stat.split("=") for stat in stats]
        stats_dict = dict(stats)
        #stat_df = pd.DataFrame.from_dict(orient="index", data=stats_dict)
        #stat_df.columns = ["Value"]
    except:
        stats_dict={"Not gdalinfo compatible"}
    
    return(stats_dict)
    #return(stat_df)
    
# This creates empty dictionaries for each unfilled row - why? Is the datatype default.dict?
s3_files["stats"] = s3_files["gdalinfo"].apply(lambda info: extract_raster_statistics(info))
# This doesn't work - why?
# s3_files["stats"] = s3_files.apply(lambda row: extract_raster_statistics(row["gdalinfo"]), axis=1)

# %%
s3_files["stats"]
# Out:
# 0      {'STATISTICS_MAXIMUM': '50', 'STATISTICS_MEAN'...
# 1      {'STATISTICS_MAXIMUM': '50', 'STATISTICS_MEAN'...
# 2      {'STATISTICS_MAXIMUM': '50', 'STATISTICS_MEAN'...
# 3      {'STATISTICS_MAXIMUM': '50', 'STATISTICS_MEAN'...
# 4      {'STATISTICS_MAXIMUM': '50', 'STATISTICS_MEAN'...
# 5      {'STATISTICS_MAXIMUM': '50', 'STATISTICS_MEAN'...
# 6      {'STATISTICS_MAXIMUM': '50', 'STATISTICS_MEAN'...
# 7      {'STATISTICS_MAXIMUM': '50', 'STATISTICS_MEAN'...
# 8      {'STATISTICS_MAXIMUM': '50', 'STATISTICS_MEAN'...
# 9      {'STATISTICS_MAXIMUM': '50', 'STATISTICS_MEAN'...
# 10     {'STATISTICS_MAXIMUM': '50', 'STATISTICS_MEAN'...
# 11     {'STATISTICS_MAXIMUM': '50', 'STATISTICS_MEAN'...
# 12     {'STATISTICS_MAXIMUM': '50', 'STATISTICS_MEAN'...
# 13     {'STATISTICS_MAXIMUM': '50', 'STATISTICS_MEAN'...
# 14     {'STATISTICS_MAXIMUM': '50', 'STATISTICS_MEAN'...
# 15     {'STATISTICS_MAXIMUM': '50', 'STATISTICS_MEAN'...
# 16     {'STATISTICS_MAXIMUM': '50', 'STATISTICS_MEAN'...
# 17     {'STATISTICS_MAXIMUM': '50', 'STATISTICS_MEAN'...
# 18     {'STATISTICS_MAXIMUM': '50', 'STATISTICS_MEAN'...
# 19     {'STATISTICS_MAXIMUM': '50', 'STATISTICS_MEAN'...
# 20     {'STATISTICS_MAXIMUM': '50', 'STATISTICS_MEAN'...
# 21     {'STATISTICS_MAXIMUM': '50', 'STATISTICS_MEAN'...
# 22     {'STATISTICS_MAXIMUM': '50', 'STATISTICS_MEAN'...
# 23     {'STATISTICS_MAXIMUM': '50', 'STATISTICS_MEAN'...
# 24     {'STATISTICS_MAXIMUM': '50', 'STATISTICS_MEAN'...
# 25     {'STATISTICS_MAXIMUM': '50', 'STATISTICS_MEAN'...
# 26     {'STATISTICS_MAXIMUM': '50', 'STATISTICS_MEAN'...
# 27     {'STATISTICS_MAXIMUM': '50', 'STATISTICS_MEAN'...
# 28     {'STATISTICS_MAXIMUM': '50', 'STATISTICS_MEAN'...
# 29     {'STATISTICS_MAXIMUM': '50', 'STATISTICS_MEAN'...
#                              ...
# 585    {'STATISTICS_MAXIMUM': '1292.3179931641', 'STA...
# 586    {'STATISTICS_MAXIMUM': '1365.7239990234', 'STA...
# 587    {'STATISTICS_MAXIMUM': '1453.5350341797', 'STA...
# 588    {'STATISTICS_MAXIMUM': '1564.4189453125', 'STA...
# 589    {'STATISTICS_MAXIMUM': '874.53460693359', 'STA...
# 590    {'STATISTICS_MAXIMUM': '924.20977783203', 'STA...
# 591    {'STATISTICS_MAXIMUM': '983.63311767578', 'STA...
# 592    {'STATISTICS_MAXIMUM': '1058.6710205078', 'STA...
# 593    {'STATISTICS_MAXIMUM': '1058.6710205078', 'STA...
# 594    {'STATISTICS_MAXIMUM': '1058.6710205078', 'STA...
# 595                                                   {}
# 596                                                   {}
# 597                                                   {}
# 598                                                   {}
# 599    {'STATISTICS_MAXIMUM': '1', 'STATISTICS_MEAN':...
# 600    {'STATISTICS_MAXIMUM': '4542733312', 'STATISTI...
# 601    {'STATISTICS_MAXIMUM': '4542733312', 'STATISTI...
# 602    {'STATISTICS_MAXIMUM': '1', 'STATISTICS_MEAN':...
# 603    {'STATISTICS_MAXIMUM': '1', 'STATISTICS_MEAN':...
# 604    {'STATISTICS_MAXIMUM': '1', 'STATISTICS_MEAN':...
# 605    {'STATISTICS_MAXIMUM': '333439392', 'STATISTIC...
# 606    {'STATISTICS_MAXIMUM': '333439392', 'STATISTIC...
# 607    {'STATISTICS_MAXIMUM': '1', 'STATISTICS_MEAN':...
# 608    {'STATISTICS_MAXIMUM': '1', 'STATISTICS_MEAN':...
# 609    {'STATISTICS_MAXIMUM': '1', 'STATISTICS_MEAN':...
# 610                                                   {}
# 611                                                   {}
# 612                                                   {}
# 613    {'STATISTICS_MAXIMUM': '5', 'STATISTICS_MEAN':...
# 614                                                   {}
# Name: stats, Length: 615, dtype: object

# %%
s3_files.to_csv("/Users/nathansuberi/Desktop/RW_Data/gdalinfo_on_s3.csv")

# %% [markdown]
# Can also use rasterio to calculate stats
#
# https://mapbox.s3.amazonaws.com/playground/perrygeo/rasterio-docs/cookbook.html

# %%
from pprint import pprint
import rasterio
import numpy as np

def rasterio_stats(start_time, num_files, key, count, file_size):
    #try:
    start = datetime.now()

    s3_loc = "/vsicurl/https://wri-public-data.s3.amazonaws.com/" + key

    # Could do all this with src.block_windows... just track min and max and keep updating them
    # Could take a long time... maybe only do for those datasets we have to, i.e. can't fit in memory
    # Judge by the size
    CUTOFF_FOR_USING_BLOCK_WINDOWS = 1000000

    if file_size > CUTOFF_FOR_USING_BLOCK_WINDOWS:
        stats = []
        with rasterio.open(s3_loc, "r") as src:                
            num_bands = src.profile["count"]
            for band in range(1, num_bands+1): 

                new_stats = {'min':np.inf,
                 'mean':None,
                 'median':None,
                 'max':-np.inf}

                windows = src.block_windows()
                for ix, window in windows:
                    array = src.read(indexes=band, window=window)
                    array_min = array.min()
                    array_max = array.max()
                    if array_min < new_stats["min"]:
                        new_stats["min"] = array_min
                    if array_max > new_stats["max"]:
                        new_stats["max"] = array_max
            stats.append(new_stats)
            pass

        return(stats)

    with rasterio.open(s3_loc, "r") as src:
        array = src.read()

    stats = []
    for band in array:
        stats.append({
            'min': band.min(),
            'mean': band.mean(),
            'median': np.median(band),
            'max': band.max()})

    # Show how far in we are...
    print("Finished", count, "out of", num_files)
    print("Progress:", count/float(num_files))
    # This would help you to investigate the outputs on some entries, 
    # even if you have to keyboard interrupt before the entire apply function finishes
    # gdalinfo.append(res)

    end = datetime.now()
    print("Time for current file:", end-start)
    print("Total time:", end-start_time, "\n")

    return(stats)
"""    except:
        # Show how far in we are...
        print("Interrupted")
        print("Finished", count, "out of", num_files)
        print("Progress:", count/float(num_files))
        # This would help you to investigate the outputs on some entries, 
        # even if you have to keyboard interrupt before the entire apply function finishes
        # gdalinfo.append(res)

        end = datetime.now()
        print("Time for current file:", end-start)
        print("Total time:", end-start_time, "\n")
        return("Not a gdalinfo compatible file")
"""
# Initializers
#num_files = s3_files_small.shape[0]
#s3_files_small["count"] = list(range(1, num_files+1))
num_files = s3_files.shape[0]
s3_files["count"] = list(range(1, num_files+1))
start_time = datetime.now()

s3_files["rasterio_stats"] = s3_files.apply(lambda row: rasterio_stats(start_time, 
                                                                        num_files, 
                                                                        row["Key"],
                                                                        row["count"],
                                                                        row["Size"]), axis=1)
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# rasterio/_base.pyx in rasterio._base.DatasetBase.start (rasterio/_base.c:3983)()
#
# rasterio/_err.pyx in rasterio._err.exc_wrap_pointer (rasterio/_err.c:2203)()
#
# CPLE_OpenFailedError: '/vsicurl/https://wri-public-data.s3.amazonaws.com/resourcewatch/raster/Annual_discharge_anomalies/optimize.bat' not recognized as a supported file format.
#
# During handling of the above exception, another exception occurred:
#
# RasterioIOError                           Traceback (most recent call last)
# <ipython-input-6-d32767b0e187> in <module>()
#      87                                                                         row["Key"],
#      88                                                                         row["count"],
# ---> 89                                                                         row["Size"]), axis=1)
#
# ~/.pyenv/versions/3.6.0/lib/python3.6/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4260                         f, axis,
#    4261                         reduce=reduce,
# -> 4262                         ignore_failures=ignore_failures)
#    4263             else:
#    4264                 return self._apply_broadcast(f, axis)
#
# ~/.pyenv/versions/3.6.0/lib/python3.6/site-packages/pandas/core/frame.py in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4356             try:
#    4357                 for i, v in enumerate(series_gen):
# -> 4358                     results[i] = func(v)
#    4359                     keys.append(v.name)
#    4360             except Exception as e:
#
# <ipython-input-6-d32767b0e187> in <lambda>(row)
#      87                                                                         row["Key"],
#      88                                                                         row["count"],
# ---> 89                                                                         row["Size"]), axis=1)
#
# <ipython-input-6-d32767b0e187> in rasterio_stats(start_time, num_files, key, count, file_size)
#      39         return(stats)
#      40
# ---> 41     with rasterio.open(s3_loc, "r") as src:
#      42         array = src.read()
#      43
#
# ~/.pyenv/versions/3.6.0/lib/python3.6/site-packages/rasterio/__init__.py in open(fp, mode, driver, width, height, count, crs, transform, dtype, nodata, **kwargs)
#     280                 raise ValueError(
#     281                     "mode must be one of 'r', 'r+', or 'w', not %s" % mode)
# --> 282             s.start()
#     283             return s
#     284
#
# rasterio/_base.pyx in rasterio._base.DatasetBase.start (rasterio/_base.c:4085)()
#
# RasterioIOError: ("'/vsicurl/https://wri-public-data.s3.amazonaws.com/resourcewatch/raster/Annual_discharge_anomalies/optimize.bat' not recognized as a supported file format.", 'occurred at index 38')

# %%
# Join the gdalinfo results from the smaller dataset back to your dataframe of all files on s3
s3_files = s3_files.join(s3_files_small["rasterio_stats"])

# %%
s3_files
# Out:
#                                    ETag  \
# 0    "b19b8950cb1f4b50843642511ad59c44"
# 1    "47b6977ea93e1ccd1cd5a4e3f551abff"
# 2    "317a22a0425c823f4ab36a34edb0c5b4"
# 3    "2744364ab86d0a22904f938bbe1b0654"
# 4    "29ecefb7dde5b640d422d9629301ac23"
# 5    "fa3a1858d2b4c423d99f53ea3dc6a60b"
# 6    "7003db296e5c9704e9aa1c6104bbc390"
# 7    "af7632d6641fa3a88af9d04ff98f81c7"
# 8    "9aeecfd08caf463667442f976df6129c"
# 9    "01db6772a98b32c9174b46549e9b8cac"
# 10   "eb8ad4e1a8010cba10ade408028bc95d"
# 11   "be8c74a364362e8ceca9bef242a3ed07"
# 12   "ff5102aff5a4dba3532fbfeeb7c2ecbf"
# 13   "e8cb7d0289ecf61ad36dcb8f99e21fa7"
# 14   "713c110b74559952f8e73ec537d28d80"
# 15   "de0ff97b098296fb90f1c362e49892fa"
# 16   "5f43cf7b61f5d0a4f1037d2ae985c7ff"
# 17   "e0eb1465cb52646c46c596aedf1d957e"
# 18   "6f26b78bdd8ab6e4d563472e9e25f147"
# 19   "f942814c8d1d9667767144fce5c8c7a1"
# 20   "eb61eab66bcf66052bba8b2af9580cc7"
# 21   "ce1048896786e26419c58ac5be287c8b"
# 22   "8a93e10f80639b38a713997043e07aea"
# 23   "23a33b209f0b8c1eb88fce6181476d32"
# 24   "ef2bdc358b65d4c69a468c40c3505508"
# 25   "822f7f275c6bee76420d47358ca90c2c"
# 26   "2662893aa4722a2997f46946b66f6202"
# 27   "1bd6ecf413d5fa8648ebc2b5f36b6f94"
# 28   "d517041ad1b01d1b0692f0986e28b551"
# 29   "5e51c63b7c130045ef86ac6ff706029d"
# ..                                  ...
# 585  "4d64a907e9fd233297ec69c5fca0c55d"
# 586  "ef76c5e35f9b4e01daa9e24f8b62bf95"
# 587  "d3e0e0cad2f35466a30838baaae19109"
# 588  "8fa6f856695fd8040f0e4f1901703849"
# 589  "6d1e78cbca8084d025a130fe500fb7cd"
# 590  "f4790e24dd1c38a1aca033c18451e77c"
# 591  "eea1ecf5fd2a2179a474edbcd250ac59"
# 592  "3c10c84859576106ee54518002cf83dc"
# 593  "f6691fb5bf2ee2314837de0671834ee5"
# 594  "73d5cf5cb6085546e717cf412344cfce"
# 595  "d52cd5d1bc672a4c38568597f2983ec8"
# 596  "274c552a4a62da9174b3cbf36741df11"
# 597  "146b80b59ea24dfe24b93c706c2ce683"
# 598  "b1079cfa6753434ea180055def2842a1"
# 599  "f2c617f709d793620d1fd06ef65bdd8b"
# 600  "abf20b755754e98944077e6a4cf25a8c"
# 601  "f1f169ead2ac7f50783808e8f6fc607b"
# 602  "f20afee077a953c2bc6bb17e4fd54fe9"
# 603  "f20afee077a953c2bc6bb17e4fd54fe9"
# 604  "ca6c5074b4867bc57e0b87b06eb8c7bd"
# 605  "e021c959267b9293b8262ab746996232"
# 606  "36802cba8428a685d256391ca225de24"
# 607  "54fcffe77d8df63728e8928b372d3685"
# 608  "54fcffe77d8df63728e8928b372d3685"
# 609  "6296267acfc9d995913435da8fe0d722"
# 610  "ae3b3df9970b49b6523e608759bc957d"
# 611  "7e25879f87ada47f0903f377820db744"
# 612  "5c15e49293da2325a4b398d72bce69e3"
# 613  "ef50a40a70aa35ff4c5e2d25aa83fd8d"
# 614  "6c105aa0c0ae62a821900c88869cef4f"
#
#                                                    Key  \
# 0    resourcewatch/raster/Annual_discharge_anomalie...
# 1    resourcewatch/raster/Annual_discharge_anomalie...
# 2    resourcewatch/raster/Annual_discharge_anomalie...
# 3    resourcewatch/raster/Annual_discharge_anomalie...
# 4    resourcewatch/raster/Annual_discharge_anomalie...
# 5    resourcewatch/raster/Annual_discharge_anomalie...
# 6    resourcewatch/raster/Annual_discharge_anomalie...
# 7    resourcewatch/raster/Annual_discharge_anomalie...
# 8    resourcewatch/raster/Annual_discharge_anomalie...
# 9    resourcewatch/raster/Annual_discharge_anomalie...
# 10   resourcewatch/raster/Annual_discharge_anomalie...
# 11   resourcewatch/raster/Annual_discharge_anomalie...
# 12   resourcewatch/raster/Annual_discharge_anomalie...
# 13   resourcewatch/raster/Annual_discharge_anomalie...
# 14   resourcewatch/raster/Annual_discharge_anomalie...
# 15   resourcewatch/raster/Annual_discharge_anomalie...
# 16   resourcewatch/raster/Annual_discharge_anomalie...
# 17   resourcewatch/raster/Annual_discharge_anomalie...
# 18   resourcewatch/raster/Annual_discharge_anomalie...
# 19   resourcewatch/raster/Annual_discharge_anomalie...
# 20   resourcewatch/raster/Annual_discharge_anomalie...
# 21   resourcewatch/raster/Annual_discharge_anomalie...
# 22   resourcewatch/raster/Annual_discharge_anomalie...
# 23   resourcewatch/raster/Annual_discharge_anomalie...
# 24   resourcewatch/raster/Annual_discharge_anomalie...
# 25   resourcewatch/raster/Annual_discharge_anomalie...
# 26   resourcewatch/raster/Annual_discharge_anomalie...
# 27   resourcewatch/raster/Annual_discharge_anomalie...
# 28   resourcewatch/raster/Annual_discharge_anomalie...
# 29   resourcewatch/raster/Annual_discharge_anomalie...
# ..                                                 ...
# 585  resourcewatch/raster/test/soc_030_liz/soc_030_...
# 586  resourcewatch/raster/test/soc_030_liz/soc_030_...
# 587  resourcewatch/raster/test/soc_030_liz/soc_030_...
# 588  resourcewatch/raster/test/soc_030_liz/soc_030_...
# 589  resourcewatch/raster/test/soc_030_liz/soc_030_...
# 590  resourcewatch/raster/test/soc_030_liz/soc_030_...
# 591  resourcewatch/raster/test/soc_030_liz/soc_030_...
# 592  resourcewatch/raster/test/soc_030_liz/soc_030_...
# 593  resourcewatch/raster/test/soc_030_liz/soc_030_...
# 594  resourcewatch/raster/test/soc_030_liz/soc_030_...
# 595  resourcewatch/raster/wat.018/wat_018_GRACE_aqu...
# 596  resourcewatch/raster/wat.018/wat_018_GRACE_aqu...
# 597  resourcewatch/raster/wat.018/wat_018_GRACE_aqu...
# 598  resourcewatch/raster/wat.018/wat_018_GRACE_aqu...
# 599  resourcewatch/raster/wat_011_global_riverine_N...
# 600  resourcewatch/raster/wat_011_global_riverine_N...
# 601  resourcewatch/raster/wat_011_global_riverine_N...
# 602  resourcewatch/raster/wat_011_global_riverine_N...
# 603  resourcewatch/raster/wat_011_global_riverine_N...
# 604  resourcewatch/raster/wat_011_global_riverine_N...
# 605  resourcewatch/raster/wat_011_global_riverine_N...
# 606  resourcewatch/raster/wat_011_global_riverine_N...
# 607  resourcewatch/raster/wat_011_global_riverine_N...
# 608  resourcewatch/raster/wat_011_global_riverine_N...
# 609  resourcewatch/raster/wat_011_global_riverine_N...
# 610  resourcewatch/raster/wat_015_erosion_risk/tif1...
# 611  resourcewatch/raster/wat_015_erosion_risk/wat_...
# 612  resourcewatch/raster/wat_015_erosion_risk/wat_...
# 613  resourcewatch/raster/wat_015_erosion_risk/wat_...
# 614  resourcewatch/raster/wat_015_erosion_risk/wat_...
#
#                  LastModified  \
# 0   2017-11-01 18:50:10+00:00
# 1   2017-11-01 18:50:10+00:00
# 2   2017-11-01 18:50:10+00:00
# 3   2017-11-01 18:50:10+00:00
# 4   2017-11-01 18:50:10+00:00
# 5   2017-11-01 18:50:10+00:00
# 6   2017-11-01 18:50:10+00:00
# 7   2017-11-01 18:50:10+00:00
# 8   2017-11-01 18:50:10+00:00
# 9   2017-11-01 18:50:10+00:00
# 10  2017-11-01 18:50:10+00:00
# 11  2017-11-01 18:50:10+00:00
# 12  2017-11-01 18:50:10+00:00
# 13  2017-11-01 18:50:10+00:00
# 14  2017-11-01 18:50:10+00:00
# 15  2017-11-01 18:50:10+00:00
# 16  2017-11-01 18:50:10+00:00
# 17  2017-11-01 18:50:10+00:00
# 18  2017-11-01 18:50:10+00:00
# 19  2017-11-01 18:50:11+00:00
# 20  2017-11-01 18:50:11+00:00
# 21  2017-11-01 18:50:11+00:00
# 22  2017-11-01 18:50:11+00:00
# 23  2017-11-01 18:50:11+00:00
# 21   {'DisplayName': 'worldresourcesinst', 'ID': '2...     1034300
# 22   {'DisplayName': 'worldresourcesinst', 'ID': '2...     1034300
# 23   {'DisplayName': 'worldresourcesinst', 'ID': '2...     1034300
# 24   {'DisplayName': 'worldresourcesinst', 'ID': '2...     1034300
# 25   {'DisplayName': 'worldresourcesinst', 'ID': '2...     1034300
# 26   {'DisplayName': 'worldresourcesinst', 'ID': '2...     1034300
# 27   {'DisplayName': 'worldresourcesinst', 'ID': '2...     1034300
# 28   {'DisplayName': 'worldresourcesinst', 'ID': '2...     1034300
# 29   {'DisplayName': 'worldresourcesinst', 'ID': '2...     1034300
# ..                                                 ...         ...
# 585  {'DisplayName': 'worldresourcesinst', 'ID': '2...        1812
# 586  {'DisplayName': 'worldresourcesinst', 'ID': '2...        1812
# 587  {'DisplayName': 'worldresourcesinst', 'ID': '2...        1812
# 588  {'DisplayName': 'worldresourcesinst', 'ID': '2...        1812
# 589  {'DisplayName': 'worldresourcesinst', 'ID': '2...        1812
# 590  {'DisplayName': 'worldresourcesinst', 'ID': '2...        1812
# 591  {'DisplayName': 'worldresourcesinst', 'ID': '2...        1812
# 592  {'DisplayName': 'worldresourcesinst', 'ID': '2...        1812
# 593  {'DisplayName': 'worldresourcesinst', 'ID': '2...      632300
# 594  {'DisplayName': 'worldresourcesinst', 'ID': '2...        4175
# 595  {'DisplayName': 'worldresourcesinst', 'ID': '2...      780744
# 596  {'DisplayName': 'worldresourcesinst', 'ID': '2...    41230840
# 597  {'DisplayName': 'worldresourcesinst', 'ID': '2...    41230840
# 598  {'DisplayName': 'worldresourcesinst', 'ID': '2...    41230844
# 599  {'DisplayName': 'worldresourcesinst', 'ID': '2...     1717086
# 600  {'DisplayName': 'worldresourcesinst', 'ID': '2...     2415501
# 601  {'DisplayName': 'worldresourcesinst', 'ID': '2...      446809
# 602  {'DisplayName': 'worldresourcesinst', 'ID': '2...     2463555
# 603  {'DisplayName': 'worldresourcesinst', 'ID': '2...     2463555
# 604  {'DisplayName': 'worldresourcesinst', 'ID': '2...      418895
# 605  {'DisplayName': 'worldresourcesinst', 'ID': '2...     2389234
# 606  {'DisplayName': 'worldresourcesinst', 'ID': '2...      434171
# 607  {'DisplayName': 'worldresourcesinst', 'ID': '2...     2460473
# 608  {'DisplayName': 'worldresourcesinst', 'ID': '2...     2460473
# 609  {'DisplayName': 'worldresourcesinst', 'ID': '2...      418557
# 610  {'DisplayName': 'worldresourcesinst', 'ID': '2...           5
# 611  {'DisplayName': 'worldresourcesinst', 'ID': '2...          97
# 612  {'DisplayName': 'worldresourcesinst', 'ID': '2...        1510
# 613  {'DisplayName': 'worldresourcesinst', 'ID': '2...  1935438920
# 614  {'DisplayName': 'worldresourcesinst', 'ID': '2...         203
#
#     StorageClass                                     rasterio_stats
# 0       STANDARD                                                NaN
# 1       STANDARD                                                NaN
# 2       STANDARD                                                NaN
# 3       STANDARD                                                NaN
# 4       STANDARD                                                NaN
# 5       STANDARD                                                NaN
# 6       STANDARD                                                NaN
# 7       STANDARD                                                NaN
# 8       STANDARD                                                NaN
# 9       STANDARD                                                NaN
# 10      STANDARD                                                NaN
# 11      STANDARD                                                NaN
# 12      STANDARD                                                NaN
# 13      STANDARD                                                NaN
# 14      STANDARD                                                NaN
# 15      STANDARD                                                NaN
# 16      STANDARD                                                NaN
# 17      STANDARD                                                NaN
# 18      STANDARD                                                NaN
# 19      STANDARD                                                NaN
# 20      STANDARD                                                NaN
# 21      STANDARD                                                NaN
# 22      STANDARD                                                NaN
# 23      STANDARD                                                NaN
# 24      STANDARD                                                NaN
# 25      STANDARD                                                NaN
# 26      STANDARD                                                NaN
# 27      STANDARD                                                NaN
# 28      STANDARD                                                NaN
# 29      STANDARD                                                NaN
# ..           ...                                                ...
# 585     STANDARD  [{'min': -9999.0, 'mean': -6326.8, 'median': -...
# 586     STANDARD  [{'min': -1e+08, 'mean': -863470.0, 'median': ...
# 587     STANDARD  [{'min': -1e+08, 'mean': -700771.0, 'median': ...
# 588     STANDARD  [{'min': -2e+08, 'mean': -1.86744e+06, 'median...
# 589     STANDARD  [{'min': -9999.0, 'mean': -6326.63, 'median': ...
# 590     STANDARD  [{'min': -2e+08, 'mean': -1.57379e+06, 'median...
# 591     STANDARD  [{'min': -2e+08, 'mean': -1.49442e+06, 'median...
# 592     STANDARD  [{'min': -2e+08, 'mean': -2.03212e+06, 'median...
# 593     STANDARD  [{'min': -1e+08, 'mean': -863470.0, 'median': ...
# 594     STANDARD  [{'min': -1e+08, 'mean': -863470.0, 'median': ...
# 595     STANDARD                     Not a gdalinfo compatible file
# 596     STANDARD                                                NaN
# 597     STANDARD                                                NaN
# 598     STANDARD                                                NaN
# 599     STANDARD                                                NaN
# 600     STANDARD                                                NaN
# 601     STANDARD  [{'min': -9999.0, 'mean': 3033193.24192, 'medi...
# 602     STANDARD                                                NaN
# 603     STANDARD                                                NaN
# 604     STANDARD  [{'min': -9999.0, 'mean': -7423.95568166, 'med...
# 605     STANDARD                                                NaN
# 606     STANDARD  [{'min': -9999.0, 'mean': 291769.206798, 'medi...
# 607     STANDARD                                                NaN
# 608     STANDARD                                                NaN
# 609     STANDARD  [{'min': -9999.0, 'mean': -7445.59651097, 'med...
# 610     STANDARD                     Not a gdalinfo compatible file
# 611     STANDARD                     Not a gdalinfo compatible file
# 612     STANDARD                     Not a gdalinfo compatible file
# 613     STANDARD                                                NaN
# 614     STANDARD                     Not a gdalinfo compatible file
#
# [615 rows x 7 columns]

# %% [markdown]
# Use the python email library (smtplib) and basic outline below to send a message that reports on the statistics calculated by gdalinfo, above.

# %%
import smtplib

gmail_user = 'nsuberi@gmail.com'  
gmail_password = '@'

sent_from = gmail_user  
to = ['nathan.suberi@wri.org' ]
subject = 'Resource Watch status update'  
body = "sample"

email_text = """\  
From: %s  
To: %s  
Subject: %s

# %s
""" % (sent_from, to, subject, body)


server = smtplib.SMTP_SSL('smtp.gmail.com', 465)
server.ehlo()
server.login(gmail_user, gmail_password)
server.sendmail(sent_from, to, email_text)
server.close()

print('Email sent!')
#except:  
#    print('Something went wrong...')


## Works to "send" from my account... but hasn't ended up in the other account!
# Out:
# Email sent!
